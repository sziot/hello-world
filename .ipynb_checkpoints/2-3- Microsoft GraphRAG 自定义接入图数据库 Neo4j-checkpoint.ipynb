# %% [markdown]
# # <center>Deepseek企业级Agent项目开发实战</center>

# %% [markdown]
# ## <center>Part 3. Microsoft GraphRAG 自定义接入图数据库 Neo4j</center>

# %% [markdown]
# &emsp;&emsp;`Microsoft GraphRAG` 的核心概念在于将`Konwledge Graph` 存储的数据与大语言模型结合，通过查询图数据库来增强模型的回答质量。经过前两节课程对`Microsoft GraphRAG`构建索引过程的详解，我们已经借助大模型结合提示工程从非结构化文本中提取出实体和关系，其实这就足够支撑我们构建基于本地文档的完整知识图谱了。
#
# &emsp;&emsp;因此，本节课，我们就详细的介绍一下如果将`Microsoft GraphRAG`构建的索引文件存储至本地的图数据库中进行可视化的展示，以便用于接下来的`GraphRAG Query`阶段。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503041644948.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;首先，我们需要在本地搭建一个图数据库来存储知识结构。

# %% [markdown]
# &emsp;&emsp; Neo4j 是一个开源的 `NoSQL` 图数据库，它使用图来表示和存储数据。在 `DB-Engines` 排名中根据数据库管理系统的受欢迎程度对其进行排名中，`Graph DBMS` 榜单中 `Neo4j` 排名第一。查询链接为：[Graph DBMS 排名](https://db-engines.com/en/ranking/graph+dbms?source=post_page-----1cb68f1ac2---------------------------------------)

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518292.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在总体排名中，`Neo4j` 位列第十九，在技术市场上占有很大的空间。其开源地址为：[Neo4j 开源地址](https://github.com/neo4j/neo4j)

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121522873.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;`Neo4j` 的安装方法非常多，比如`Docker`安装， `Neo4j Desktop` 安装，`源码`安装以及在线适用等方式。最简单的方式肯定是使用`Neo4j Desktop` 安装，只需要下载安装包，解压后便可以正常运行。下载安装包的地址如上图所示，在`Neo4j`的`GitHub`地址中找到`Download`按钮，下载`.exe`安装包（比如`Windows`系统），执行傻瓜式安装。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121530623.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;这种安装方式及其简单，因为不需要我们配置任何环境变量，只需要解压后便可运行。但是其成功率并不是特别高，因为电脑环境的差异，可能会导致安装后出现各种未知的问题，比如打开后报错、闪退、点击没有任何反应等情况。因此，我们这里给大家讲解一种最稳定的方式：源码安装。

# %% [markdown]
# &emsp;&emsp;接下来，我们就基于`Win`系统来给大家详细讲解源码安装`Neo4j`的完整流程。

# %% [markdown]
# # 1. Windows 源码安装 Neo4j

# %% [markdown]
# &emsp;&emsp;首先，还是可以通过`GitHub`地址中的`Download`按钮进入到`Neo4j`的官方地址，也可以点击该链接直接进入：https://neo4j.com/

# %% [markdown]
# &emsp;&emsp;在最上方导航栏找到`Products`，点击`Deployment Center`，进入到`Neo4j`的源码下载页面。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518268.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在`Neo4j`的源码下载页面中，需要选择`COMMUNITY`版本，(社区版，即免费版)，然后选择`Windows`版本，并且指定以什么方式下载，比如`tar`包，`unzip`包，`Source Code`，选择结束后，点击`Download`按钮，下载源码包。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518269.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;如果网络正常，会自动弹出窗口，可以选择下载至本地的路径。如下所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518270.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;最后，下载完成后，将`tar` 或者 `zip` 包解压后，便可以得到`Neo4j`的源码包。如下所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518271.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;至此，`Neo4j`的源码包便下载完成了，其实也并不复杂。但是在运行和启动`Neo4j`服务之前，我们需要先配置一下`Neo4j`的环境变量。配置方法就是常规的`Windows`环境变量配置，首先右键点击`此电脑`，选择`属性`，然后点击`高级系统设置`：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518272.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在`系统属性`窗口中，点击`环境变量`按钮，进入到`环境变量`窗口。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518273.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在系统变量中，点击`新建`按钮：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518274.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在`新建`窗口中，输入变量名`NEO4J_HOME`，变量值为`Neo4j`的安装路径，比如我刚才解压的文件路径就是`D:\neo4k-community-2024.02.0-windows`，然后点击`确定`按钮：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518275.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;配置好`NEO4J_HOME`环境变量后，我们还需要配置`Path`环境变量。在`系统变量`中，点击`Path`变量，然后点击`编辑`按钮:

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518276.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;在`Path`变量中，点击`新建`按钮，然后输入`%NEO4J_HOME%\bin`，然后点击`确定`按钮：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518278.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;配置好`Path`环境变量后，`Neo4j`服务就配置好了。但在启动之前，我们还需要检查一下当前系统是否存在`Java`环境，以及`Java`版本是否满足要求。首先需要明确的是，`Neo4j`服务依赖于`Java`环境，同时对`Java`版本也有一定的要求，要求`Java`版本是`OpenJDK`的`21`版本。官方说明：https://neo4j.com/docs/operations-manual/current/installation/windows/

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121558112.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;检查当前系统`Java`环境是否存在，以及`Java`版本是否满足要求的命令如下所示：在`cmd`命令行中输入`java -version`，然后回车，如果出现`Java`版本信息，则说明`Java`环境存在，并且版本满足要求。如果出现`Java`环境不存在，或者版本不满足要求，则需要先安装`Java`环境。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518286.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;如果`Java`环境存在，并且版本满足要求，则可以跳过接下来`Java`环境的安装，直接启动`Neo4j`服务。如果`Java`环境不存在，或者版本不满足要求，则需要先安装`Java`环境。具体的方法为：首先进入`Oracle`官网，点击`Java`，然后点击`Java SE`，进入到`Java`的下载页面。 地址：https://www.oracle.com/java/technologies/downloads/?er=221886#java21

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121606257.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;下载至本地并执行`.exe` 的安装即可，这里不在赘述。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518282.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;同样，安装完成以后，也需要配置`JAVA_HOME`环境变量。在`系统变量`中，点击`新建`按钮，然后输入`JAVA_HOME`，变量值为`Java`的安装路径，比如我刚才安装的`Java`路径是`C:\Program Files\Java\jdk-21`，然后点击`确定`按钮：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121611802.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;配置好`JAVA_HOME`环境变量后，我们还需要配置`Path`环境变量。在`系统变量`中，点击`Path`变量，然后点击`编辑`按钮：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518285.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;全部配置好以后，在`cmd`命令行中输入`java -version`，然后回车，如果出现`Java`版本信息，则说明`java`环境配置成功。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518286.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;至此，配置好了`Neo4j`服务的环境，同时其依赖的`Java`环境也配置好了。接下来，我们就可以启动`Neo4j`服务了。在`cmd`命令行中输入`neo4j windows-service install`，然后回车，如果出现`Neo4j`服务安装成功的信息，则说明`Neo4j`服务安装成功。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518287.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;安装成功后，在`cmd`命令行中输入`neo4j.bat console`，然后回车，如果出现`Neo4j`服务启动成功的信息，则说明`Neo4j`服务启动成功。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518288.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;启动后会看到两个连接地址，一个是`Bolt:localhost:7687`，一个是`HTTP:localhost:7474`，其中`Bolt`是`Neo4j`的`Bolt`协议连接地址，`HTTP`是`Neo4j`的`HTTP`协议连接地址。我们可以通过`localhost:7474`访问`Neo4j`的`Web`界面，如下所示：

# %% [markdown]
# &emsp;&emsp;首次登录的默认账号是`neo4j`，密码是`neo4j`。输入后点击`connect`按钮，即可进入到`Neo4j`的`Web`界面。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518289.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;同时，首次登录成功后会提示修改密码，此时我们点击`Change Password`按钮，然后输入新的密码，点击`Save`按钮，即可修改密码。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121518290.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，`Neo4j`服务便在本地安装成功并顺利了，接下来就可以开始使用`Neo4j`服务了。

# %% [markdown]
# # 2. Python 连接 Neo4j

# %% [markdown]
# &emsp;&emsp;`Neo4j` 与 `Python`、`JavaScript`、`Java` 和 `.Net` 等库都做了集成，因此只要安装了对应的库，就可以连接`Neo4j`服务。在`Python`中，可以直接通过`pip` 安装`neo4j`包来连接`Neo4j`服务。执行如下命令：

# %%
! pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\programdata\anaconda3\envs\agent\lib\site-packages (5.26.0)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\envs\agent\lib\site-packages (from neo4j) (2024.2)

# %% [markdown]
# &emsp;&emsp;从`neo4j`包中导入`GraphDatabase`类，然后设置`Neo4j`的连接地址、用户名、密码和数据库名称，然后创建`driver`对象，最后通过`driver`对象连接`Neo4j`服务。执行如下代码：

# %%
from neo4j import GraphDatabase


NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"  # 这里替换成自己设置的密码
NEO4J_DATABASE="neo4j"         # 社区版仅能使用默认的neo4j数据库，不支持创建其他数据库

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

# %% [markdown]
# &emsp;&emsp;可以快速做一个连接测试，执行如下代码：

# %%
driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

def test_connection():
    # 在这里创建会话
    with driver.session() as session:
        session.run("MATCH (n) RETURN n LIMIT 1")

try:
    test_connection()
    print("连接成功！")
except Exception as e:
    print("连接失败:", e)
finally:
    driver.close()  # 确保在所有操作完成后再关闭驱动程序
# Out:
# 连接成功！

# %% [markdown]
# &emsp;&emsp;如果返回结果为`连接成功！`，则说明`Neo4j`服务一切正常，便可以进入下面的实践。否则需要进一步检查`Neo4j`服务是否正常启动，以及`Neo4j`的连接地址、用户名、密码和数据库名称是否正确。

# %% [markdown]
# # 3. 知识图谱快速入门

# %% [markdown]
# &emsp;&emsp;知识图谱建立在图论的基础上，而图是用于对对象之间的成对关系进行建模的结构。图主要由两个主要元素组成：<font color="red">节点</font>和<font color="red">关系</font>。其中：
#
# - 节点代表单个对象或实体，类似于传统数据库中的记录。这些实体可以是任何人、公司或地点。
# - 节点通过标签进行分类，方便根据节点的角色进行分类和查询，例如“客户”或“产品”。

# %% [markdown]
# &emsp;&emsp;`Neo4j` 是存储知识图谱的其中一种图数据库，它支持节点和关系的存储，同时，通过`Cypher`查询语言进行图谱的创建、查询和分析，即 `Cypher` 是 `Neo4j` 中用于交互和操作图谱的查询语言。其形式及如下：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131043957.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;而关于`Cypher`查询语言的详细介绍，可以参考`Neo4j`的官方文档：[Cypher Core concepts](https://neo4j.com/docs/cypher-manual/current/queries/concepts/)进行学习。我们这里不对基础内容展开详细的介绍。本节课的重点是借助`Neo4j` 的 `Python` 集成，给大家介绍用于接下来`Microsoft GraphRAG` 索引文件接入过程时必备的相关概念。主要有以下几点：

# %% [markdown]
# - **节点，可以是`Person`、`Organization`、`Product`、`Location`等实体类型，每个节点可以有多个属性，例如`name`、`age`、`gender`等，同时<font color="red">属性是以键值对形式存储的</font>。**

# %%
from neo4j import GraphDatabase


NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"  # 这里替换成自己设置的密码
NEO4J_DATABASE="neo4j"         # 社区版仅能使用默认的neo4j数据库，不支持创建其他数据库

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

# %% [markdown]
# &emsp;&emsp;通过`CREATE`语句可以创建节点，同时可以为节点添加属性，语法形式是：
#
# ```python
#     CREATE (node_name:node_type {property_name: property_value, ...})
# ```
#
# &emsp;&emsp;其中，`node_name` 这是一个变量名，用于引用创建的节点，`node_type` 是节点的标签，表示节点的类型，`property_name` 是属性的名称，`property_value` 是属性的值。

# %%
with driver.session() as session:
    # 添加多个节点：Person
    session.run("""
        CREATE (p1:Person {name: 'muyu', age: 30, city: 'beijing'}),
               (p2:Person {name: 'zhangsan', age: 23, city: 'shanghai'})
    """)
    
    # 添加多个节点：Company
    session.run("""
        CREATE (c1:Company {name: 'Fufan', industry: 'Technology', location: 'beijing'}),
               (c2:Company {name: 'Beyond', industry: 'Education', location: 'beijing'})
    """)

# %% [markdown]
# &emsp;&emsp;如上代码所示：类似 `p1` 这种的生命周期仅仅是局部作用域：变量的作用域通常是局部的，仅在创建它的查询中有效。一旦查询执行完毕，变量就不再存在。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131057101.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;这里面的`Person` 和 `Company` 是节点的标签，`name`、`age`、`city` 是节点的属性，`muyu`、`zhangsan`、`beijing` 是节点的属性值。 其中：
#
# - 通过`CREATE`语句创建节点时，如果该标签不存在，则创建该标签，否则不创建。
# - 一个标签下可以有多个节点，一个节点也可以有多个标签。比如`Person` 标签下可以有`muyu` 和 `zhangsan` 两个节点， 同时`muyu` 和 `zhangsan` 也可以有多个标签，比如同时是 `Person` 和 `Student`。
# - 一个节点可以有多个属性，比如`muyu` 节点可以有`name`、`age`、`city` 三个属性。

# %% [markdown]
# &emsp;&emsp;比如我们现在将`muyu` 和 `zhangsan` 增加到 `Student` 标签下的节点，同时他们也是 `Person` 标签下的节点。因此我们通过如下`Cypher`语句进行创建：

# %%
with driver.session() as session:
    # 为名为"muyu"的节点添加Student标签
    session.run("""
        MATCH (p:Person {name: 'muyu'})
        SET p:Student
        RETURN p
    """)
    
    # 为名为"zhangsan"的节点添加Student标签
    session.run("""
        MATCH (p:Person {name: 'zhangsan'})
        SET p:Student
        RETURN p
    """)

# %% [markdown]
# &emsp;&emsp;这里需要了解的知识点是：`MATCH` 语句用于在图谱中查找节点，`SET` 语句用于为节点添加标签，`RETURN` 语句用于返回添加标签后的节点。执行后在`Neo4j`的浏览器中可以看到：`muyu` 和 `zhangsan` 同时是 `Person` 和 `Student` 标签下的节点。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131118642.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;同时，我们也可以更新节点的属性，比如将`muyu` 的`age` 属性更新为`31`，通过如下`Cypher`语句进行更新：

# %%
with driver.session() as session:
    session.run("""
        MATCH (p:Person {name: 'muyu'})
        SET p.age = 31
        RETURN p
    """)

# %% [markdown]
# &emsp;&emsp;执行后在`Neo4j`的浏览器中可以看到：`muyu` 的`age` 属性被更新为`31`。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131121413.png" width=80%></div>

# %% [markdown]
# - 关系：关系是连接节点的边，用于表示节点之间的关联。

# %% [markdown]
# &emsp;&emsp;关系由两个主要元素组成：
#   - 关系类型：表示关系的名称，例如“朋友”或“同事”。
#   - 关系方向：表示关系的方向，例如“从A到B”或“从B到A”。
#
# &emsp;&emsp;关系类型和关系方向是关系的重要组成部分，用于描述节点之间的关联。关系类型可以是任何字符串，而关系方向可以是“正向”或“反向”。其语法形式如下：
#
# ```python
#     CREATE (node_name)-[:relation_type]->(related_node_name)
# ```
#
# &emsp;&emsp;其中，`node_name` 是节点的名称，`relation_type` 是关系的类型，`related_node_name` 是相关节点的名称

# %% [markdown]
# &emsp;&emsp;这里我们以`muyu` 和 `zhangsan` 为例，创建`company` 和 `person` 之间的关系，通过如下`Cypher`语句进行创建：

# %%
with driver.session() as session:
    # 创建muyu与Fufan公司之间的EMPLOYED_BY关系
    session.run("""
        MATCH (p:Person {name: 'muyu'})
        MATCH (c:Company {name: 'Fufan'})
        CREATE (p)-[:EMPLOYED_BY]->(c)
    """)
    
    # 创建zhangsan与Beyond公司之间的LIVES_IN关系
    session.run("""
        MATCH (p:Person {name: 'zhangsan'})
        MATCH (c:Company {name: 'Beyond'})
        CREATE (p)-[:EMPLOYED_BY]->(c)
    """)

# %% [markdown]
# &emsp;&emsp;需要使用`MATCH`语句先找到相应的节点，然后再创建它们之间的关系。执行代码后，则可以在`Neo4j`的浏览器中看到：`muyu` 和 `zhangsan` 与`Fufan` 和 `Beyond` 公司之间建立了`EMPLOYED_BY` 关系。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131127430.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;以上是通过节点、属性、标签、关系四个概念的角度，给大家介绍了`Neo4j` 中图谱的创建、更新和查询。这样的图谱其实就已经具备了知识图谱的雏形，即：
#
# - 节点：表示实体，例如人、公司、地点等。
# - 属性：表示实体的特征，例如姓名、年龄、城市等。
# - 标签：表示实体的类型，例如`Person`、`Company`、`Student`等。
# - 关系：表示实体之间的关系，例如`EMPLOYED_BY`等。

# %% [markdown]
# &emsp;&emsp;我们是可以基于这样的图谱开始进行简单到复杂的查询的，比如如下的一些示例：

# %%
def neo4j_query_examples(driver, query_type, params=None):
    """
    执行各种Neo4j查询示例
    
    参数:
    - driver: Neo4j驱动实例
    - query_type: 查询类型，可选值包括:
        'all_persons', 'all_companies', 'filter_by_city', 'all_relationships',
        'specific_relationship', 'node_relationships', 'path_query', 'aggregation',
        'group_by', 'colleagues', 'complex_query', 'param_query', 'subgraph', 'community'
    - params: 查询参数字典，根据查询类型不同而不同
    
    返回:
    - 查询结果列表
    """
    if params is None:
        params = {}
    
    results = []
    
    with driver.session() as session:
        if query_type == 'all_persons':
            # 查询所有Person节点
            result = session.run("""
                MATCH (p:Person)
                RETURN p.name AS name, p.age AS age, p.city AS city
            """)
            
            print("所有Person节点:")
            for record in result:
                print(f"姓名: {record['name']}, 年龄: {record['age']}, 城市: {record['city']}")
                results.append({
                    'name': record['name'],
                    'age': record['age'],
                    'city': record['city']
                })
        
        elif query_type == 'all_companies':
            # 查询所有Company节点
            result = session.run("""
                MATCH (c:Company)
                RETURN c.name AS name, c.industry AS industry, c.location AS location
            """)
            
            print("所有Company节点:")
            for record in result:
                print(f"公司: {record['name']}, 行业: {record['industry']}, 位置: {record['location']}")
                results.append({
                    'name': record['name'],
                    'industry': record['industry'],
                    'location': record['location']
                })
        
        elif query_type == 'filter_by_city':
            # 按城市过滤Person节点
            city = params.get('city', 'beijing')
            result = session.run("""
                MATCH (p:Person)
                WHERE p.city = $city
                RETURN p.name AS name, p.age AS age
            """, {'city': city})
            
            print(f"{city}的人员:")
            for record in result:
                print(f"姓名: {record['name']}, 年龄: {record['age']}")
                results.append({
                    'name': record['name'],
                    'age': record['age']
                })
        
        elif query_type == 'all_relationships':
            # 查询所有关系
            result = session.run("""
                MATCH (p:Person)-[r]->(c:Company)
                RETURN p.name AS person, type(r) AS relationship, c.name AS company
            """)
            
            print("所有人员与公司的关系:")
            for record in result:
                print(f"{record['person']} {record['relationship']} {record['company']}")
                results.append({
                    'person': record['person'],
                    'relationship': record['relationship'],
                    'company': record['company']
                })
        
        elif query_type == 'specific_relationship':
            # 查询特定类型的关系
            rel_type = params.get('rel_type', 'EMPLOYED_BY')
            result = session.run(f"""
                MATCH (p:Person)-[:{rel_type}]->(c:Company)
                RETURN p.name AS person, c.name AS company
            """)
            
            print(f"{rel_type}关系:")
            for record in result:
                print(f"{record['person']} 与 {record['company']} 有{rel_type}关系")
                results.append({
                    'person': record['person'],
                    'company': record['company']
                })
        
        elif query_type == 'node_relationships':
            # 查询特定节点的关系
            person_name = params.get('person_name', 'muyu')
            result = session.run("""
                MATCH (p:Person {name: $name})-[r]->(c)
                RETURN type(r) AS relationship, c.name AS connected_to, labels(c) AS node_type
            """, {'name': person_name})
            
            print(f"{person_name}的所有关系:")
            for record in result:
                print(f"关系类型: {record['relationship']}, 连接到: {record['connected_to']}, 节点类型: {record['node_type']}")
                results.append({
                    'relationship': record['relationship'],
                    'connected_to': record['connected_to'],
                    'node_type': record['node_type']
                })
              
        elif query_type == 'aggregation':
            # 聚合查询
            result = session.run("""
                MATCH (p:Person)-[:EMPLOYED_BY]->(c:Company)
                RETURN c.name AS company, count(p) AS employee_count, avg(p.age) AS avg_age
            """)
            
            print("公司员工统计:")
            for record in result:
                print(f"公司: {record['company']}, 员工数: {record['employee_count']}, 平均年龄: {round(record['avg_age'], 1)}")
                results.append({
                    'company': record['company'],
                    'employee_count': record['employee_count'],
                    'avg_age': record['avg_age']
                })
        
        elif query_type == 'group_by':
            # 条件分组查询
            result = session.run("""
                MATCH (p:Person)
                RETURN p.city AS city, count(p) AS person_count,
                       collect(p.name) AS names
                ORDER BY person_count DESC
            """)
            
            print("按城市分组的人员统计:")
            for record in result:
                print(f"城市: {record['city']}, 人数: {record['person_count']}, 姓名: {record['names']}")
                results.append({
                    'city': record['city'],
                    'person_count': record['person_count'],
                    'names': record['names']
                })
        
        
        elif query_type == 'complex_query':
            # 多条件复合查询
            min_age = params.get('min_age', 25)
            location = params.get('location', 'beijing')
            result = session.run("""
                MATCH (p:Person)-[r]->(c:Company)
                WHERE p.age > $min_age AND c.location = $location
                AND (type(r) = 'EMPLOYED_BY' OR type(r) = 'INVESTED_IN')
                RETURN p.name AS person, p.age AS age, 
                       type(r) AS relationship, c.name AS company
                ORDER BY p.age DESC
            """, {'min_age': min_age, 'location': location})
            
            print(f"{min_age}岁以上且与{location}公司有雇佣或投资关系的人:")
            for record in result:
                print(f"{record['person']} ({record['age']}岁) {record['relationship']} {record['company']}")
                results.append({
                    'person': record['person'],
                    'age': record['age'],
                    'relationship': record['relationship'],
                    'company': record['company']
                })
        
        elif query_type == 'param_query':
            # 参数化查询
            query_params = {
                'min_age': params.get('min_age', 25),
                'location': params.get('location', 'beijing'),
                'relationship_types': params.get('relationship_types', ["EMPLOYED_BY", "INVESTED_IN"])
            }
            
            result = session.run("""
                MATCH (p:Person)-[r]->(c:Company)
                WHERE p.age > $min_age AND c.location = $location
                AND type(r) IN $relationship_types
                RETURN p.name AS person, type(r) AS relationship, c.name AS company
            """, query_params)
            
            print(f"参数化查询结果 (年龄 > {query_params['min_age']}, 位置: {query_params['location']}):")
            for record in result:
                print(f"{record['person']} {record['relationship']} {record['company']}")
                results.append({
                    'person': record['person'],
                    'relationship': record['relationship'],
                    'company': record['company']
                })
        
        else:
            print(f"未知的查询类型: {query_type}")
            results.append({"error": f"未知的查询类型: {query_type}"})
    
    return results

# %%
from neo4j import GraphDatabase

NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"  # 这里替换成自己设置的密码
NEO4J_DATABASE="neo4j"         # 社区版仅能使用默认的neo4j数据库，不支持创建其他数据库

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

try:
    # 查询所有Person节点
    neo4j_query_examples(driver, 'all_persons')
    
    # 查询北京的人员
    neo4j_query_examples(driver, 'filter_by_city', {'city': 'beijing'})
    
    # 查询muyu的所有关系
    neo4j_query_examples(driver, 'node_relationships', {'person_name': 'muyu'})
    
    # 执行复杂查询
    neo4j_query_examples(driver, 'complex_query', {
        'min_age': 20,
        'location': 'beijing'
    })    
    
finally:
    # 关闭驱动
    driver.close()
# Out:
# 所有Person节点:
# 姓名: muyu, 年龄: 31, 城市: beijing
# 姓名: zhangsan, 年龄: 23, 城市: shanghai
# beijing的人员:
# 姓名: muyu, 年龄: 31
# muyu的所有关系:
# 关系类型: EMPLOYED_BY, 连接到: Fufan, 节点类型: ['Company']
# 20岁以上且与beijing公司有雇佣或投资关系的人:
# muyu (31岁) EMPLOYED_BY Fufan
# zhangsan (23岁) EMPLOYED_BY Beyond

# %% [markdown]
# &emsp;&emsp;至此，我们已经完成了`Neo4j`的连接，并掌握了基础的`Cypher`语句，接下来，我们将介绍如何将`Microsoft GraphRAG`生成的各个`.parquet`文件导入到`Neo4j`的图数据库中，构建更加复杂和丰富的知识图谱。

# %% [markdown]
# # 4. Microsoft GraphRAG 导入

# %% [markdown]
# &emsp;&emsp;在上节课中，我们详细的介绍了`Microsoft GraphRAG`提供的两种方法将本地的非结构化数据构建知识图谱索引的完整流程及底层的实现原理，而无论是通过`Microsoft GraphRAG`的`CLI`工具，还是通过源码的`Poetry`, 其生成的文件都是一样的，即在`output`目录下会依次生成：
#
# - documents.parquet
# - text_units.parquet
# - entities.parquet
# - relationships.parquet
# - communities.parquet
# - community_reports.parquet

# %% [markdown]
# &emsp;&emsp;这些文件中存储了构建知识图谱索引的全部数据，而本节课我们将介绍如何将这些数据导入到`Neo4j`的图数据库中，并进行可视化。

# %% [markdown]
# ## 4.1 构建批量导入函数

# %% [markdown]
# &emsp;&emsp;在开始逐步构建知识图谱之前，我们需要先构建一个批量的通用导入函数，用于将各个`.parquet`文件中的数据更高效的导入到`Neo4j`的图数据库中。 知识图谱存储的往往是非常大的数据量（数百万到数亿行的量级），有非常多的复杂关系，因此在实际的使用中，往往都是需要一些优化策略来做大规模数据的管理，常见的优化方案是：
#
# 1. 使用 `Neo4j Admin Import` 导入，这是最快的导入方式，可以比`Cypher`导入快`10-100`倍。
# 2. 并行处理与多线程。
# 3. 使用`APOC`批量导入。
# 4. 搭配其他优化策略，比如优化`Cypher`语句、优化数据格式、数据分区与分布式处理等。

# %% [markdown]
# &emsp;&emsp;在本期的`GraphRAG`系列课程中，我们会结合不同的场景依次介绍以上四种大规模数据导入的优化策略。本节课，我们首先介绍如何做并行处理与多线程。

# %% [markdown]
# &emsp;&emsp;在如下的`parallel_batched_import`函数中，实现的是一个使用并行批量导入数据到`Neo4j`的函数。它将大批量数据分成多个批次，然后使用线程池并行处理每个批次，从而提高导入的效果。

# %%
import time
import pandas as pd
import concurrent.futures
from neo4j import GraphDatabase


def parallel_batched_import(statement, df, batch_size=100, max_workers=8):
    """
    使用并行处理进行批量导入数据到Neo4j
    
    参数:
    - statement: Cypher查询语句，使用value作为每行数据的引用
    - df: 要导入的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """

    # 1. 初始化，计算总行数，批次数，并记录开始时间
    total = len(df)
    batches = (total + batch_size - 1) // batch_size  # 向上取整
    start_time = time.time()
    results = []
    
    print(f"开始并行导入 {total} 行数据，分为 {batches} 个批次，每批 {batch_size} 条")
    

    # 2. 定义批处理函数
    def process_batch(batch_idx):
        """
        批处理函数，用于处理每个批次的数据
        """

        # 1. 计算批次的起始和结束索引
        start = batch_idx * batch_size
        end = min(start + batch_size, total)
        batch = df.iloc[start:end]
        
        batch_start_time = time.time()
        
        try:
            with driver.session(database=NEO4J_DATABASE) as session:
                # NWIND 是 Cypher 查询语言中的一个关键字，用于将一个列表展开为多行。 $rows 是一个参数，表示将要传入的行数据
                # 完整意思是：将$rows参数（一个列表）中的每个元素展开，每个元素被赋值给变量value， 对每个value执行后续的Cypher语句
                #    id   name   age
                #    0    张三    25
                #    1    李四    30

                # 调用.to_dict("records")后，得到：
                # [
                #     {"id": 1, "name": "张三", "age": 25},
                #     {"id": 2, "name": "李四", "age": 30}
                # ]
                result = session.run(
                    "UNWIND $rows AS value " + statement,   
                    rows=batch.to_dict("records")
                )
                summary = result.consume()    # Neo4j 中用于处理查询结果的一个方法。它的主要作用是获取查询的摘要信息，包括执行统计、计数和其他相关信息
                batch_duration = time.time() - batch_start_time
                
                return {
                    "batch": batch_idx,
                    "rows": end - start,
                    "success": True,
                    "duration": batch_duration,
                    "counters": summary.counters   # summary.counters 是在执行 Cypher 查询后返回的统计信息
                }
        except Exception as e:
            batch_duration = time.time() - batch_start_time
            print(f"批次 {batch_idx} (行 {start}-{end-1}) 处理失败: {str(e)}")
            
            return {
                "batch": batch_idx,
                "rows": end - start,
                "success": False,
                "duration": batch_duration,
                "error": str(e)
            }
    
    # 使用线程池并行处理批次
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_batch, i) for i in range(batches)]
        
        # 处理完成的批次
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            result = future.result()
            results.append(result)
            
            if result["success"]:
                print(f"批次 {result['batch']} 完成: {result['rows']} 行, 耗时 {result['duration']:.2f}秒")
            else:
                print(f"批次 {result['batch']} 失败: {result['rows']} 行, 耗时 {result['duration']:.2f}秒, 错误: {result.get('error', '未知错误')}")
            
            # 显示进度
            print(f"进度: {i+1}/{batches} 批次完成 ({((i+1)/batches*100):.1f}%)")
    
    # 统计结果
    successful_rows = sum(r["rows"] for r in results if r["success"])
    failed_rows = sum(r["rows"] for r in results if not r["success"])
    
    duration = time.time() - start_time
    rows_per_second = successful_rows / duration if duration > 0 else 0
    
    print(f"导入完成: 总计 {total} 行, 成功 {successful_rows} 行, 失败 {failed_rows} 行")
    print(f"总耗时: {duration:.2f}秒, 平均速度: {rows_per_second:.2f} 行/秒")
    
    return {
        "total_rows": total,
        "successful_rows": successful_rows,
        "failed_rows": failed_rows,
        "duration_seconds": duration,
        "rows_per_second": rows_per_second,
        "batch_results": results
    }

# %% [markdown]
# &emsp;&emsp;理解了`parallel_batched_import`函数后，我们就依次将完成`Microsoft GraphRAG`索引过程得到的各个`.parquet`文件导入到`Neo4j`的图数据库中。

# %% [markdown]
# ## 4.2 导入文档

# %% [markdown]
# &emsp;&emsp;`documents.parquet`文件中主要存储的是在执行索引之前，我们存放在`Input`文件夹下的原始的非结构化文档，比如`.txt`、`csv`等大批量文件。经过索引的构建流程后，会经过文档加载器解析出文档中的全部内容，并且会通过后处理，在进行`text_unit`的切分后，填充每个文档对应的`text_unit_ids`。 读取该文件的代码如下所示：

# %%
import pandas as pd
from tabulate import tabulate

df_documents = pd.read_parquet('documents.parquet')  # 替换为实际路径

print(tabulate(df_documents, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+----------------------+----------------------+----------------------+---------------------------+----------+
# | id                   | human_readable_id | title                | text                 | text_unit_ids        | creation_date             | metadata |
# +----------------------+-------------------+----------------------+----------------------+----------------------+---------------------------+----------+
# | 66bf9f67042bef537ff7 | 1                 | technology_companies | 在过去的几十年中，全 | ['8f298209e463b21ab7 | 2025-03-12 15:10:35 +0800 |          |
# | c55ae62fa9471ea3e56e |                   | .txt                 | 球科技行业经历了翻天 | 25bc5347cdeb4a33454e |                           |          |
# | e868278e00d44302d9ad |                   |                      | 覆地的变化。以硅谷为 | 3d1cea78efdf96c3f5a2 |                           |          |
# | fb80dd0d8e0a226f0550 |                   |                      | 中心的创新生态系统催 | 6f19fd5477e4bc115897 |                           |          |
# | 76e16c9c0a2f428cb967 |                   |                      | 生了许多世界知名的科 | 55e6e95b20dcb02bf293 |                           |          |
# | 443c406533e17154153a |                   |                      | 技公司，如苹果、谷歌 | 98715b473987f03271f5 |                           |          |
# | 027ad2aa             |                   |                      | 、微软和亚马逊。这些 | a6cb030d2b'  'b0c0fd |                           |          |
# |                      |                   |                      | 公司不仅改变了人们的 | b9714ba7fb74bb0e162b |                           |          |
# |                      |                   |                      | 生活方式，还推动了全 | fb90ec6bab1d50450576 |                           |          |
# |                      |                   |                      | 球经济的发展。  苹果 | 78d0d91b9d5f72936ae3 |                           |          |
# |                      |                   |                      | 公司：从车库到万亿美 | 44577359ab5418f104f2 |                           |          |
# |                      |                   |                      | 元市值               | 35cdef72f703ea06aa4b |                           |          |
# |                      |                   |                      | 苹果公司（Apple Inc. | 96976c1dfab32ef0000c |                           |          |
# |                      |                   |                      | ）由史蒂夫·乔布斯（S | 00'  'f3f52dc49c93ea |                           |          |
# |                      |                   |                      | teve Jobs）、史蒂夫· | 0a43c6c483269624ed62 |                           |          |
# |                      |                   |                      | 沃兹尼亚克（Steve Wo | 27b53c15bf39a1fd8102 |                           |          |
# |                      |                   |                      | zniak）和罗恩·韦恩（ | 227d44332fad53503232 |                           |          |
# |                      |                   |                      | Ron Wayne）于 1976   | eff12494290e40dfdb11 |                           |          |
# |                      |                   |                      | 年在美国加利福尼亚州 | 4c8c1df2db601a555fec |                           |          |
# |                      |                   |                      | 库比蒂诺的一个车库中 | 297639ec3d7a6a'  '28 |                           |          |
# |                      |                   |                      | 创立。最初，苹果公司 | 6421f13c7d50f5e46eab |                           |          |
# |                      |                   |                      | 专注于个人电脑的开发 | 4c8500bb778a63ef0b11 |                           |          |
# |                      |                   |                      | ，其第一款产品 Apple | 5a0125f5b60eac4eb2bf |                           |          |
# |                      |                   |                      | I 在 1976            | e6b394e8d2dd12062245 |                           |          |
# |                      |                   |                      | 年发布。1984         | 4cee42514379d1e1dbc1 |                           |          |
# |                      |                   |                      | 年，苹果推出了       | 664fb018d4ad109f918b |                           |          |
# |                      |                   |                      | Macintosh 电脑，这是 | dea5bf'  'c74ed55a3e |                           |          |
# |                      |                   |                      | 第一款成功商用化的图 | bcbc0bb18a6e60a119aa |                           |          |
# |                      |                   |                      | 形用户界面电脑，彻底 | b7efcf80364e115f5ce4 |                           |          |
# |                      |                   |                      | 改变了人机交互的方式 | 157b1ac1a2aef7ac4d9f |                           |          |
# |                      |                   |                      | 。  乔布斯在 1985    | 0b13ab35a02fdc381471 |                           |          |
# |                      |                   |                      | 年离开苹果，但在     | 6c37007baabe0eeb6124 |                           |          |
# |                      |                   |                      | 1997 年回归，并带领  | 81ae10ef89fdc45015'  |                           |          |
# |                      |                   |                      | 公司推出了           | '01434455979f8f5369e |                           |          |
# |                      |                   |                      | iMac、iPod、iPhone   | a62fdc2ff4ff13606772 |                           |          |
# |                      |                   |                      | 和 iPad 等一系列革命 | 93c575d32f1672521daa |                           |          |
# |                      |                   |                      | 性产品。2007         | ee69a7f111448645d4c7 |                           |          |
# |                      |                   |                      | 年，iPhone 的发布标  | 0464db9dbbbe3d009c42 |                           |          |
# |                      |                   |                      | 志着智能手机时代的开 | 336fd2801161e3418c60 |                           |          |
# |                      |                   |                      | 始，苹果也因此成为全 | 7aa4efc1d'  'c4c5297 |                           |          |
# |                      |                   |                      | 球最有价值的公司之一 | b4bf585666851d3e5012 |                           |          |
# |                      |                   |                      | 。截至 2023          | 3a6e5dd9a6223b146756 |                           |          |
# |                      |                   |                      | 年，苹果的市值已超过 | 24752a2a3033ba6629af |                           |          |
# |                      |                   |                      | 2 万亿美元。  谷歌： | 55fb798a18a2d6ecbb97 |                           |          |
# |                      |                   |                      | 从搜索引擎到人工智能 | 4baddbfb2eace4d64689 |                           |          |
# |                      |                   |                      | 巨头 谷歌（Google）  | 71449b35c10fa5c1cc2c |                           |          |
# |                      |                   |                      | 由拉里·佩奇（Larry P | c'  'ff294773b342885 |                           |          |
# |                      |                   |                      | age）和谢尔盖·布林（ | 4364049d61157058e7f9 |                           |          |
# |                      |                   |                      | Sergey Brin）于 1998 | de1a226375609c8b313a |                           |          |
# |                      |                   |                      | 年在加利福尼亚州门洛 | ebd02b85757c543588bf |                           |          |
# |                      |                   |                      | 帕克创立。最初，谷歌 | d9af6a9fe5ce8b934d3f |                           |          |
# |                      |                   |                      | 是一个搜索引擎，但其 | 05568b9d546deea0526c |                           |          |
# |                      |                   |                      | 技术迅速超越了竞争对 | 032d061a7a1cd'  'd60 |                           |          |
# |                      |                   |                      | 手，成为全球最受欢迎 | 53c77d9ebfd4d738edc8 |                           |          |
# |                      |                   |                      | 的搜索工具。2004 年  | 952fb42859160e820228 |                           |          |
# |                      |                   |                      | ，谷歌在纳斯达克上市 | 5dc7775b30a9af0a2111 |                           |          |
# |                      |                   |                      | ，募集资金超过 16    | 2d34c0fa090292a87f80 |                           |          |
# |                      |                   |                      | 亿美元。  谷歌的创新 | 3dd2311ac0dcb9762898 |                           |          |
# |                      |                   |                      | 能力不仅限于搜索。20 | 9f4419b04eba30a25c17 |                           |          |
# |                      |                   |                      | 06 年，谷歌收购了 Yo | 25299'  '975147fe6dd |                           |          |
# |                      |                   |                      | uTube，成为在线视频  | f0ae318e21d71cad0028 |                           |          |
# |                      |                   |                      | 领域的领导者。2007   | 6ee9044ec244041b3a3e |                           |          |
# |                      |                   |                      | 年，谷歌推出了       | 839c26181775b45e4140 |                           |          |
# |                      |                   |                      | Android 操作系统，如 | 9bfdae0451c7f506eb94 |                           |          |
# |                      |                   |                      | 今已成为全球最流行的 | dc9598f67ab941f8144e |                           |          |
# |                      |                   |                      | 移动操作系统。近年来 | 80075e0c72671b482']  |                           |          |
# |                      |                   |                      | ，谷歌在人工智能领域 |                      |                           |          |
# |                      |                   |                      | 取得了显著进展，其开 |                      |                           |          |
# |                      |                   |                      | 发的 AlphaGo 在 2016 |                      |                           |          |
# |                      |                   |                      | 年击败了世界围棋冠军 |                      |                           |          |
# |                      |                   |                      | 李世石，展示了人工智 |                      |                           |          |
# |                      |                   |                      | 能的强大潜力。  微软 |                      |                           |          |
# |                      |                   |                      | ：从操作系统到云计算 |                      |                           |          |
# |                      |                   |                      | 微软（Microsoft）由  |                      |                           |          |
# |                      |                   |                      | 比尔·盖茨（Bill Gate |                      |                           |          |
# |                      |                   |                      | s）和保罗·艾伦（Paul |                      |                           |          |
# |                      |                   |                      | Allen）于 1975 年在  |                      |                           |          |
# |                      |                   |                      | 美国华盛顿州雷德蒙德 |                      |                           |          |
# |                      |                   |                      | 创立。微软最初以开发 |                      |                           |          |
# |                      |                   |                      | BASIC 解释器起家，但 |                      |                           |          |
# |                      |                   |                      | 真正使其成名的是     |                      |                           |          |
# |                      |                   |                      | 1981 年发布的 MS-DOS |                      |                           |          |
# |                      |                   |                      | 操作系统。1985       |                      |                           |          |
# |                      |                   |                      | 年，微软推出了       |                      |                           |          |
# |                      |                   |                      | Windows 操作系统，成 |                      |                           |          |
# |                      |                   |                      | 为个人电脑领域的霸主 |                      |                           |          |
# |                      |                   |                      | 。  进入 21 世纪后， |                      |                           |          |
# |                      |                   |                      | 微软逐渐将业务重心转 |                      |                           |          |
# |                      |                   |                      | 向云计算。2008       |                      |                           |          |
# |                      |                   |                      | 年，微软推出了 Azure |                      |                           |          |
# |                      |                   |                      | 云服务平台，如今已成 |                      |                           |          |
# |                      |                   |                      | 为全球第二大云计算服 |                      |                           |          |
# |                      |                   |                      | 务提供商。此外，微软 |                      |                           |          |
# |                      |                   |                      | 还通过收购 LinkedIn  |                      |                           |          |
# |                      |                   |                      | 和 GitHub 等平台，进 |                      |                           |          |
# |                      |                   |                      | 一步扩展了其在企业服 |                      |                           |          |
# |                      |                   |                      | 务和开发者社区中的影 |                      |                           |          |
# |                      |                   |                      | 响力。  亚马逊：从在 |                      |                           |          |
# |                      |                   |                      | 线书店到全球电商巨头 |                      |                           |          |
# |                      |                   |                      | 亚马逊（Amazon）由杰 |                      |                           |          |
# |                      |                   |                      | 夫·贝索斯（Jeff      |                      |                           |          |
# |                      |                   |                      | Bezos）于 1994 年在  |                      |                           |          |
# |                      |                   |                      | 美国华盛顿州西雅图创 |                      |                           |          |
# |                      |                   |                      | 立。最初，亚马逊是一 |                      |                           |          |
# |                      |                   |                      | 家在线书店，但很快扩 |                      |                           |          |
# |                      |                   |                      | 展为销售各类商品的电 |                      |                           |          |
# |                      |                   |                      | 商平台。1997 年，亚  |                      |                           |          |
# |                      |                   |                      | 马逊在纳斯达克上市， |                      |                           |          |
# |                      |                   |                      | 开启了其快速扩张的历 |                      |                           |          |
# |                      |                   |                      | 程。  2006           |                      |                           |          |
# |                      |                   |                      | 年，亚马逊推出了     |                      |                           |          |
# |                      |                   |                      | AWS（Amazon Web Serv |                      |                           |          |
# |                      |                   |                      | ices），这是全球首个 |                      |                           |          |
# |                      |                   |                      | 大规模商用的云计算平 |                      |                           |          |
# |                      |                   |                      | 台。如今，AWS 已成为 |                      |                           |          |
# |                      |                   |                      | 亚马逊最重要的利润来 |                      |                           |          |
# |                      |                   |                      | 源之一。此外，亚马逊 |                      |                           |          |
# |                      |                   |                      | 还通过收购 Whole     |                      |                           |          |
# |                      |                   |                      | Foods 和推出 Alexa   |                      |                           |          |
# |                      |                   |                      | 智能助手，进一步巩固 |                      |                           |          |
# |                      |                   |                      | 了其在零售和科技领域 |                      |                           |          |
# |                      |                   |                      | 的领先地位。  创新生 |                      |                           |          |
# |                      |                   |                      | 态系统的关键要素 硅  |                      |                           |          |
# |                      |                   |                      | 谷之所以能够成为全球 |                      |                           |          |
# |                      |                   |                      | 科技创新的中心，离不 |                      |                           |          |
# |                      |                   |                      | 开其独特的生态系统。 |                      |                           |          |
# |                      |                   |                      | 首先，硅谷拥有斯坦福 |                      |                           |          |
# |                      |                   |                      | 大学和加州大学伯克利 |                      |                           |          |
# |                      |                   |                      | 分校等世界顶尖高校， |                      |                           |          |
# |                      |                   |                      | 这些学校培养了大量的 |                      |                           |          |
# |                      |                   |                      | 技术人才。其次，硅谷 |                      |                           |          |
# |                      |                   |                      | 的风险投资行业非常发 |                      |                           |          |
# |                      |                   |                      | 达，为初创企业提供了 |                      |                           |          |
# |                      |                   |                      | 充足的资金支持。此外 |                      |                           |          |
# |                      |                   |                      | ，硅谷的文化鼓励创新 |                      |                           |          |
# |                      |                   |                      | 和冒险，许多创业者在 |                      |                           |          |
# |                      |                   |                      | 这里实现了从零到一的 |                      |                           |          |
# |                      |                   |                      | 突破。               |                      |                           |          |
# |                      |                   |                      | 科技巨头的竞争与合作 |                      |                           |          |
# |                      |                   |                      | 尽管苹果、谷歌、微软 |                      |                           |          |
# |                      |                   |                      | 和亚马逊在多个领域存 |                      |                           |          |
# |                      |                   |                      | 在竞争，但它们之间也 |                      |                           |          |
# |                      |                   |                      | 有广泛的合作。例如， |                      |                           |          |
# |                      |                   |                      | 谷歌的搜索服务是苹果 |                      |                           |          |
# |                      |                   |                      | Safari 浏览器的默认  |                      |                           |          |
# |                      |                   |                      | 搜索引擎，而微软的   |                      |                           |          |
# |                      |                   |                      | Office 软件也支持在  |                      |                           |          |
# |                      |                   |                      | 苹果和安卓设备上运行 |                      |                           |          |
# |                      |                   |                      | 。此外，这些公司还共 |                      |                           |          |
# |                      |                   |                      | 同参与了开源项目和技 |                      |                           |          |
# |                      |                   |                      | 术标准的制定，推动了 |                      |                           |          |
# |                      |                   |                      | 整个行业的发展。  未 |                      |                           |          |
# |                      |                   |                      | 来趋势：人工智能与量 |                      |                           |          |
# |                      |                   |                      | 子计算 展望未来，人  |                      |                           |          |
# |                      |                   |                      | 工智能和量子计算将成 |                      |                           |          |
# |                      |                   |                      | 为科技行业的下一个风 |                      |                           |          |
# |                      |                   |                      | 口。谷歌和微软已经在 |                      |                           |          |
# |                      |                   |                      | 量子计算领域投入了大 |                      |                           |          |
# |                      |                   |                      | 量资源，并取得了一些 |                      |                           |          |
# |                      |                   |                      | 突破性进展。与此同时 |                      |                           |          |
# |                      |                   |                      | ，苹果和亚马逊也在积 |                      |                           |          |
# |                      |                   |                      | 极布局人工智能，试图 |                      |                           |          |
# |                      |                   |                      | 通过智能设备和语音助 |                      |                           |          |
# |                      |                   |                      | 手进一步提升用户体验 |                      |                           |          |
# |                      |                   |                      | 。  总结 从苹果的    |                      |                           |          |
# |                      |                   |                      | iPhone 到谷歌的搜索  |                      |                           |          |
# |                      |                   |                      | 引擎，从微软的云计算 |                      |                           |          |
# |                      |                   |                      | 到亚马逊的电商平台， |                      |                           |          |
# |                      |                   |                      | 这些科技巨头不仅改变 |                      |                           |          |
# |                      |                   |                      | 了我们的生活方式，还 |                      |                           |          |
# |                      |                   |                      | 推动了全球经济的数字 |                      |                           |          |
# |                      |                   |                      | 化转型。未来，随着人 |                      |                           |          |
# |                      |                   |                      | 工智能和量子计算等新 |                      |                           |          |
# |                      |                   |                      | 兴技术的发展，科技行 |                      |                           |          |
# |                      |                   |                      | 业将继续引领创新潮流 |                      |                           |          |
# |                      |                   |                      | ，为人类社会带来更多 |                      |                           |          |
# |                      |                   |                      | 可能性。             |                      |                           |          |
# | 9b053fc85dd527526eb1 | 2                 | technology_companies | 在改革开放的浪潮中， | ['883cc91e297d6cbf5d | 2025-03-12 11:28:07 +0800 |          |
# | f7a7f3bcb90904bd0038 |                   | _zh.txt              | 中国科技行业实现了跨 | 4677352382732277daac |                           |          |
# | a05b07f35fb4f1d5b6b9 |                   |                      | 越式发展。以深圳、北 | e24594ffe6172ecbdd31 |                           |          |
# | 6c19dd3e87d023197ed2 |                   |                      | 京、杭州为核心的创新 | f7d27bdb47c3ca976a09 |                           |          |
# | 85c29406a2284f99a330 |                   |                      | 生态系统孕育了众多具 | 1a777941f4a8fb66ef88 |                           |          |
# | 101892dfaacc39988d2e |                   |                      | 有全球影响力的科技企 | d0810e6dc708b5f3b05f |                           |          |
# | 9aa62ad4             |                   |                      | 业，如华为、阿里巴巴 | e9b7d13e13'  '34a96c |                           |          |
# |                      |                   |                      | 、腾讯和字节跳动。这 | 09f5fd44e8b970ad9d0e |                           |          |
# |                      |                   |                      | 些企业不仅重塑了数字 | 4be759f3e4281e0bca6c |                           |          |
# |                      |                   |                      | 生活方式，更成为数字 | 41a72e868248e79652fc |                           |          |
# |                      |                   |                      | 经济新引擎。  华为： | c84ebd0226306581034e |                           |          |
# |                      |                   |                      | 从交换机到5G领军者   | 2a79cc6a424ad20c533e |                           |          |
# |                      |                   |                      | 华为技术有限公司由任 | 7a2373b3a330ab81c512 |                           |          |
# |                      |                   |                      | 正非于1987年在深圳创 | ef'  'ed91503e6018a2 |                           |          |
# |                      |                   |                      | 立。早期专注于电信设 | 98ebf9e251724dc1dac8 |                           |          |
# |                      |                   |                      | 备研发，1993年成功开 | edb4f5131e34db418df3 |                           |          |
# |                      |                   |                      | 发C&C08数字程控交换  | 0d0a4ff287364e748f88 |                           |          |
# |                      |                   |                      | 机。2013年推出首款5G | d1d2bddb515833b4de68 |                           |          |
# |                      |                   |                      | 原型机，2019年遭美国 | 496790b7244c5533fa66 |                           |          |
# |                      |                   |                      | 商务部列入实体清单事 | 3634594fd344c9'  '11 |                           |          |
# |                      |                   |                      | 件后，发布自研操作系 | 5274092015190a0c5f38 |                           |          |
# |                      |                   |                      | 统鸿蒙（HarmonyOS）  | b887dce5d094af773d03 |                           |          |
# |                      |                   |                      | 。2021年以28.7%的全  | db43339372050a36fc7f |                           |          |
# |                      |                   |                      | 球通信设备市场份额保 | de1ad1308fb2d5e18cbd |                           |          |
# |                      |                   |                      | 持行业第一。  阿里巴 | f8cd7e17469e5194f7b4 |                           |          |
# |                      |                   |                      | 巴：电商平台到数字经 | d8290213413255be7c3d |                           |          |
# |                      |                   |                      | 济体 阿里巴巴集团由  | c5e97a'  'ce107dd1f1 |                           |          |
# |                      |                   |                      | 马云等18人于1999年在 | c26ce2073fdb34877c6c |                           |          |
# |                      |                   |                      | 杭州创立。2003年推出 | a82fed3205d49df55738 |                           |          |
# |                      |                   |                      | 淘宝网，2009年首创双 | 513411bf0e423971a7a6 |                           |          |
# |                      |                   |                      | 十一购物节事件。2014 | e80396e4cba4ae8dca7a |                           |          |
# |                      |                   |                      | 年在纽约证券交易所上 | 8afb90ea6d9830f5d62a |                           |          |
# |                      |                   |                      | 市创全球最大IPO纪录  | 342c1d0de07766f3fe'  |                           |          |
# |                      |                   |                      | 。2017年成立达摩院聚 | '66f5659cfc38c69decf |                           |          |
# |                      |                   |                      | 焦人工智能研发，2021 | 267b2eba530d70042811 |                           |          |
# |                      |                   |                      | 年云计算业务跃居亚太 | d865ca30016893328e88 |                           |          |
# |                      |                   |                      | 市场首位。  腾讯：即 | 1b6196cf6bd2be2b9f7a |                           |          |
# |                      |                   |                      | 时通讯到生态构建者   | 7fa787e0ad1cbe85952a |                           |          |
# |                      |                   |                      | 深圳市腾讯计算机系统 | 03b20000a6d7f6f67ce7 |                           |          |
# |                      |                   |                      | 有限公司由马化腾等"  | 5f741ec2b']          |                           |          |
# |                      |                   |                      | 腾讯五虎"于1998年创  |                      |                           |          |
# |                      |                   |                      | 立。2004年在香港联交 |                      |                           |          |
# |                      |                   |                      | 所上市，2011年推出微 |                      |                           |          |
# |                      |                   |                      | 信（WeChat）引发移动 |                      |                           |          |
# |                      |                   |                      | 社交革命。2017年《王 |                      |                           |          |
# |                      |                   |                      | 者荣耀》成为全球营收 |                      |                           |          |
# |                      |                   |                      | 最高手游事件。通过投 |                      |                           |          |
# |                      |                   |                      | 资京东、美团等企业构 |                      |                           |          |
# |                      |                   |                      | 建庞大数字生态。  字 |                      |                           |          |
# |                      |                   |                      | 节跳动：算法驱动的内 |                      |                           |          |
# |                      |                   |                      | 容帝国 北京字节跳动  |                      |                           |          |
# |                      |                   |                      | 科技有限公司由张一鸣 |                      |                           |          |
# |                      |                   |                      | 于2012年创立。2016年 |                      |                           |          |
# |                      |                   |                      | 推出抖音（TikTok）引 |                      |                           |          |
# |                      |                   |                      | 发短视频热潮，2021年 |                      |                           |          |
# |                      |                   |                      | 月活用户突破10亿事件 |                      |                           |          |
# |                      |                   |                      | 。2020年通过收购中融 |                      |                           |          |
# |                      |                   |                      | 小贷获得金融牌照，20 |                      |                           |          |
# |                      |                   |                      | 23年推出大模型云雀（ |                      |                           |          |
# |                      |                   |                      | Lark）布局人工智能领 |                      |                           |          |
# |                      |                   |                      | 域。                 |                      |                           |          |
# |                      |                   |                      | 创新要素的中国特色   |                      |                           |          |
# |                      |                   |                      | 中关村科技园与粤港澳 |                      |                           |          |
# |                      |                   |                      | 大湾区的建设展现独特 |                      |                           |          |
# |                      |                   |                      | 优势：1）清华大学、  |                      |                           |          |
# |                      |                   |                      | 浙江大学等高校提供人 |                      |                           |          |
# |                      |                   |                      | 才储备；2）"双创"政  |                      |                           |          |
# |                      |                   |                      | 策催生孵化器模式；3  |                      |                           |          |
# |                      |                   |                      | ）科创板设立完善科技 |                      |                           |          |
# |                      |                   |                      | 企业融资通道。       |                      |                           |          |
# |                      |                   |                      | 跨界竞合新格局 虽然  |                      |                           |          |
# |                      |                   |                      | 华为与小米在智能手机 |                      |                           |          |
# |                      |                   |                      | 市场激烈竞争，但2021 |                      |                           |          |
# |                      |                   |                      | 年共同参与开放原子开 |                      |                           |          |
# |                      |                   |                      | 源基金会事件。阿里巴 |                      |                           |          |
# |                      |                   |                      | 巴的钉钉与腾讯会议在 |                      |                           |          |
# |                      |                   |                      | 协同办公领域角力，却 |                      |                           |          |
# |                      |                   |                      | 都在使用华为云基础设 |                      |                           |          |
# |                      |                   |                      | 施。                 |                      |                           |          |
# |                      |                   |                      | 未来赛道：AI与半导体 |                      |                           |          |
# |                      |                   |                      | 寒武纪的思元370芯片  |                      |                           |          |
# |                      |                   |                      | 与中芯国际的7nm工艺  |                      |                           |          |
# |                      |                   |                      | 突破显示国产化进程加 |                      |                           |          |
# |                      |                   |                      | 速。百度的"文心一言" |                      |                           |          |
# |                      |                   |                      | 大模型和商汤科技的Se |                      |                           |          |
# |                      |                   |                      | nseNova平台正在重塑A |                      |                           |          |
# |                      |                   |                      | I产业生态。          |                      |                           |          |
# +----------------------+-------------------+----------------------+----------------------+----------------------+---------------------------+----------+

# %% [markdown]
# &emsp;&emsp;其中各个字段的含义如下所示：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>Document DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个文档（即单个文件）。                           |
# | human_readable_id   | 字符串             | 可读的标识符，通常用于用户界面显示，便于用户理解和识别。   |
# | title               | 字符串             | 加载的文档其对应的文件名。                     |
# | text                | 字符串             | 通过文档解析器解析到的文档全部内容。                       |
# | text_unit_ids       | 列表（字符串）     | 关联的文本单元的唯一标识符列表，文本单元是将文档切分的块。 |
# | creation_date       | 日期时间           | 创建的日期和时间，以 UTC 或本地时间格式表示。 |
# | metadata            | 字典（可选）       | 额外的元数据，包含与文档相关的其他信息，如作者、来源、标签等。此字段可以为空。 |
#
# </div>

# %% [markdown]
# &emsp;&emsp;在知识图谱构建过程中，Document实体作为原始信息载体，其导入策略可以考虑以下原则：
#
# - **节点标识**：需要使用`id`字段作为Document节点的唯一标识符，确保图谱中的文档实体一致性。
# - **约束策略**：唯一性约束，确保文档的id是唯一的。
# - **属性选择**：比如标题，文本内容等（我们上节课讲解了如何自定义属性（即通过 file_partten 和 file_filter 来定义出更多的列）），但是注意：text_unit_ids 有必要添加属性吗？ 可以做，但是很低效，因为后面可以通过关系来连接，从而降低查询的复杂度。举个例子：
#     - 一个包含1000个文档，每个文档平均有50个文本单元的知识图谱：
#         - 使用关系：创建50,000个CONTAINS关系，每个关系指向一个TextUnit节点
#         - 使用属性：每个Document节点包含一个平均有50个ID的列表，需要在查询时进行列表处理
# - **标签策略**：基础标签，为所有文档添加`__Document__`标签。

# %% [markdown]
# &emsp;&emsp;因此，把上述的策略转化成代码。就如下所示：

# %%
# 创建Document节点
def create_document_nodes(df_documents):
    # 首先创建唯一性约束
    with driver.session(database=NEO4J_DATABASE) as session:
        try:
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (d:__Document__) REQUIRE d.id IS UNIQUE")
        except Exception as e:
            print(f"创建约束时出错 (可能已存在): {e}")
    
    # 导入文档
    # MERGE与ON CREATE SET组合，是一种条件性属性设置方式：特点是：
    # 1. 只在节点首次创建时设置属性
    # 2. 如果节点已存在，不会修改现有属性
    # 适合初始导入场景，避免覆盖已有数据
    cypher_statement = """
    MERGE (d:__Document__ {id: value.id})
    ON CREATE SET 
        d.human_readable_id = value.human_readable_id,
        d.title = value.title,
        d.text = value.text,
        d.creation_date = value.creation_date,
        d.import_timestamp = timestamp()
    """
    
    return parallel_batched_import(cypher_statement, df_documents)

# %% [markdown]
# &emsp;&emsp;接下来，连接到`Neo4j`数据库，并调用`create_document_nodes`函数，导入文档。代码如下：

# %%
NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"
NEO4J_DATABASE="neo4j"

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

# 执行 document.parquet 文件的导入
create_document_nodes(df_documents)
# Out:
# 开始并行导入 2 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 2 行, 耗时 1.81秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 2 行, 成功 2 行, 失败 0 行
# 总耗时: 1.90秒, 平均速度: 1.05 行/秒
# {'total_rows': 2,
#  'successful_rows': 2,
#  'failed_rows': 0,
#  'duration_seconds': 1.898055076599121,
#  'rows_per_second': 1.0537102029639418,
#  'batch_results': [{'batch': 0,
#    'rows': 2,
#    'success': True,
#    'duration': 1.8076467514038086,
#    'counters': {'_contains_updates': True, 'labels_added': 2, 'nodes_created': 2, 'properties_set': 12}}]}

# %% [markdown]
# &emsp;&emsp;看到创建完成后，在`localhost:7474`的`Neo4j`浏览器中，可以看到`__Document__`标签的节点已经创建完成。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121817980.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们已经完成了`documents.parquet`文件的导入。接下来执行`text_units.parquet`文件的导入。

# %% [markdown]
# ## 4.3 导入文本单元

# %% [markdown]
# &emsp;&emsp;`text_units.parquet`文件中主要存储的是内容是根据`settings.yaml`文件中定义的切分策略，将`documents.parquet`文件中的内容切分出来的文本单元。同时会通过后处理，关联到经过实体和关系提取`Workflow`后的实体和关系。读取该文件的代码如下所示：

# %%
from tabulate import tabulate

df_text_units = pd.read_parquet('text_units.parquet')  # 替换为实际路径
# 假设 df 是你的 DataFrame
print(tabulate(df_text_units, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+----------------------+----------+----------------------+------------------------------------------+------------------------------------------+---------------+
# | id                   | human_readable_id | text                 | n_tokens | document_ids         | entity_ids                               | relationship_ids                         | covariate_ids |
# +----------------------+-------------------+----------------------+----------+----------------------+------------------------------------------+------------------------------------------+---------------+
# | 8f298209e463b21ab725 | 1                 | 在过去的几十年中，全 | 300      | ['66bf9f67042bef537f | ['4b2d9bf3-01d4-435c-9de5-8eb8744ffc11'  | ['09d7a448-7d00-47b8-b9b6-471cc6c29c55'  | []            |
# | bc5347cdeb4a33454e3d |                   | 球科技行业经历了翻天 |          | f7c55ae62fa9471ea3e5 |  '0e4861f4-29ec-4ddd-bf7d-a055a00e75a4'  |  'bbbdb1fe-5c09-4dfd-97c9-faf3924e7678'  |               |
# | 1cea78efdf96c3f5a26f |                   | 覆地的变化。以硅谷为 |          | 6ee868278e00d44302d9 |  '2b44a251-58fc-48e0-bdcd-4fc9173adb3c'  |  'bfe79d79-b3f1-40a4-a91b-a926e3d7a0e7'  |               |
# | 19fd5477e4bc11589755 |                   | 中心的创新生态系统催 |          | adfb80dd0d8e0a226f05 |  '1d238b98-0667-4c09-8b39-831a9d63e2c7'  |  '3bdfb17e-16de-48f0-b2ba-737fad5fd12b'  |               |
# | e6e95b20dcb02bf29398 |                   | 生了许多世界知名的科 |          | 5076e16c9c0a2f428cb9 |  'a1970ae2-2174-464c-8e6a-a69038276d4c'  |  'f44ec3d3-f4e3-4278-b887-55c03c0af3fd'  |               |
# | 715b473987f03271f5a6 |                   | 技公司，如苹果、谷歌 |          | 67443c406533e1715415 |  '758325f0-6a01-487e-82e4-3fe8dc7dd3f9'  |  '7b66e3bc-1923-4995-882b-2565cd44654b'  |               |
# | cb030d2b             |                   | 、微软和亚马逊。这些 |          | 3a027ad2aa']         |  'b50512b1-2314-4da1-88b4-7e8d6edc5364'  |  '2da622b4-44f0-4c66-b0c6-dfb88d31d9e2'  |               |
# |                      |                   | 公司不仅改变了人们的 |          |                      |  'e46d6ac5-135f-41d5-b7db-a020eb6ccf67'  |  '8f3f2643-27ab-4ece-bae4-35fa36c47450'  |               |
# |                      |                   | 生活方式，还推动了全 |          |                      |  'c4892971-46e1-4a9f-8256-8414d812612d'  |  '7426d0b5-8e54-4875-b07c-092586f6bcea'  |               |
# |                      |                   | 球经济的发展。  苹果 |          |                      |  '6d5bce0c-e166-460f-a432-879f253d4eda'  |  '4c35d813-36ba-4823-9cde-c11c65b60d71'  |               |
# |                      |                   | 公司：从车库到万亿美 |          |                      |  'f368d1b9-3236-4167-85f8-c5501e58d2ac'  |  'b654f769-e0a8-440e-aef3-0818fea43f5a'  |               |
# |                      |                   | 元市值               |          |                      |  '19aa98c5-8378-4a3e-ba84-3517a8517152'] |  'eed51419-f167-4105-999b-72c083f5d22f'] |               |
# |                      |                   | 苹果公司（Apple Inc. |          |                      |                                          |                                          |               |
# |                      |                   | ）由史蒂夫·乔布斯（S |          |                      |                                          |                                          |               |
# |                      |                   | teve Jobs）、史蒂夫· |          |                      |                                          |                                          |               |
# |                      |                   | 沃兹尼亚克（Steve Wo |          |                      |                                          |                                          |               |
# |                      |                   | zniak）和罗恩·韦恩（ |          |                      |                                          |                                          |               |
# |                      |                   | Ron Wayne）于 1976   |          |                      |                                          |                                          |               |
# |                      |                   | 年在美国加利福尼亚州 |          |                      |                                          |                                          |               |
# |                      |                   | 库比蒂诺的一个车库中 |          |                      |                                          |                                          |               |
# |                      |                   | 创立。最初，苹果公司 |          |                      |                                          |                                          |               |
# |                      |                   | 专注于个人电脑的开发 |          |                      |                                          |                                          |               |
# |                      |                   | ，其第一款产品 Apple |          |                      |                                          |                                          |               |
# |                      |                   | I 在 1976            |          |                      |                                          |                                          |               |
# |                      |                   | 年发布。1984         |          |                      |                                          |                                          |               |
# |                      |                   | 年，苹果推出了       |          |                      |                                          |                                          |               |
# |                      |                   | Macintosh 电脑，这是 |          |                      |                                          |                                          |               |
# |                      |                   | 第一款成功商用化的图 |          |                      |                                          |                                          |               |
# |                      |                   | 形用户界面电�        |          |                      |                                          |                                          |               |
# | b0c0fdb9714ba7fb74bb | 2                 | 在美国加利福尼亚州库 | 300      | ['66bf9f67042bef537f | ['0e4861f4-29ec-4ddd-bf7d-a055a00e75a4'  | ['c97d7e94-d8aa-4c46-befd-ad2704ffc056'  | []            |
# | 0e162bfb90ec6bab1d50 |                   | 比蒂诺的一个车库中创 |          | f7c55ae62fa9471ea3e5 |  'a1970ae2-2174-464c-8e6a-a69038276d4c'  |  '48d8bc4b-09c2-410b-bb3f-63435a0fa52e'  |               |
# | 45057678d0d91b9d5f72 |                   | 立。最初，苹果公司专 |          | 6ee868278e00d44302d9 |  'e46d6ac5-135f-41d5-b7db-a020eb6ccf67'  |  'cffabb9c-7278-4942-9726-9ba78e19160e'  |               |
# | 936ae344577359ab5418 |                   | 注于个人电脑的开发， |          | adfb80dd0d8e0a226f05 |  'e1bf420e-8d58-4f6f-ad67-4b6d36587e53'  |  'b45e85e5-85e0-41da-8a14-c2a59fadf6e7'  |               |
# | f104f235cdef72f703ea |                   | 其第一款产品 Apple I |          | 5076e16c9c0a2f428cb9 |  'c90a88ac-e1ae-4cb4-be79-adce4f21fa6b'  |  'd9aca59f-9c0c-4f25-a483-41e864d5bd9e'  |               |
# | 06aa4b96976c1dfab32e |                   | 在 1976 年发布。1984 |          | 67443c406533e1715415 |  '3646a409-05c8-43c1-8ae6-fdfbc2af796d'  |  'efaf3a05-b112-4cd7-9680-23ce2986b6a7'  |               |
# | f0000c00             |                   | 年，苹果推出了       |          | 3a027ad2aa']         |  'f1d9e0cd-64d1-41c2-a03b-14aa8ce1730c'  |  '5b03f5d1-9923-4af4-ab85-f1960dddc966'  |               |
# |                      |                   | Macintosh 电脑，这是 |          |                      |  'bc99b765-aaf4-45ea-9dc6-257093d1ff61'  |  '7ee3517c-4f5e-43e9-9f57-bf4b54a325c3'  |               |
# |                      |                   | 第一款成功商用化的图 |          |                      |  '46b5a6ed-2d99-478a-b088-5cc746943c58'  |  'ecaa7159-de2e-4ffc-a465-9a690e68c7d9'  |               |
# |                      |                   | 形用户界面电脑，彻底 |          |                      |  'a54c2467-c3fd-44df-a8a1-8833a488e180'] |  'f58a7cd9-ede4-4e98-beec-ec0760febd40'  |               |
# |                      |                   | 改变了人机交互的方式 |          |                      |                                          |  '0a05778f-979f-40af-ab60-6f88253993e6'  |               |
# |                      |                   | 。  乔布斯在 1985    |          |                      |                                          |  'a3ec056a-7619-46bc-9866-3dff737009f5'  |               |
# |                      |                   | 年离开苹果，但在     |          |                      |                                          |  '816ab210-aea3-433e-854c-a6efc3e139f1'  |               |
# |                      |                   | 1997 年回归，并带领  |          |                      |                                          |  '04451dca-feca-4190-b212-e9f72aed3cf7'] |               |
# |                      |                   | 公司推出了           |          |                      |                                          |                                          |               |
# |                      |                   | iMac、iPod、iPhone   |          |                      |                                          |                                          |               |
# |                      |                   | 和 iPad 等一系列革命 |          |                      |                                          |                                          |               |
# |                      |                   | 性产品。2007         |          |                      |                                          |                                          |               |
# |                      |                   | 年，iPhone 的发布标  |          |                      |                                          |                                          |               |
# |                      |                   | 志着智能手机时代的开 |          |                      |                                          |                                          |               |
# |                      |                   | 始，苹果也因此成为全 |          |                      |                                          |                                          |               |
# |                      |                   | 球最有价值的公司之一 |          |                      |                                          |                                          |               |
# |                      |                   | 。截至 2023          |          |                      |                                          |                                          |               |
# |                      |                   | 年，苹果的市值已超过 |          |                      |                                          |                                          |               |
# |                      |                   | 2 万亿美元。  谷歌： |          |                      |                                          |                                          |               |
# |                      |                   | 从搜索引擎到人工智能 |          |                      |                                          |                                          |               |
# |                      |                   | 巨头 谷歌（Google）  |          |                      |                                          |                                          |               |
# |                      |                   | 由拉里·佩奇（Larry P |          |                      |                                          |                                          |               |
# |                      |                   | age）和谢尔盖·布林（ |          |                      |                                          |                                          |               |
# |                      |                   | Sergey Brin）于      |          |                      |                                          |                                          |               |
# | f3f52dc49c93ea0a43c6 | 3                 | 因此成为全球最有价值 | 300      | ['66bf9f67042bef537f | ['e1bf420e-8d58-4f6f-ad67-4b6d36587e53'  | ['816ab210-aea3-433e-854c-a6efc3e139f1'  | []            |
# | c483269624ed6227b53c |                   | 的公司之一。截至     |          | f7c55ae62fa9471ea3e5 |  '3646a409-05c8-43c1-8ae6-fdfbc2af796d'  |  '04451dca-feca-4190-b212-e9f72aed3cf7'  |               |
# | 15bf39a1fd8102227d44 |                   | 2023                 |          | 6ee868278e00d44302d9 |  'f1d9e0cd-64d1-41c2-a03b-14aa8ce1730c'  |  '78aced59-d1bc-4da2-9b5b-934d9e0fac60'  |               |
# | 332fad53503232eff124 |                   | 年，苹果的市值已超过 |          | adfb80dd0d8e0a226f05 |  'b3177da6-ac72-4c1f-8a43-b287d1be5b68'  |  'a50981c3-a09c-41df-8bbb-4570ed98ccb4'  |               |
# | 94290e40dfdb114c8c1d |                   | 2 万亿美元。  谷歌： |          | 5076e16c9c0a2f428cb9 |  '606558ee-36d4-4626-9c42-7342dc8b1dc7'  |  '48435746-58cb-46e9-a130-586db4ef4ac3'  |               |
# | f2db601a555fec297639 |                   | 从搜索引擎到人工智能 |          | 67443c406533e1715415 |  '42c8cae8-0e5c-4430-b859-595eb4ec584e'  |  '0955e0aa-9a69-4147-8a5a-ff003e746a8f'] |               |
# | ec3d7a6a             |                   | 巨头 谷歌（Google）  |          | 3a027ad2aa']         |  '51633ffb-8c01-4e96-be3a-13db4061e788'] |                                          |               |
# |                      |                   | 由拉里·佩奇（Larry P |          |                      |                                          |                                          |               |
# |                      |                   | age）和谢尔盖·布林（ |          |                      |                                          |                                          |               |
# |                      |                   | Sergey Brin）于 1998 |          |                      |                                          |                                          |               |
# |                      |                   | 年在加利福尼亚州门洛 |          |                      |                                          |                                          |               |
# |                      |                   | 帕克创立。最初，谷歌 |          |                      |                                          |                                          |               |
# |                      |                   | 是一个搜索引擎，但其 |          |                      |                                          |                                          |               |
# |                      |                   | 技术迅速超越了竞争对 |          |                      |                                          |                                          |               |
# |                      |                   | 手，成为全球最受欢迎 |          |                      |                                          |                                          |               |
# |                      |                   | 的搜索工具。2004 年  |          |                      |                                          |                                          |               |
# |                      |                   | ，谷歌在纳斯达克上市 |          |                      |                                          |                                          |               |
# |                      |                   | ，募集资金超过 16    |          |                      |                                          |                                          |               |
# |                      |                   | 亿美元。  谷歌的创新 |          |                      |                                          |                                          |               |
# |                      |                   | 能力不仅限于搜索。20 |          |                      |                                          |                                          |               |
# |                      |                   | 06 年，谷歌收购了 Yo |          |                      |                                          |                                          |               |
# |                      |                   | uTube，成为在线视频  |          |                      |                                          |                                          |               |
# |                      |                   | 领域的领导者。2007   |          |                      |                                          |                                          |               |
# |                      |                   | 年，谷歌推出了       |          |                      |                                          |                                          |               |
# |                      |                   | Android 操作系统，如 |          |                      |                                          |                                          |               |
# |                      |                   | 今已成为全球最流行的 |          |                      |                                          |                                          |               |
# |                      |                   | 移动操作系统。近年来 |          |                      |                                          |                                          |               |
# |                      |                   | ，谷歌在人工智       |          |                      |                                          |                                          |               |
# | 286421f13c7d50f5e46e | 4                 | 超过 16 亿美元。  谷 | 300      | ['66bf9f67042bef537f | ['606558ee-36d4-4626-9c42-7342dc8b1dc7'  | ['78e40a5d-9796-4a3b-9589-6b170ef4ccf7'  | []            |
# | ab4c8500bb778a63ef0b |                   | 歌的创新能力不仅限于 |          | f7c55ae62fa9471ea3e5 |  '42c8cae8-0e5c-4430-b859-595eb4ec584e'  |  '7dc834ae-a064-431b-843b-77d5deda96c1'  |               |
# | 115a0125f5b60eac4eb2 |                   | 搜索。2006           |          | 6ee868278e00d44302d9 |  '50b90370-f4b6-4a3f-a900-363c4c16de17'  |  '3700ad70-3f89-48c9-ba47-041654d378d2'  |               |
# | bfe6b394e8d2dd120622 |                   | 年，谷歌收购了 YouTu |          | adfb80dd0d8e0a226f05 |  'c4bf1c25-cdd2-4f05-b858-b485717fefa7'  |  '7aa559c4-6d37-45a8-b7de-d39a76ce4ff9'  |               |
# | 454cee42514379d1e1db |                   | be，成为在线视频领域 |          | 5076e16c9c0a2f428cb9 |  'e1454e36-6ef9-44b7-b642-0093038b32d5'  |  'a95ab5d3-0627-4b21-aab3-d37cb154873a'  |               |
# | c1664fb018d4ad109f91 |                   | 的领导者。2007       |          | 67443c406533e1715415 |  '85bf01f7-c57b-40d4-be01-5665a2d20470'  |  'f4e0d9af-5a23-4e51-9e73-1e0d22cf05e6'  |               |
# | 8bdea5bf             |                   | 年，谷歌推出了       |          | 3a027ad2aa']         |  'e5255339-1528-44e2-add5-3f21316d5ccf'  |  '37f03eb1-7a1f-4461-8282-2d586c56fb4c'  |               |
# |                      |                   | Android 操作系统，如 |          |                      |  '0e220816-9615-45a2-a7a3-563014c07af7'  |  '7e1428dc-4758-41e2-9f8f-6732a35b3b54'  |               |
# |                      |                   | 今已成为全球最流行的 |          |                      |  'a75e5d6d-485d-43b5-a3cd-6d4cfd872342'  |  '1f3c29b7-70c4-4354-a630-66581b98f6e2'  |               |
# |                      |                   | 移动操作系统。近年来 |          |                      |  '9f736e48-1338-4b4c-aafb-327d6b30fd86'  |  '612fcffc-84a6-4351-aadb-735cfb6c2a5b'] |               |
# |                      |                   | ，谷歌在人工智能领域 |          |                      |  '2c6ffa99-fffb-488f-b050-71deab7c150d'] |                                          |               |
# |                      |                   | 取得了显著进展，其开 |          |                      |                                          |                                          |               |
# |                      |                   | 发的 AlphaGo 在 2016 |          |                      |                                          |                                          |               |
# |                      |                   | 年击败了世界围棋冠军 |          |                      |                                          |                                          |               |
# |                      |                   | 李世石，展示了人工智 |          |                      |                                          |                                          |               |
# |                      |                   | 能的强大潜力。  微软 |          |                      |                                          |                                          |               |
# |                      |                   | ：从操作系统到云计算 |          |                      |                                          |                                          |               |
# |                      |                   | 微软（Microsoft）由  |          |                      |                                          |                                          |               |
# |                      |                   | 比尔·盖茨（Bill Gate |          |                      |                                          |                                          |               |
# |                      |                   | s）和保罗·艾伦（Paul |          |                      |                                          |                                          |               |
# |                      |                   | Allen）于 1975 年在  |          |                      |                                          |                                          |               |
# |                      |                   | 美国华盛顿州雷德蒙德 |          |                      |                                          |                                          |               |
# |                      |                   | 创立。微软最初以开发 |          |                      |                                          |                                          |               |
# |                      |                   | BASIC 解释器起家，但 |          |                      |                                          |                                          |               |
# |                      |                   | 真正使其成名的是     |          |                      |                                          |                                          |               |
# |                      |                   | 1981 年发布的 MS-DOS |          |                      |                                          |                                          |               |
# |                      |                   | 操作系统。1985       |          |                      |                                          |                                          |               |
# |                      |                   | 年，微软推出了       |          |                      |                                          |                                          |               |
# |                      |                   | Windows 操作系统，成 |          |                      |                                          |                                          |               |
# |                      |                   | 为个人电脑领域的     |          |                      |                                          |                                          |               |
# | c74ed55a3ebcbc0bb18a | 5                 | 艾伦（Paul Allen）于 | 300      | ['66bf9f67042bef537f | ['c4892971-46e1-4a9f-8256-8414d812612d'  | ['e2d5aa30-4467-4025-929c-622a6a603e72'  | []            |
# | 6e60a119aab7efcf8036 |                   | 1975 年在美国华盛顿  |          | f7c55ae62fa9471ea3e5 |  '6d5bce0c-e166-460f-a432-879f253d4eda'  |  '70a6dc3c-3ea6-452c-8566-d7d488d580be'  |               |
# | 4e115f5ce4157b1ac1a2 |                   | 州雷德蒙德创立。微软 |          | 6ee868278e00d44302d9 |  'a5ef70b5-84e9-4cb8-b647-eedd9d69b279'  |  '61e119fe-4ca9-4150-9cce-c7584471980a'  |               |
# | aef7ac4d9f0b13ab35a0 |                   | 最初以开发 BASIC 解  |          | adfb80dd0d8e0a226f05 |  'fbdceca3-e4ef-41df-bb34-e69434ad7eac'  |  '3bf4a124-60d4-45e1-a63e-f7bb9b9551a9'  |               |
# | 2fdc3814716c37007baa |                   | 释器起家，但真正使其 |          | 5076e16c9c0a2f428cb9 |  'fb0ba0b2-b5fe-4a4d-a0d2-fdf0d2518c08'  |  '43e99a4d-ec4d-40ca-a828-21522bc90207'  |               |
# | be0eeb612481ae10ef89 |                   | 成名的是 1981        |          | 67443c406533e1715415 |  '249fccf6-e79a-43c8-b2b5-6ca1f6a3c2c1'  |  'e272da89-8c80-4c59-a7df-61469c5450a3'  |               |
# | fdc45015             |                   | 年发布的 MS-DOS      |          | 3a027ad2aa']         |  '9a3c82d8-152a-438b-b3fa-0980dbcdaa53'  |  '28334e1f-9b88-41b8-b549-ec6775c4db2c'  |               |
# |                      |                   | 操作系统。1985       |          |                      |  'd1410226-961c-4fdd-8d76-e66aac46becb'  |  '7d06b858-4ce9-4765-a818-fee31c128d96'  |               |
# |                      |                   | 年，微软推出了       |          |                      |  'd6d7881f-e57c-4f34-8f2b-ac6b1250a9a9'  |  '2f1666d9-f6b9-44fc-b64e-59f939b62027'  |               |
# |                      |                   | Windows 操作系统，成 |          |                      |  'af9a14ed-b907-4097-826e-fe106502d627'  |  '480a1038-c5a7-4df3-aea5-fba2f2e85953'  |               |
# |                      |                   | 为个人电脑领域的霸主 |          |                      |  'ea3bb2b4-cb0a-43f9-9fc0-9ea11ae8d727'  |  '3a6b6371-0afb-4ec2-9729-67f54ec18454'  |               |
# |                      |                   | 。  进入 21 世纪后， |          |                      |  'bfc9aac3-999b-49cb-b81e-6339836368d4'  |  '7f8dbd71-f326-4f25-812b-29466e517ece'] |               |
# |                      |                   | 微软逐渐将业务重心转 |          |                      |  'd2d860ef-f321-48e2-ac23-02cf5d15d48c'] |                                          |               |
# |                      |                   | 向云计算。2008       |          |                      |                                          |                                          |               |
# |                      |                   | 年，微软推出了 Azure |          |                      |                                          |                                          |               |
# |                      |                   | 云服务平台，如今已成 |          |                      |                                          |                                          |               |
# |                      |                   | 为全球第二大云计算服 |          |                      |                                          |                                          |               |
# |                      |                   | 务提供商。此外，微软 |          |                      |                                          |                                          |               |
# |                      |                   | 还通过收购 LinkedIn  |          |                      |                                          |                                          |               |
# |                      |                   | 和 GitHub 等平台，进 |          |                      |                                          |                                          |               |
# |                      |                   | 一步扩展了其在企业服 |          |                      |                                          |                                          |               |
# |                      |                   | 务和开发者社区中的影 |          |                      |                                          |                                          |               |
# |                      |                   | 响力。  亚马逊：从在 |          |                      |                                          |                                          |               |
# |                      |                   | 线书店到全球电商巨头 |          |                      |                                          |                                          |               |
# |                      |                   | 亚马逊（Amazon）由杰 |          |                      |                                          |                                          |               |
# |                      |                   | 夫·贝索斯（Jeff      |          |                      |                                          |                                          |               |
# |                      |                   | Bezos）于 1994 年在  |          |                      |                                          |                                          |               |
# |                      |                   | 美国华盛顿州西雅图创 |          |                      |                                          |                                          |               |
# |                      |                   | 立。最初，亚马逊是一 |          |                      |                                          |                                          |               |
# |                      |                   | 家在线书店，但很�    |          |                      |                                          |                                          |               |
# | 01434455979f8f5369ea | 6                 | 和开发者社区中的影响 | 300      | ['66bf9f67042bef537f | ['6d5bce0c-e166-460f-a432-879f253d4eda'  | ['480a1038-c5a7-4df3-aea5-fba2f2e85953'  | []            |
# | 62fdc2ff4ff136067729 |                   | 力。  亚马逊：从在线 |          | f7c55ae62fa9471ea3e5 |  '51633ffb-8c01-4e96-be3a-13db4061e788'  |  '3a6b6371-0afb-4ec2-9729-67f54ec18454'  |               |
# | 3c575d32f1672521daae |                   | 书店到全球电商巨头   |          | 6ee868278e00d44302d9 |  'fb0ba0b2-b5fe-4a4d-a0d2-fdf0d2518c08'  |  '04c29a25-0ac7-4ef9-bf41-df1011c2a975'  |               |
# | e69a7f111448645d4c70 |                   | 亚马逊（Amazon）由杰 |          | adfb80dd0d8e0a226f05 |  'd6d7881f-e57c-4f34-8f2b-ac6b1250a9a9'  |  '4319e729-a0eb-4580-9ec0-73a2fe104afd'  |               |
# | 464db9dbbbe3d009c423 |                   | 夫·贝索斯（Jeff      |          | 5076e16c9c0a2f428cb9 |  'af9a14ed-b907-4097-826e-fe106502d627'  |  'ea35dc50-a02c-440e-9e9a-91184a4032f4'  |               |
# | 36fd2801161e3418c607 |                   | Bezos）于 1994 年在  |          | 67443c406533e1715415 |  'd7b3cafa-352a-464e-aa67-a58cc0cce3a2'  |  '7ca46970-b1a2-4592-98ac-17a28c3e8141'  |               |
# | aa4efc1d             |                   | 美国华盛顿州西雅图创 |          | 3a027ad2aa']         |  '0d6ad177-3e6a-4cc5-bf6c-0c0e1a4683c7'  |  '73722b4e-35a3-48c1-9874-2e38c87e322b'  |               |
# |                      |                   | 立。最初，亚马逊是一 |          |                      |  '9054b1d2-40a3-4aab-9c0f-249edecf17dc'] |  'ecd94b0e-6e93-4a76-a9a5-c9638863c4c4'] |               |
# |                      |                   | 家在线书店，但很快扩 |          |                      |                                          |                                          |               |
# |                      |                   | 展为销售各类商品的电 |          |                      |                                          |                                          |               |
# |                      |                   | 商平台。1997 年，亚  |          |                      |                                          |                                          |               |
# |                      |                   | 马逊在纳斯达克上市， |          |                      |                                          |                                          |               |
# |                      |                   | 开启了其快速扩张的历 |          |                      |                                          |                                          |               |
# |                      |                   | 程。  2006           |          |                      |                                          |                                          |               |
# |                      |                   | 年，亚马逊推出了     |          |                      |                                          |                                          |               |
# |                      |                   | AWS（Amazon Web Serv |          |                      |                                          |                                          |               |
# |                      |                   | ices），这是全球首个 |          |                      |                                          |                                          |               |
# |                      |                   | 大规模商用的云计算平 |          |                      |                                          |                                          |               |
# |                      |                   | 台。如今，AWS 已成为 |          |                      |                                          |                                          |               |
# |                      |                   | 亚马逊最重要的利润来 |          |                      |                                          |                                          |               |
# |                      |                   | 源之一。此外，亚马逊 |          |                      |                                          |                                          |               |
# |                      |                   | 还通过收购 Whole     |          |                      |                                          |                                          |               |
# |                      |                   | Foods 和推出 Alexa   |          |                      |                                          |                                          |               |
# |                      |                   | 智能助手，进一步巩固 |          |                      |                                          |                                          |               |
# |                      |                   | 了其在零售和科技领域 |          |                      |                                          |                                          |               |
# |                      |                   | 的领先地位。  创新生 |          |                      |                                          |                                          |               |
# |                      |                   | 态系统的关键要素 硅  |          |                      |                                          |                                          |               |
# |                      |                   | 谷之所以能够成为全球 |          |                      |                                          |                                          |               |
# |                      |                   | 科                   |          |                      |                                          |                                          |               |
# | c4c5297b4bf585666851 | 7                 | 为亚马逊最重要的利润 | 300      | ['66bf9f67042bef537f | ['758325f0-6a01-487e-82e4-3fe8dc7dd3f9'  | ['ea35dc50-a02c-440e-9e9a-91184a4032f4'  | []            |
# | d3e50123a6e5dd9a6223 |                   | 来源之一。此外，亚马 |          | f7c55ae62fa9471ea3e5 |  '6d5bce0c-e166-460f-a432-879f253d4eda'  |  '7ca46970-b1a2-4592-98ac-17a28c3e8141'  |               |
# | b14675624752a2a3033b |                   | 逊还通过收购 Whole   |          | 6ee868278e00d44302d9 |  'e1bf420e-8d58-4f6f-ad67-4b6d36587e53'  |  '4de5bed7-b933-47fc-bddc-e325df3fad6a'  |               |
# | a6629af55fb798a18a2d |                   | Foods 和推出 Alexa   |          | adfb80dd0d8e0a226f05 |  '0d6ad177-3e6a-4cc5-bf6c-0c0e1a4683c7'  |  '6ac1c842-fdfc-4edf-bc8e-8047520d4751'  |               |
# | 6ecbb974baddbfb2eace |                   | 智能助手，进一步巩固 |          | 5076e16c9c0a2f428cb9 |  '9054b1d2-40a3-4aab-9c0f-249edecf17dc'  |  'b9e1a97c-8cc7-4e01-94ea-939e02723d48'] |               |
# | 4d6468971449b35c10fa |                   | 了其在零售和科技领域 |          | 67443c406533e1715415 |  '8b0e3553-021a-4e25-9458-77f5ebe2a61f'  |                                          |               |
# | 5c1cc2cc             |                   | 的领先地位。  创新生 |          | 3a027ad2aa']         |  '8384bbeb-0e91-4624-9ce1-fac0cfe9b59b'] |                                          |               |
# |                      |                   | 态系统的关键要素 硅  |          |                      |                                          |                                          |               |
# |                      |                   | 谷之所以能够成为全球 |          |                      |                                          |                                          |               |
# |                      |                   | 科技创新的中心，离不 |          |                      |                                          |                                          |               |
# |                      |                   | 开其独特的生态系统。 |          |                      |                                          |                                          |               |
# |                      |                   | 首先，硅谷拥有斯坦福 |          |                      |                                          |                                          |               |
# |                      |                   | 大学和加州大学伯克利 |          |                      |                                          |                                          |               |
# |                      |                   | 分校等世界顶尖高校， |          |                      |                                          |                                          |               |
# |                      |                   | 这些学校培养了大量的 |          |                      |                                          |                                          |               |
# |                      |                   | 技术人才。其次，硅谷 |          |                      |                                          |                                          |               |
# |                      |                   | 的风险投资行业非常发 |          |                      |                                          |                                          |               |
# |                      |                   | 达，为初创企业提供了 |          |                      |                                          |                                          |               |
# |                      |                   | 充足的资金支持。此外 |          |                      |                                          |                                          |               |
# |                      |                   | ，硅谷的文化鼓励创新 |          |                      |                                          |                                          |               |
# |                      |                   | 和冒险，许多创业者在 |          |                      |                                          |                                          |               |
# |                      |                   | 这里实现了从零到一的 |          |                      |                                          |                                          |               |
# |                      |                   | 突破。               |          |                      |                                          |                                          |               |
# |                      |                   | 科技巨头的竞争与合作 |          |                      |                                          |                                          |               |
# |                      |                   | 尽管苹果、谷歌、     |          |                      |                                          |                                          |               |
# | ff294773b34288543640 | 8                 | 业非常发达，为初创企 | 300      | ['66bf9f67042bef537f | ['50b90370-f4b6-4a3f-a900-363c4c16de17'  | ['5fd25732-3f80-44ce-8278-fe658530b98b'  | []            |
# | 49d61157058e7f9de1a2 |                   | 业提供了充足的资金支 |          | f7c55ae62fa9471ea3e5 |  'e1454e36-6ef9-44b7-b642-0093038b32d5'  |  'e177d523-6b20-4749-b919-8143afa0bec4'  |               |
# | 26375609c8b313aebd02 |                   | 持。此外，硅谷的文化 |          | 6ee868278e00d44302d9 |  '80a1b932-03ae-43a0-9bd7-37b6d74f36da'  |  '6ac3a0c9-ce4a-4dd6-8554-d77d7c0cda89'  |               |
# | b85757c543588bfd9af6 |                   | 鼓励创新和冒险，许多 |          | adfb80dd0d8e0a226f05 |  '9bf6c182-c48d-4bf4-9717-d64909a75391'  |  '2bb987ec-fbcd-4aac-8855-27558bf04620'  |               |
# | a9fe5ce8b934d3f05568 |                   | 创业者在这里实现了从 |          | 5076e16c9c0a2f428cb9 |  '2d9bfc43-247c-447f-9463-c85496ddbf1d'  |  '0fc6de0c-900b-44e0-b295-e3d571ce83ec'  |               |
# | b9d546deea0526c032d0 |                   | 零到一的突破。       |          | 67443c406533e1715415 |  '93762fdf-903f-442e-827b-947c8b9977e1'  |  '0b5c0a92-c7d0-435a-9a3a-6c09bd48a2b6'  |               |
# | 61a7a1cd             |                   | 科技巨头的竞争与合作 |          | 3a027ad2aa']         |  '59b9f9dc-37ed-424e-bab0-b65edac21a41'] |  '1de38f78-d72e-4d51-9400-8cd7182f0cb2'  |               |
# |                      |                   | 尽管苹果、谷歌、微软 |          |                      |                                          |  '1deaf657-0a91-4fcc-8622-1577f5483686'  |               |
# |                      |                   | 和亚马逊在多个领域存 |          |                      |                                          |  '8af7bc93-83d7-45c9-8d16-e2040410119b'] |               |
# |                      |                   | 在竞争，但它们之间也 |          |                      |                                          |                                          |               |
# |                      |                   | 有广泛的合作。例如， |          |                      |                                          |                                          |               |
# |                      |                   | 谷歌的搜索服务是苹果 |          |                      |                                          |                                          |               |
# |                      |                   | Safari 浏览器的默认  |          |                      |                                          |                                          |               |
# |                      |                   | 搜索引擎，而微软的   |          |                      |                                          |                                          |               |
# |                      |                   | Office 软件也支持在  |          |                      |                                          |                                          |               |
# |                      |                   | 苹果和安卓设备上运行 |          |                      |                                          |                                          |               |
# |                      |                   | 。此外，这些公司还共 |          |                      |                                          |                                          |               |
# |                      |                   | 同参与了开源项目和技 |          |                      |                                          |                                          |               |
# |                      |                   | 术标准的制定，推动了 |          |                      |                                          |                                          |               |
# |                      |                   | 整个行业的发展。  未 |          |                      |                                          |                                          |               |
# |                      |                   | 来趋势：人工智能与量 |          |                      |                                          |                                          |               |
# |                      |                   | 子计算 展望未来，人  |          |                      |                                          |                                          |               |
# |                      |                   | 工智能和量子计算将成 |          |                      |                                          |                                          |               |
# |                      |                   | 为科技行业的下一个风 |          |                      |                                          |                                          |               |
# |                      |                   | 口。谷歌和微软已经在 |          |                      |                                          |                                          |               |
# |                      |                   | 量子计算领域投入了大 |          |                      |                                          |                                          |               |
# |                      |                   | 量资源，并           |          |                      |                                          |                                          |               |
# | d6053c77d9ebfd4d738e | 9                 | 与了开源项目和技术标 | 300      | ['66bf9f67042bef537f | ['50b90370-f4b6-4a3f-a900-363c4c16de17'  | ['1deaf657-0a91-4fcc-8622-1577f5483686'  | []            |
# | dc8952fb42859160e820 |                   | 准的制定，推动了整个 |          | f7c55ae62fa9471ea3e5 |  'e1454e36-6ef9-44b7-b642-0093038b32d5'  |  '8af7bc93-83d7-45c9-8d16-e2040410119b'  |               |
# | 2285dc7775b30a9af0a2 |                   | 行业的发展。  未来趋 |          | 6ee868278e00d44302d9 |  '9bf6c182-c48d-4bf4-9717-d64909a75391'  |  '74a8e607-9411-4968-adb1-6880f3741592'  |               |
# | 1112d34c0fa090292a87 |                   | 势：人工智能与量子计 |          | adfb80dd0d8e0a226f05 |  '2d9bfc43-247c-447f-9463-c85496ddbf1d'  |  'bcd54b49-49a6-454e-bbe2-7cca0bc054db'  |               |
# | f803dd2311ac0dcb9762 |                   | 算 展望未来，人工智  |          | 5076e16c9c0a2f428cb9 |  '93762fdf-903f-442e-827b-947c8b9977e1'  |  'a884bad1-9af8-4881-b04b-4a2fc68d4fc0'] |               |
# | 8989f4419b04eba30a25 |                   | 能和量子计算将成为科 |          | 67443c406533e1715415 |  '59b9f9dc-37ed-424e-bab0-b65edac21a41'] |                                          |               |
# | c1725299             |                   | 技行业的下一个风口。 |          | 3a027ad2aa']         |                                          |                                          |               |
# |                      |                   | 谷歌和微软已经在量子 |          |                      |                                          |                                          |               |
# |                      |                   | 计算领域投入了大量资 |          |                      |                                          |                                          |               |
# |                      |                   | 源，并取得了一些突破 |          |                      |                                          |                                          |               |
# |                      |                   | 性进展。与此同时，苹 |          |                      |                                          |                                          |               |
# |                      |                   | 果和亚马逊也在积极布 |          |                      |                                          |                                          |               |
# |                      |                   | 局人工智能，试图通过 |          |                      |                                          |                                          |               |
# ...
# |                      |                   | 腾讯计算机系统有限公 |          |                      |                                          |                                          |               |
# |                      |                   | 司由马化腾等"腾讯五  |          |                      |                                          |                                          |               |
# |                      |                   | 虎"于1998年创立。200 |          |                      |                                          |                                          |               |
# |                      |                   | 4年在香港联交所上市  |          |                      |                                          |                                          |               |
# |                      |                   | ，2011年             |          |                      |                                          |                                          |               |
# | ed91503e6018a298ebf9 | 13                | 2021年云计算业务跃居 | 300      | ['9b053fc85dd527526e |                                          |                                          | []            |
# | e251724dc1dac8edb4f5 |                   | 亚太市场首位。  腾讯 |          | b1f7a7f3bcb90904bd00 |                                          |                                          |               |
# | 131e34db418df30d0a4f |                   | ：即时通讯到生态构建 |          | 38a05b07f35fb4f1d5b6 |                                          |                                          |               |
# | f287364e748f88d1d2bd |                   | 者 深圳市腾讯计算机  |          | b96c19dd3e87d023197e |                                          |                                          |               |
# | db515833b4de68496790 |                   | 系统有限公司由马化腾 |          | d285c29406a2284f99a3 |                                          |                                          |               |
# | b7244c5533fa66363459 |                   | 等"腾讯五虎"于1998年 |          | 30101892dfaacc39988d |                                          |                                          |               |
# | 4fd344c9             |                   | 创立。2004年在香港联 |          | 2e9aa62ad4']         |                                          |                                          |               |
# |                      |                   | 交所上市，2011年推出 |          |                      |                                          |                                          |               |
# |                      |                   | 微信（WeChat）引发移 |          |                      |                                          |                                          |               |
# |                      |                   | 动社交革命。2017年《 |          |                      |                                          |                                          |               |
# |                      |                   | 王者荣耀》成为全球营 |          |                      |                                          |                                          |               |
# |                      |                   | 收最高手游事件。通过 |          |                      |                                          |                                          |               |
# |                      |                   | 投资京东、美团等企业 |          |                      |                                          |                                          |               |
# |                      |                   | 构建庞大数字生态。   |          |                      |                                          |                                          |               |
# |                      |                   | 字节跳动：算法驱动的 |          |                      |                                          |                                          |               |
# |                      |                   | 内容帝国 北京字节跳  |          |                      |                                          |                                          |               |
# |                      |                   | 动科技有限公司由张一 |          |                      |                                          |                                          |               |
# |                      |                   | 鸣于2012年创立。2016 |          |                      |                                          |                                          |               |
# |                      |                   | 年推出抖音（TikTok） |          |                      |                                          |                                          |               |
# |                      |                   | 引发短视频热潮，2021 |          |                      |                                          |                                          |               |
# |                      |                   | 年月活用户突破10亿事 |          |                      |                                          |                                          |               |
# |                      |                   | 件。2020年通过收购中 |          |                      |                                          |                                          |               |
# |                      |                   | 融小贷获得金融牌照， |          |                      |                                          |                                          |               |
# |                      |                   | 2023年推出大模型云雀 |          |                      |                                          |                                          |               |
# |                      |                   | （Lark）布局人工智能 |          |                      |                                          |                                          |               |
# |                      |                   | 领域。               |          |                      |                                          |                                          |               |
# | 115274092015190a0c5f | 14                | 2年创立。2016年推出  | 300      | ['9b053fc85dd527526e | ['719159da-e75a-47d8-b05f-6c4514f0edd5'  | ['91fb9e42-2baa-471e-a4c5-176e23ef3415'  | []            |
# | 38b887dce5d094af773d |                   | 抖音（TikTok）引发短 |          | b1f7a7f3bcb90904bd00 |  '01e9db66-a8ec-4afc-9af3-7d9e4e3e249c'  |  '110115d8-2ed1-45be-ac72-9ca8d295f98c'  |               |
# | 03db43339372050a36fc |                   | 视频热潮，2021年月活 |          | 38a05b07f35fb4f1d5b6 |  '32ce0ec7-0a6d-4b8c-a918-9f7eac566e9c'  |  '4978e0f0-47f1-4077-b03b-42780214e087'  |               |
# | 7fde1ad1308fb2d5e18c |                   | 用户突破10亿事件。20 |          | b96c19dd3e87d023197e |  'c09bb0f0-1535-4aa8-8311-3adb3b0e2a58'  |  'ba5b8a24-4700-4af6-bf32-2f289c14a7cd'  |               |
# | bdf8cd7e17469e5194f7 |                   | 20年通过收购中融小贷 |          | d285c29406a2284f99a3 |  '0a3fa1b8-3681-4b68-be58-7dc41c21f8de'  |  'f7232764-49e3-4749-bc34-e73d4ebb51fd'  |               |
# | b4d8290213413255be7c |                   | 获得金融牌照，2023年 |          | 30101892dfaacc39988d |  '88b7d9a3-d1c2-49da-a05c-9199b1ab3a08'  |  '21a000d1-08df-426f-83df-fa12b40d6662'  |               |
# | 3dc5e97a             |                   | 推出大模型云雀（Lark |          | 2e9aa62ad4']         |  'e73383c6-5e46-48b4-b333-9dc58a95f384'  |  '3bf6e536-8f3a-4920-97fb-4462ff49c810'  |               |
# |                      |                   | ）布局人工智能领域。 |          |                      |  'd160756f-5fd3-479a-8d4a-ee59bd75fed9'  |  '82ccd44f-6a69-4597-81bb-5dc9704d6f1a'  |               |
# |                      |                   | 创新要素的中国特色   |          |                      |  'f5ce0d7a-6a5d-417e-80a7-f1ec23404162'  |  'e0b421cb-582e-4bbb-8552-bb5a4308cd8f'  |               |
# |                      |                   | 中关村科技园与粤港澳 |          |                      |  'ab8fc579-78dd-48dd-b315-ef5d1a924136'  |  '1e189014-4f0a-40c8-b8e0-16bbc74bb6e6'  |               |
# |                      |                   | 大湾区的建设展现独特 |          |                      |  '32c8508d-fc6b-45ac-882b-789c7054781c'  |  'd9a0fce1-e783-4f6c-8435-e9965645b2f6'  |               |
# |                      |                   | 优势：1）清华大学、  |          |                      |  'ff1789e2-3504-4997-ae60-db4b9c0bad4b'  |  '77a6bfa4-eb73-4172-8f25-1727f2e6a1b1'  |               |
# |                      |                   | 浙江大学等高校提供人 |          |                      |  '8e140173-c526-4a8b-b207-907c1a770ae1'  |  '45ada7a6-a142-4a69-a480-b349ac12443c'  |               |
# |                      |                   | 才储备；2）"双创"政  |          |                      |  'df8a988c-7b7b-4d6a-a8f4-9109f124c728'  |  '26e08050-bb60-4740-b1ab-b4fe2109d3aa'  |               |
# |                      |                   | 策催生孵化器模式；3  |          |                      |  'b885a885-7890-4003-9ee1-eecd45543fd9'] |  'e0847183-782a-4221-9e46-334dffa13f15'  |               |
# |                      |                   | ）科创板设立完善科技 |          |                      |                                          |  '3a57baab-f6bf-4aab-bbdc-c918ba0aaee0'] |               |
# |                      |                   | 企业融资通道。       |          |                      |                                          |                                          |               |
# |                      |                   | 跨界竞合新格局 虽然  |          |                      |                                          |                                          |               |
# |                      |                   | 华为与小米在智能手机 |          |                      |                                          |                                          |               |
# |                      |                   | 市场激烈竞争，但2021 |          |                      |                                          |                                          |               |
# |                      |                   | 年共同参与开放原子开 |          |                      |                                          |                                          |               |
# |                      |                   | 源基金会事件。阿里巴 |          |                      |                                          |                                          |               |
# |                      |                   | 巴的钉钉与腾讯会议在 |          |                      |                                          |                                          |               |
# |                      |                   | 协同办公领域角力，   |          |                      |                                          |                                          |               |
# | ce107dd1f1c26ce2073f | 15                | 科技企业融资通道。   | 203      | ['9b053fc85dd527526e | ['719159da-e75a-47d8-b05f-6c4514f0edd5'  | ['77a6bfa4-eb73-4172-8f25-1727f2e6a1b1'  | []            |
# | db34877c6ca82fed3205 |                   | 跨界竞合新格局 虽然  |          | b1f7a7f3bcb90904bd00 |  '01e9db66-a8ec-4afc-9af3-7d9e4e3e249c'  |  'e0847183-782a-4221-9e46-334dffa13f15'  |               |
# | d49df55738513411bf0e |                   | 华为与小米在智能手机 |          | 38a05b07f35fb4f1d5b6 |  'ab8fc579-78dd-48dd-b315-ef5d1a924136'  |  'db1b1497-aa98-47c5-8aaa-401750e26aa0'  |               |
# | 423971a7a6e80396e4cb |                   | 市场激烈竞争，但2021 |          | b96c19dd3e87d023197e |  '32c8508d-fc6b-45ac-882b-789c7054781c'  |  'a77b0512-5e92-4236-8920-4e26d76e8db9'  |               |
# | a4ae8dca7a8afb90ea6d |                   | 年共同参与开放原子开 |          | d285c29406a2284f99a3 |  'ff1789e2-3504-4997-ae60-db4b9c0bad4b'  |  '99816e0d-56f7-48cc-82e2-86f5fd642beb'  |               |
# | 9830f5d62a342c1d0de0 |                   | 源基金会事件。阿里巴 |          | 30101892dfaacc39988d |  '49ba19c7-7a07-4b50-8da1-b924de029c6d'  |  'c925feb3-2dc6-4fc3-821f-3a90d65de28a'  |               |
# | 7766f3fe             |                   | 巴的钉钉与腾讯会议在 |          | 2e9aa62ad4']         |  '27509e02-e2fd-4217-9c22-1a44fdd4e884'  |  '0bda819b-a2c1-4e9c-9330-7e1d08dd0c96'  |               |
# |                      |                   | 协同办公领域角力，却 |          |                      |  'e31b6b1c-4f17-447d-8214-6fa3301ccdf9'  |  '6812e8c8-160f-4f32-bb31-21453b5a1cec'  |               |
# |                      |                   | 都在使用华为云基础设 |          |                      |  'd63b90ec-75c6-4ad1-b57a-97cd38a4ead0'  |  '975eb9d9-230d-4bf9-a5c0-0fc8509517e2'] |               |
# |                      |                   | 施。                 |          |                      |  'abacfdba-23b8-4f5d-96d6-49c0023e28bd'  |                                          |               |
# |                      |                   | 未来赛道：AI与半导体 |          |                      |  '70b53e10-ee5e-4f91-92e6-79ce7ac9ede9'  |                                          |               |
# |                      |                   | 寒武纪的思元370芯片  |          |                      |  '4a1c239b-2c79-4b76-8f9d-5381c66f2a39'  |                                          |               |
# |                      |                   | 与中芯国际的7nm工艺  |          |                      |  '4a33cdd7-0e05-4455-bf81-7dde5f98e688'  |                                          |               |
# |                      |                   | 突破显示国产化进程加 |          |                      |  '6f2ee55d-1efc-4e62-ba75-1c13ac1956dd'] |                                          |               |
# |                      |                   | 速。百度的"文心一言" |          |                      |                                          |                                          |               |
# |                      |                   | 大模型和商汤科技的Se |          |                      |                                          |                                          |               |
# |                      |                   | nseNova平台正在重塑A |          |                      |                                          |                                          |               |
# |                      |                   | I产业生态。          |          |                      |                                          |                                          |               |
# | 66f5659cfc38c69decf2 | 16                | 生态。               | 3        | ['9b053fc85dd527526e |                                          |                                          | []            |
# | 67b2eba530d70042811d |                   |                      |          | b1f7a7f3bcb90904bd00 |                                          |                                          |               |
# | 865ca30016893328e881 |                   |                      |          | 38a05b07f35fb4f1d5b6 |                                          |                                          |               |
# | b6196cf6bd2be2b9f7a7 |                   |                      |          | b96c19dd3e87d023197e |                                          |                                          |               |
# | fa787e0ad1cbe85952a0 |                   |                      |          | d285c29406a2284f99a3 |                                          |                                          |               |
# | 3b20000a6d7f6f67ce75 |                   |                      |          | 30101892dfaacc39988d |                                          |                                          |               |
# | f741ec2b             |                   |                      |          | 2e9aa62ad4']         |                                          |                                          |               |
# +----------------------+-------------------+----------------------+----------+----------------------+------------------------------------------+------------------------------------------+---------------+

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>text_units DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个文档块（即从单个文档中切分出来的完整块）。                          |
# | human_readable_id   | 字符串             | 可读的标识符，通常用于用户界面显示，便于用户理解和识别。   |
# | text                | 字符串             | 该文本块中的内容                       |
# | n_tokens            | 整数               | 按照切分策略切分出来的最终文本长度。                         |
# | document_ids        | 列表（字符串）     | 关联的文档的唯一标识符列表，用于将文本块与document中的文档id关联。   |
# | entity_ids          | 列表（字符串）     | 关联的实体的唯一标识符列表，表示该文本块中都提取出来了哪些实体。       |
# | relationship_ids    | 列表（字符串）     | 关联的关系的唯一标识符列表，表示该文本块中都提取出来了哪些关系。       |
# | covariate_ids       | 列表（字符串）     | 关联的协变量的唯一标识符列表，用于统计分析或建模。   |
# </div>

# %% [markdown]
# &emsp;&emsp;在知识图谱构建过程中，TextUnit实体作为文本切分后的产物，其导入策略可以考虑以下原则：
#
# - **节点标识**：需要使用`id`字段作为TextUnit节点的唯一标识符，确保图谱中文档块实体一致性。
# - **约束策略**：唯一性约束，确保文本块的id是唯一的。
# - **属性选择**：比如文本内容，文本长度等，根据需求选择。
# - **关系策略**：创建`PART_OF`关系，将TextUnit节点与Document节点关联起来，表示该文本块属于哪个文档。

# %% [markdown]
# &emsp;&emsp;因此，把上述的策略转化成代码。就如下所示：

# %%
def setup_chunk_constraints():
    """创建Chunk标签的约束"""
    with driver.session(database=NEO4J_DATABASE) as session:
        try:
            # 创建Chunk.id唯一性约束
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (c:__Chunk__) REQUIRE c.id IS UNIQUE")
            print("已创建Chunk.id唯一性约束")
        except Exception as e:
            print(f"创建__Chunk__约束时出错 (可能已存在): {e}")
            # 尝试旧版本Neo4j的语法
            try:
                session.run("CREATE CONSTRAINT ON (c:__Chunk__) ASSERT c.id IS UNIQUE")
                print("已使用旧语法创建__Chunk__.id唯一性约束")
            except Exception as e2:
                print(f"使用旧语法创建约束也失败: {e2}")

# %%
def import_chunks(df_chunks, batch_size=100, max_workers=8):
    """
    导入文档块(Chunk)到Neo4j
    
    参数:
    - df_chunks: 包含文档块数据的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """
    # 1. 创建Chunk的约束
    setup_chunk_constraints()
    
    # 2. 创建Chunk节点
    print("开始导入Chunk节点...")
    chunk_statement = """
    MERGE (c:__Chunk__ {id: value.id})
    SET c.text = value.text,
        c.n_tokens = value.n_tokens,
        c.human_readable_id = value.human_readable_id,
        // 设置显示名称为human_readable_id
        c.name = value.human_readable_id
    """
    
    chunk_result = parallel_batched_import(chunk_statement, df_chunks, batch_size, max_workers)
    
    # 3. 准备关系数据 - 正确处理嵌套的document_ids并过滤无效数据
    print("准备Chunk-Document关系数据...")
    relations_data = []
    
    for idx, row in df_chunks.iterrows():
        chunk_id = row['id']
        doc_ids_container = row['document_ids']
        
        # 处理嵌套结构
        flat_doc_ids = []
        
        # 如果是列表，展平它
        if isinstance(doc_ids_container, list):
            for item in doc_ids_container:
                # 如果是NumPy数组
                if hasattr(item, 'dtype') and hasattr(item, 'tolist'):
                    flat_doc_ids.extend(item.tolist())
                # 如果是列表
                elif isinstance(item, list):
                    flat_doc_ids.extend(item)
                # 如果是单个值
                else:
                    flat_doc_ids.append(item)
        # 如果不是列表，直接添加
        elif doc_ids_container is not None:
            flat_doc_ids.append(doc_ids_container)
        
        # 记录处理后的document_ids
        if idx < 5:  # 只记录前几行，避免日志过大
            print(f"行 {idx} 处理后的document_ids: {flat_doc_ids}")
        
        # 为每个文档ID创建关系，过滤掉无效的ID
        for doc_id in flat_doc_ids:
            if doc_id is not None and str(doc_id).strip() != '':
                # 确保doc_id是字符串并过滤掉特殊格式
                doc_id_str = str(doc_id).strip()
                
                # 过滤掉不符合预期格式的ID
                if doc_id_str.startswith('<elementId>') or doc_id_str.startswith('<id>'):
                    print(f"跳过无效的document_id: {doc_id_str}")
                    continue
                
                # 如果是列表形式的字符串，提取实际ID
                if doc_id_str.startswith('[') and doc_id_str.endswith(']'):
                    try:
                        # 尝试解析列表字符串
                        import ast
                        id_list = ast.literal_eval(doc_id_str)
                        if isinstance(id_list, list) and len(id_list) > 0:
                            doc_id_str = str(id_list[0])
                    except:
                        print(f"无法解析列表格式的document_id: {doc_id_str}")
                        continue
                
                relations_data.append({
                    'chunk_id': chunk_id,
                    'document_id': doc_id_str
                })
    
    # 4. 确保Document节点存在
    if relations_data:
        unique_doc_ids = set(item['document_id'] for item in relations_data)
        print(f"发现 {len(unique_doc_ids)} 个唯一的document_id")
        
        # 创建Document节点
        docs_df = pd.DataFrame({'id': list(unique_doc_ids)})
        document_statement = """
        MERGE (d:__Document__ {id: value.id})
        // 设置显示名称
        SET d.name = value.id
        """
        doc_result = parallel_batched_import(document_statement, docs_df, batch_size, max_workers)
        print(f"已创建 {doc_result['successful_rows']} 个Document节点")
        
        # 5. 创建关系
        print(f"开始创建 {len(relations_data)} 个Chunk-Document关系...")
        df_relations = pd.DataFrame(relations_data)
        
        relation_statement = """
        MATCH (c:__Chunk__ {id: value.chunk_id})
        MATCH (d:__Document__ {id: value.document_id})
        MERGE (c)-[:PART_OF]->(d)
        """
        
        relation_result = parallel_batched_import(relation_statement, df_relations, batch_size, max_workers)
        print(f"已创建 {relation_result['successful_rows']} 个Chunk-Document关系")
    else:
        print("没有找到有效的Chunk-Document关系数据")
    
    # 6. 验证结果
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Chunk节点数量
        result = session.run("MATCH (c:__Chunk__) RETURN count(c) as count")
        chunk_count = result.single()["count"]
        
        # 检查Document节点数量
        result = session.run("MATCH (d:__Document__) RETURN count(d) as count")
        doc_count = result.single()["count"]
        
        # 检查PART_OF关系数量
        result = session.run("MATCH ()-[r:PART_OF]->() RETURN count(r) as count")
        relation_count = result.single()["count"]
        
        print(f"验证结果: {chunk_count} 个Chunk节点, {doc_count} 个Document节点, {relation_count} 个PART_OF关系")
    
    return chunk_result

# %% [markdown]
# &emsp;&emsp;接下来，连接到`Neo4j`数据库，并调用`import_chunks`函数，导入文本单元。代码如下：

# %%
NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"
NEO4J_DATABASE="neo4j"

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

# 执行 text_units.parquet 文件的导入
import_chunks(df_text_units)
# Out:
# 已创建Chunk.id唯一性约束
# 开始导入Chunk节点...
# 开始并行导入 16 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 16 行, 耗时 0.49秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 16 行, 成功 16 行, 失败 0 行
# 总耗时: 0.49秒, 平均速度: 32.38 行/秒
# 准备Chunk-Document关系数据...
# 行 0 处理后的document_ids: [array(['66bf9f67042bef537ff7c55ae62fa9471ea3e56ee868278e00d44302d9adfb80dd0d8e0a226f055076e16c9c0a2f428cb967443c406533e17154153a027ad2aa'],
#       dtype=object)]
# 行 1 处理后的document_ids: [array(['66bf9f67042bef537ff7c55ae62fa9471ea3e56ee868278e00d44302d9adfb80dd0d8e0a226f055076e16c9c0a2f428cb967443c406533e17154153a027ad2aa'],
#       dtype=object)]
# 行 2 处理后的document_ids: [array(['66bf9f67042bef537ff7c55ae62fa9471ea3e56ee868278e00d44302d9adfb80dd0d8e0a226f055076e16c9c0a2f428cb967443c406533e17154153a027ad2aa'],
#       dtype=object)]
# 行 3 处理后的document_ids: [array(['66bf9f67042bef537ff7c55ae62fa9471ea3e56ee868278e00d44302d9adfb80dd0d8e0a226f055076e16c9c0a2f428cb967443c406533e17154153a027ad2aa'],
#       dtype=object)]
# 行 4 处理后的document_ids: [array(['66bf9f67042bef537ff7c55ae62fa9471ea3e56ee868278e00d44302d9adfb80dd0d8e0a226f055076e16c9c0a2f428cb967443c406533e17154153a027ad2aa'],
#       dtype=object)]
# 发现 2 个唯一的document_id
# 开始并行导入 2 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 2 行, 耗时 0.11秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 2 行, 成功 2 行, 失败 0 行
# 总耗时: 0.11秒, 平均速度: 18.12 行/秒
# 已创建 2 个Document节点
# 开始创建 16 个Chunk-Document关系...
# 开始并行导入 16 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 16 行, 耗时 0.69秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 16 行, 成功 16 行, 失败 0 行
# 总耗时: 0.69秒, 平均速度: 23.16 行/秒
# 已创建 16 个Chunk-Document关系
# 验证结果: 16 个Chunk节点, 2 个Document节点, 16 个PART_OF关系
# {'total_rows': 16,
#  'successful_rows': 16,
#  'failed_rows': 0,
#  'duration_seconds': 0.49408960342407227,
#  'rows_per_second': 32.3827902654073,
#  'batch_results': [{'batch': 0,
#    'rows': 16,
#    'success': True,
#    'duration': 0.4921996593475342,
#    'counters': {'_contains_updates': True, 'labels_added': 16, 'nodes_created': 16, 'properties_set': 80}}]}

# %% [markdown]
# &emsp;&emsp;同样第，执行完成后可以在`localhost:7474`的`Neo4j`浏览器中，可以看到`__Chunk__`标签的节点已经创建完成，以及`__Chunk__`与`__Document__`之间的关系也已经创建完成。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121844987.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了`text_units.parquet`文件的导入。接下来，我们开始导入`entities.parquet`文件。

# %% [markdown]
# ## 4.4 导入实体

# %% [markdown]
# &emsp;&emsp;`entities.parquet`文件中主要存储的通过提示词，借助大模型从`text_units`中提取出来的实体。读取该文件的代码如下所示：

# %%
# 使用绝对路径读取 Parquet 文件
df_entities = pd.read_parquet('entities.parquet')  # 替换为实际路径

# 假设 df 是你的 DataFrame
print(tabulate(df_entities, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+----------------------+--------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------+--------+---+---+
# | id                   | human_readable_id | title                | type         | description          | text_unit_ids                                                                                                                        | frequency | degree | x | y |
# +----------------------+-------------------+----------------------+--------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------+--------+---+---+
# | 4b2d9bf3-01d4-435c-9 | 0                 | APPLE INC.           | ORGANIZATION | Apple Inc. is a      | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 1         | 7      | 0 | 0 |
# | de5-8eb8744ffc11     |                   |                      |              | global technology    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company founded in   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 1976 in Cupertino,   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | California, known    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | for products like    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | the Apple I and      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Macintosh computers, |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | and has grown to a   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | trillion-dollar      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | market value         |                                                                                                                                      |           |        |   |   |
# | 0e4861f4-29ec-4ddd-  | 1                 | STEVE JOBS           | PERSON       | Steve Jobs, one of   | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2         | 6      | 0 | 0 |
# | bf7d-a055a00e75a4    |                   |                      |              | the co-founders of   |  'b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |           |        |   |   |
# |                      |                   |                      |              | Apple Inc., is       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | widely recognized as |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | a visionary leader   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | in the technology    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | industry. He played  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | a pivotal role in    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | developing           |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | groundbreaking       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | products such as the |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Macintosh, iMac,     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | iPod, iPhone, and    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | iPad, which          |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | revolutionized the   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | tech landscape.      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | After leaving Apple  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | in 1985, Jobs        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | returned to the      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company in 1997 and  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | successfully         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | revitalized it,      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | cementing his legacy |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | as a transformative  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | figure in both       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Apple's history and  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | the broader          |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | technology sector.   |                                                                                                                                      |           |        |   |   |
# | 2b44a251-58fc-48e0-b | 2                 | STEVE WOZNIAK        | PERSON       | Steve Wozniak is one | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 1         | 1      | 0 | 0 |
# | dcd-4fc9173adb3c     |                   |                      |              | of the co-founders   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | of Apple Inc., known |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | for his engineering  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | contributions to     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | early Apple products |                                                                                                                                      |           |        |   |   |
# | 1d238b98-0667-4c09-8 | 3                 | RON WAYNE            | PERSON       | Ron Wayne is one of  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 1         | 1      | 0 | 0 |
# | b39-831a9d63e2c7     |                   |                      |              | the co-founders of   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Apple Inc., who      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | played a role in the |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company's early days |                                                                                                                                      |           |        |   |   |
# | a1970ae2-2174-464c-8 | 4                 | CUPERTINO            | GEO          | Cupertino is a city  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2         | 3      | 0 | 0 |
# | e6a-a69038276d4c     |                   |                      |              | located in           |  'b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |           |        |   |   |
# |                      |                   |                      |              | California, USA. It  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | is notably           |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | recognized as the    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | birthplace of Apple  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Inc., which was      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | founded in 1976. The |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company's origins    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | trace back to a      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | humble beginning in  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | a garage within the  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | city, marking        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Cupertino as a       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | significant location |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | in the history of    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | technology and       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | innovation.          |                                                                                                                                      |           |        |   |   |
# | 758325f0-6a01-487e-8 | 5                 | SILICON VALLEY       | GEO          | Silicon Valley is a  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2         | 7      | 0 | 0 |
# | 2e4-3fe8dc7dd3f9     |                   |                      |              | globally renowned    |  'c4c5297b4bf585666851d3e50123a6e5dd9a6223b14675624752a2a3033ba6629af55fb798a18a2d6ecbb974baddbfb2eace4d6468971449b35c10fa5c1cc2cc'] |           |        |   |   |
# |                      |                   |                      |              | hub for technology   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | and innovation,      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | recognized for its   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | concentration of     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | leading tech         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | companies, such as   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Apple Inc., as well  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | as its thriving      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | startup ecosystem.   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Additionally, it is  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | home to top          |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | universities,        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | further solidifying  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | its position as a    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | center for           |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | technological        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | advancement and      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | entrepreneurial      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | activity. This       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | combination of       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | academic excellence, |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | corporate            |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | leadership, and a    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | dynamic startup      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | culture makes        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Silicon Valley a     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | pivotal region in    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | the global tech      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | landscape.           |                                                                                                                                      |           |        |   |   |
# | b50512b1-2314-4da1-8 | 6                 | APPLE I              | EVENT        | The Apple I was the  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 1         | 2      | 0 | 0 |
# | 8b4-7e8d6edc5364     |                   |                      |              | first product        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | released by Apple    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Inc. in 1976,        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | marking the          |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company's entry into |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | the personal         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | computer market      |                                                                                                                                      |           |        |   |   |
# | e46d6ac5-135f-41d5-b | 7                 | MACINTOSH            | EVENT        | MACINTOSH            | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2         | 2      | 0 | 0 |
# | 7db-a020eb6ccf67     |                   |                      |              | 是苹果公司（Apple In |  'b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |           |        |   |   |
# |                      |                   |                      |              | c.）于1984年推出的一 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 款具有革命性意义的个 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 人电脑。它的发布标志 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 着图形用户界面（GUI  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | ）在计算机领域的首次 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 成功商业化，彻底改变 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 了人机交互的方式。MA |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | CINTOSH 以其创新的图 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 形用户界面为特色，成 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 为当时技术领域的重大 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 突破，为后续计算机设 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 计和发展奠定了基础。 |                                                                                                                                      |           |        |   |   |
# | c4892971-46e1-4a9f-8 | 8                 | MICROSOFT            | ORGANIZATION | Microsoft is a       | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2         | 10     | 0 | 0 |
# | 256-8414d812612d     |                   |                      |              | global technology    |  'c74ed55a3ebcbc0bb18a6e60a119aab7efcf80364e115f5ce4157b1ac1a2aef7ac4d9f0b13ab35a02fdc3814716c37007baabe0eeb612481ae10ef89fdc45015'] |           |        |   |   |
# |                      |                   |                      |              | company renowned for |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | its software         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | products, including  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Windows and Office.  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Founded in 1975 by   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Paul Allen in        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Redmond, Washington, |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Microsoft initially  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | gained prominence    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | with the development |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | of BASIC             |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | interpreters. The    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | company achieved     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | widespread           |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | recognition with the |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | release of MS-DOS in |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 1981 and Windows in  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 1985, which became   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | foundational to its  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | success. In the 21st |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | century, Microsoft   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | shifted its focus to |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | cloud computing,     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | launching Azure in   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 2008, and expanded   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | its influence        |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | through strategic    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | acquisitions such as |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | LinkedIn and GitHub. |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Today, Microsoft     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | remains a leader in  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | the technology       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | industry,            |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | continuously         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | innovating and       |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | adapting to the      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | evolving digital     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | landscape.           |                                                                                                                                      |           |        |   |   |
# | 6d5bce0c-e166-460f-a | 9                 | AMAZON               | ORGANIZATION | Amazon is a global   | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 4         | 9      | 0 | 0 |
# | 432-879f253d4eda     |                   |                      |              | technology and       |  'c74ed55a3ebcbc0bb18a6e60a119aab7efcf80364e115f5ce4157b1ac1a2aef7ac4d9f0b13ab35a02fdc3814716c37007baabe0eeb612481ae10ef89fdc45015'  |           |        |   |   |
# |                      |                   |                      |              | e-commerce company   |  '01434455979f8f5369ea62fdc2ff4ff1360677293c575d32f1672521daaee69a7f111448645d4c70464db9dbbbe3d009c42336fd2801161e3418c607aa4efc1d'  |           |        |   |   |
# |                      |                   |                      |              | founded by Jeff      |  'c4c5297b4bf585666851d3e50123a6e5dd9a6223b14675624752a2a3033ba6629af55fb798a18a2d6ecbb974baddbfb2eace4d6468971449b35c10fa5c1cc2cc'] |           |        |   |   |
# |                      |                   |                      |              | Bezos in 1994 in     |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Seattle, Washington. |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | Initially starting   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | as an online         |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | bookstore, Amazon    |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | rapidly expanded its |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | offerings to become  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | a comprehensive      |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | platform selling a   |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | wide variety of      |                                                                                                                                      |           |        |   |   |
# ...
# |                      |                   |                      |              | 得到了多家科技企业的 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 支持，其中包括华为和 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 小米。2021年，华为和 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 小米共同参与了开放原 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 子开源基金会的活动， |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 展现了其在科技领域的 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 重要影响力。作为一家 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 科技组织，开放原子开 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 源基金会通过促进企业 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 间的合作与创新，为开 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 源社区的发展做出了积 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 极贡献。             |                                                                                                                                      |           |        |   |   |
# | ff1789e2-3504-4997-a | 93                | 腾讯会议             | ORGANIZATION | 腾讯会议是腾讯旗下的 | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'  | 2         | 3      | 0 | 0 |
# | e60-db4b9c0bad4b     |                   |                      |              | 协同办公产品，主要功 |  'ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |           |        |   |   |
# |                      |                   |                      |              | 能是提供在线会议和协 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 同办公服务。作为腾讯 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 在协同办公领域的重要 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 工具，腾讯会议与阿里 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 巴巴的钉钉形成了直接 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 竞争关系。两款产品均 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 旨在满足企业和个人用 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 户在远程办公和团队协 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 作方面的需求。       |                                                                                                                                      |           |        |   |   |
# | 8e140173-c526-4a8b-b | 94                | 科创板               | EVENT        | 科创板是中国设立的资 | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] | 1         | 1      | 0 | 0 |
# | 207-907c1a770ae1     |                   |                      |              | 本市场板块，为科技企 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 业提供融资通道"      |                                                                                                                                      |           |        |   |   |
# | df8a988c-7b7b-4d6a-a | 95                | 双创政策             | EVENT        | 双创政策是中国政府推 | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] | 1         | 1      | 0 | 0 |
# | 8f4-9109f124c728     |                   |                      |              | 动创新创业的政策，催 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 生孵化器模式"        |                                                                                                                                      |           |        |   |   |
# | b885a885-7890-4003-9 | 96                | 钉钉                 | ORGANIZATION | 钉钉是阿里巴巴旗下的 | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] | 1         | 2      | 0 | 0 |
# | ee1-eecd45543fd9     |                   |                      |              | 协同办公工具，与腾讯 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 会议竞争"            |                                                                                                                                      |           |        |   |   |
# | 49ba19c7-7a07-4b50-8 | 97                | 华为云               | ORGANIZATION | 华为云是华为提供的云 | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 2      | 0 | 0 |
# | da1-b924de029c6d     |                   |                      |              | 基础设施服务，被阿里 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 巴巴的钉钉和腾讯会议 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 使用                 |                                                                                                                                      |           |        |   |   |
# | 27509e02-e2fd-4217-9 | 98                | 寒武纪               | ORGANIZATION | 寒武纪是一家科技企业 | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | c22-1a44fdd4e884     |                   |                      |              | ，其思元370芯片在半  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 导体领域取得突破     |                                                                                                                                      |           |        |   |   |
# | e31b6b1c-4f17-447d-8 | 99                | 中芯国际             | ORGANIZATION | 中芯国际是一家半导体 | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | 214-6fa3301ccdf9     |                   |                      |              | 制造企业，其7nm工艺  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 突破加速了国产化进程 |                                                                                                                                      |           |        |   |   |
# | d63b90ec-75c6-4ad1-b | 100               | 百度                 | ORGANIZATION | 百度是一家科技企业， | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | 57a-97cd38a4ead0     |                   |                      |              | 其“文心一言”大模型正 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 在重塑AI产业生态     |                                                                                                                                      |           |        |   |   |
# | abacfdba-23b8-4f5d-9 | 101               | 商汤科技             | ORGANIZATION | 商汤科技是一家科技企 | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | 6d6-49c0023e28bd     |                   |                      |              | 业，其SenseNova平台  |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 正在重塑AI产业生态   |                                                                                                                                      |           |        |   |   |
# | 70b53e10-ee5e-4f91-9 | 102               | 思元370芯片          | ORGANIZATION | 思元370芯片是寒武纪  | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | 2e6-79ce7ac9ede9     |                   |                      |              | 推出的半导体产品，代 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 表国产化进程的突破   |                                                                                                                                      |           |        |   |   |
# | 4a1c239b-2c79-4b76-8 | 103               | 7NM工艺              | ORGANIZATION | 7nm工艺是中芯国际在  | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | f9d-5381c66f2a39     |                   |                      |              | 半导体制造领域的重大 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 突破                 |                                                                                                                                      |           |        |   |   |
# | 4a33cdd7-0e05-4455-b | 104               | 文心一言             | ORGANIZATION | 文心一言是百度推出的 | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | f81-7dde5f98e688     |                   |                      |              | 大模型，正在重塑AI产 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 业生态               |                                                                                                                                      |           |        |   |   |
# | 6f2ee55d-1efc-4e62-b | 105               | SENSENOVA平台        | ORGANIZATION | SenseNova平台是商汤  | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] | 1         | 1      | 0 | 0 |
# | a75-1c13ac1956dd     |                   |                      |              | 科技推出的AI产品，正 |                                                                                                                                      |           |        |   |   |
# |                      |                   |                      |              | 在重塑AI产业生态     |                                                                                                                                      |           |        |   |   |
# +----------------------+-------------------+----------------------+--------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------+--------+---+---+

# %% [markdown]
# &emsp;&emsp;各个字段的解释如下所示：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>entities DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个实体记录。                           |
# | human_readable_id   | 字符串             | 可读的标识符，用于用户界面显示，便于用户理解和识别。   |
# | title               | 字符串             | 实体的名称或主题。                   |
# | type                | 字符串             | 实体的类型，例如 `GEO` 表示地理位置。                       |
# | description         | 字符串             | 对实体的详细描述，提供更多上下文信息。                     |
# | text_unit_ids       | 列表（字符串）     | 关联的文本单元的唯一标识符列表，用于将实体与文本块关联。 |
# | frequency           | 整数               | 实体出现的频率，表示该实体在数据中的重要性或常见程度。     |
# | degree              | 整数               | 实体的度数，通常表示与其他实体的连接数量。                 |
# | x                   | 浮点数             | 实体在二维空间中的 x 坐标，通常用于可视化。                |
# | y                   | 浮点数             | 实体在二维空间中的 y 坐标，通常用于可视化。                |
#
# </div>

# %% [markdown]
# &emsp;&emsp;在知识图谱构建过程中，其导入策略可以考虑以下原则：
#
# - **节点标识**：需要使用`id`字段作为Entity节点的唯一标识符，确保图谱中实体节点一致性。同时为了避免重复，`name`字段也需要作为Entity节点的唯一标识符。
# - **约束策略**：唯一性约束，确保实体的id是唯一的。
# - **属性选择**：比如实体的名称，描述，频率，度数等，根据需求选择。
# - **标签策略**：给节点添加动态标签（根据 实体的 type 添加）
# - **关系策略**：创建`HAS_ENTITY`关系，将Entity节点与Chunk节点关联起来，表示该实体属于哪个文本块。

# %% [markdown]
# &emsp;&emsp;因此，把上述的策略转化成代码。就如下所示：

# %%
def setup_entity_constraints():
    """创建Entity标签的约束"""
    with driver.session(database=NEO4J_DATABASE) as session:
        try:
            # 创建Entity.id唯一性约束
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (e:__Entity__) REQUIRE e.id IS UNIQUE")
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (e:__Entity__) REQUIRE e.name IS UNIQUE")
            print("已创建__Entity__.id唯一性约束")
        except Exception as e:
            print(f"创建__Entity__约束时出错 (可能已存在): {e}")
            # 尝试旧版本Neo4j的语法
            try:
                session.run("CREATE CONSTRAINT ON (e:__Entity__) ASSERT e.id IS UNIQUE")
                print("已使用旧语法创建__Entity__.id唯一性约束")
            except Exception as e2:
                print(f"使用旧语法创建约束也失败: {e2}")

def import_entities(df_entities, batch_size=100, max_workers=8):
    """
    导入实体(Entity)到Neo4j
    
    参数:
    - df_entities: 包含实体数据的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """
    # 1. 创建Entity的约束
    setup_entity_constraints()
    
    # 2. 预处理text_unit_ids - 确保是列表格式
    print("预处理text_unit_ids...")
    
    # 创建DataFrame的副本
    df_entities = df_entities.copy()
    
    # 处理text_unit_ids字段
    for idx, row in df_entities.iterrows():
        text_unit_ids = row.get('text_unit_ids')
        
        # 如果不是列表，转换为列表
        if not isinstance(text_unit_ids, list):
            if isinstance(text_unit_ids, str):
                try:
                    # 尝试解析JSON字符串
                    import json
                    text_unit_ids = json.loads(text_unit_ids)
                except:
                    # 如果解析失败，将其作为单个元素的列表
                    text_unit_ids = [text_unit_ids]
            elif hasattr(text_unit_ids, 'dtype') and hasattr(text_unit_ids, 'tolist'):
                # 处理NumPy数组
                text_unit_ids = text_unit_ids.tolist()
            else:
                # 其他类型，转为列表
                text_unit_ids = [text_unit_ids] if text_unit_ids is not None else []
        
        # 处理嵌套列表
        flat_text_unit_ids = []
        for item in text_unit_ids:
            if isinstance(item, list) or (hasattr(item, 'dtype') and hasattr(item, 'tolist')):
                if hasattr(item, 'tolist'):
                    flat_text_unit_ids.extend(item.tolist())
                else:
                    flat_text_unit_ids.extend(item)
            else:
                flat_text_unit_ids.append(item)
        
        # 确保所有ID都是字符串且非空
        flat_text_unit_ids = [str(id) for id in flat_text_unit_ids if id is not None and str(id).strip() != '']
        
        # 更新DataFrame
        df_entities.at[idx, 'text_unit_ids'] = flat_text_unit_ids
    
    # 3. 检查Neo4j功能支持
    print("检查Neo4j功能支持...")
    has_apoc = False
    has_vector = False
    
    try:
        with driver.session(database=NEO4J_DATABASE) as session:
            # 检查APOC
            try:
                result = session.run("RETURN apoc.version() AS version")
                version = result.single()["version"]
                has_apoc = True
                print(f"APOC插件已安装，版本: {version}")
            except Exception as e:
                print(f"检查APOC插件时出错 (可能未安装): {e}")
            
    except Exception as e:
        print(f"检查Neo4j功能支持时出错: {e}")
    
    # 4. 导入Entity节点并创建关系
    print("开始导入__Entity__节点并创建关系...")
    
    # 根据功能支持构建Cypher语句
    if has_apoc and has_vector:
        # 完整功能支持
        entity_statement = """
        MERGE (e:__Entity__ {id:value.id})
        SET e += value {.human_readable_id, .description, .frequency, .degree, .x, .y}
        SET e.name = replace(coalesce(value.title, value.human_readable_id, ''), '"', '')
        
        WITH e, value
        CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
        
        WITH e, value
        CALL apoc.create.addLabels(e, 
            CASE WHEN coalesce(value.type,"") = "" 
            THEN [] 
            ELSE [apoc.text.upperCamelCase(replace(value.type,'"',''))] 
            END
        ) YIELD node
        
        WITH node as e, value
        UNWIND value.text_unit_ids AS text_unit
        MATCH (c:__Chunk__ {id:text_unit})
        MERGE (c)-[:HAS_ENTITY]->(e)
        """
    elif has_apoc:
        # 只有APOC支持，没有向量支持
        entity_statement = """
        MERGE (e:__Entity__ {id:value.id})
        SET e += value {.human_readable_id, .description, .frequency, .degree, .x, .y}
        SET e.name = replace(coalesce(value.title, value.human_readable_id, ''), '"', '')
        
        WITH e, value
        CALL apoc.create.addLabels(e, 
            CASE WHEN coalesce(value.type,"") = "" 
            THEN [] 
            ELSE [apoc.text.upperCamelCase(replace(value.type,'"',''))] 
            END
        ) YIELD node
        
        WITH node as e, value
        UNWIND value.text_unit_ids AS text_unit
        MATCH (c:__Chunk__ {id:text_unit})
        MERGE (c)-[:HAS_ENTITY]->(e)
        """
    elif has_vector:
        # 只有向量支持，没有APOC支持
        entity_statement = """
        MERGE (e:__Entity__ {id:value.id})
        SET e += value {.human_readable_id, .description, .frequency, .degree, .x, .y}
        SET e.name = replace(coalesce(value.title, value.human_readable_id, ''), '"', '')
        
        WITH e, value
        CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
        
        WITH e, value
        UNWIND value.text_unit_ids AS text_unit
        MATCH (c:__Chunk__ {id:text_unit})
        MERGE (c)-[:HAS_ENTITY]->(e)
        """
    else:
        # 基本功能，无APOC和向量支持
        entity_statement = """
        MERGE (e:__Entity__ {id:value.id})
        SET e += value {.human_readable_id, .description, .frequency, .degree, .x, .y}
        SET e.name = replace(coalesce(value.title, value.human_readable_id, ''), '"', '')
        
        WITH e, value
        UNWIND value.text_unit_ids AS text_unit
        MATCH (c:__Chunk__ {id:text_unit})
        MERGE (c)-[:HAS_ENTITY]->(e)
        """
    
    # 执行导入
    entity_result = parallel_batched_import(entity_statement, df_entities, batch_size, max_workers)
    
    # 5. 验证结果
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Entity节点数量
        result = session.run("MATCH (e:__Entity__) RETURN count(e) as count")
        entity_count = result.single()["count"]
        
        # 检查HAS_ENTITY关系数量
        result = session.run("MATCH (c:__Chunk__)-[r:HAS_ENTITY]->(e:__Entity__) RETURN count(r) as count")
        relation_count = result.single()["count"]
        
        # 检查动态标签
        result = session.run("CALL db.labels() YIELD label WHERE label <> '__Entity__' AND label <> '__Chunk__' AND label <> '__Document__' RETURN collect(label) as labels")
        dynamic_labels = result.single()["labels"]
        
        print(f"验证结果: {entity_count} 个__Entity__节点, {relation_count} 个HAS_ENTITY关系")
        print(f"动态标签: {dynamic_labels}")
    
    return entity_result

# %% [markdown]
# &emsp;&emsp;如果需要安装`apoc`插件，可以进入该地址：https://github.com/neo4j/apoc/releases， 下载对应的版本，然后将其放置在`Neo4j`的`plugins`文件夹下，重启`Neo4j`即可。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131146422.png" width=80%></div>

# %%
NEO4J_URI="bolt://localhost"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="87654321"
NEO4J_DATABASE="neo4j"

driver = GraphDatabase.driver(
    NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )


# 导入实体
import_entities(df_entities, batch_size=100, max_workers=8)
# Out:
# 已创建__Entity__.id唯一性约束
# 预处理text_unit_ids...
# 检查Neo4j功能支持...
# APOC插件已安装，版本: 2025.06.2
# 开始导入__Entity__节点并创建关系...
# 开始并行导入 106 行数据，分为 2 个批次，每批 100 条
# 批次 1 完成: 6 行, 耗时 1.88秒
# 进度: 1/2 批次完成 (50.0%)
# 批次 0 完成: 100 行, 耗时 3.20秒
# 进度: 2/2 批次完成 (100.0%)
# 导入完成: 总计 106 行, 成功 106 行, 失败 0 行
# 总耗时: 3.20秒, 平均速度: 33.14 行/秒
# 验证结果: 106 个__Entity__节点, 143 个HAS_ENTITY关系
# 动态标签: ['Person', 'Company', 'Student', 'Organization', 'Geo', 'Event']
# {'total_rows': 106,
#  'successful_rows': 106,
#  'failed_rows': 0,
#  'duration_seconds': 3.198157548904419,
#  'rows_per_second': 33.14408323514645,
#  'batch_results': [{'batch': 1,
#    'rows': 6,
#    'success': True,
#    'duration': 1.8848140239715576,
#    'counters': {'_contains_updates': True, 'labels_added': 6, 'relationships_created': 6, 'nodes_created': 6, 'properties_set': 48}},
#   {'batch': 0,
#    'rows': 100,
#    'success': True,
#    'duration': 3.1964495182037354,
#    'counters': {'_contains_updates': True, 'labels_added': 100, 'relationships_created': 137, 'nodes_created': 100, 'properties_set': 800}}]}

# %% [markdown]
# &emsp;&emsp;执行完成后，可以在`localhost:7474`的`Neo4j`浏览器中，可以看到会根据`type`字段，创建了不同的标签。同时，`__Entity__`节点与`__Chunk__`节点之间，也创建了`HAS_ENTITY`关系。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121911563.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了`entities.parquet`文件的导入。接下来，我们开始导入`relationships.parquet`文件。

# %% [markdown]
# ## 4.5 导入关系

# %% [markdown]
# &emsp;&emsp;在`relationships.parquet`文件中，主要存储的是通过提示词，借助大模型从`text_units`中提取出来的关系。读取该文件的代码如下所示：

# %%
# 使用绝对路径读取 Parquet 文件
df_relations = pd.read_parquet('relationships.parquet')  # 替换为实际路径

# 假设 df 是你的 DataFrame
print(tabulate(df_relations, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+----------------+----------------------+----------------------+--------+-----------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | id                   | human_readable_id | source         | target               | description          | weight | combined_degree | text_unit_ids                                                                                                                        |
# +----------------------+-------------------+----------------+----------------------+----------------------+--------+-----------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | 09d7a448-7d00-47b8-b | 0                 | APPLE INC.     | STEVE JOBS           | Steve Jobs co-       | 9.0    | 13              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 9b6-471cc6c29c55     |                   |                |                      | founded Apple Inc.   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | and played a key     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | role in its growth   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | and innovation       |        |                 |                                                                                                                                      |
# | bbbdb1fe-5c09-4dfd-9 | 1                 | APPLE INC.     | STEVE WOZNIAK        | Steve Wozniak co-    | 9.0    | 8               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 7c9-faf3924e7678     |                   |                |                      | founded Apple Inc.   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | and contributed to   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | the development of   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | its early products   |        |                 |                                                                                                                                      |
# | bfe79d79-b3f1-40a4-a | 2                 | APPLE INC.     | RON WAYNE            | Ron Wayne co-founded | 6.0    | 8               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 91b-a926e3d7a0e7     |                   |                |                      | Apple Inc. but left  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | the company shortly  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | after its founding   |        |                 |                                                                                                                                      |
# | 3bdfb17e-16de-48f0-b | 3                 | APPLE INC.     | CUPERTINO            | Apple Inc. was       | 8.0    | 10              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 2ba-737fad5fd12b     |                   |                |                      | founded in           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Cupertino,           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | California, in 1976  |        |                 |                                                                                                                                      |
# | f44ec3d3-f4e3-4278-b | 4                 | APPLE INC.     | SILICON VALLEY       | Apple Inc. is a      | 8.0    | 14              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 887-55c03c0af3fd     |                   |                |                      | prominent company    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | based in Silicon     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Valley, a global     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | center for           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | technology           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | innovation           |        |                 |                                                                                                                                      |
# | 7b66e3bc-1923-4995-8 | 5                 | APPLE INC.     | APPLE I              | The Apple I was the  | 9.0    | 9               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 82b-2565cd44654b     |                   |                |                      | first product        |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | released by Apple    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Inc. in 1976         |        |                 |                                                                                                                                      |
# | 2da622b4-44f0-4c66-b | 6                 | APPLE INC.     | MACINTOSH            | The Macintosh was a  | 1.0    | 9               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 0c6-dfb88d31d9e2     |                   |                |                      | revolutionary        |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | product released by  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Apple Inc. in 1984   |        |                 |                                                                                                                                      |
# | 8f3f2643-27ab-4ece-  | 7                 | CUPERTINO      | CALIFORNIA           | Cupertino is a city  | 9.0    | 5               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | bae4-35fa36c47450    |                   |                |                      | located in the state |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | of California        |        |                 |                                                                                                                                      |
# | 7426d0b5-8e54-4875-b | 8                 | SILICON VALLEY | GOOGLE               | Google is a          | 8.0    | 15              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 07c-092586f6bcea     |                   |                |                      | prominent company    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | based in Silicon     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Valley, a global     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | center for           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | technology           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | innovation           |        |                 |                                                                                                                                      |
# | 4c35d813-36ba-4823-9 | 9                 | SILICON VALLEY | MICROSOFT            | Microsoft has a      | 7.0    | 17              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | cde-c11c65b60d71     |                   |                |                      | significant presence |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | in Silicon Valley, a |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | global center for    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | technology           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | innovation           |        |                 |                                                                                                                                      |
# | b654f769-e0a8-440e-a | 10                | SILICON VALLEY | AMAZON               | Amazon has a         | 7.0    | 16              | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | ef3-0818fea43f5a     |                   |                |                      | presence in Silicon  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Valley, a global     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | center for           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | technology           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | innovation           |        |                 |                                                                                                                                      |
# | eed51419-f167-4105-9 | 11                | SILICON VALLEY | CALIFORNIA           | Silicon Valley is a  | 1.0    | 9               | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] |
# | 99b-72c083f5d22f     |                   |                |                      | region located in    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | the state of         |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | California           |        |                 |                                                                                                                                      |
# | c97d7e94-d8aa-4c46-b | 12                | APPLE          | STEVE JOBS           | Steve Jobs co-       | 9.0    | 15              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | efd-ad2704ffc056     |                   |                |                      | founded Apple and    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | led the company to   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | develop              |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | revolutionary        |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | products.            |        |                 |                                                                                                                                      |
# | 48d8bc4b-09c2-410b-b | 13                | APPLE          | CUPERTINO            | Apple was founded in | 8.0    | 12              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | b3f-63435a0fa52e     |                   |                |                      | a garage in          |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Cupertino,           |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | California.          |        |                 |                                                                                                                                      |
# | cffabb9c-7278-4942-9 | 14                | APPLE          | MACINTOSH            | Apple launched the   | 7.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | 726-9ba78e19160e     |                   |                |                      | Macintosh in 1984,   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | revolutionizing      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | human-computer       |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | interaction.         |        |                 |                                                                                                                                      |
# | b45e85e5-85e0-41da-8 | 15                | APPLE          | IPHONE               | Apple released the   | 9.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | a14-c2a59fadf6e7     |                   |                |                      | iPhone in 2007,      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | marking the          |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | beginning of the     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | smartphone era.      |        |                 |                                                                                                                                      |
# | d9aca59f-9c0c-4f25-a | 16                | APPLE          | APPLE I              | Apple released its   | 8.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | 483-41e864d5bd9e     |                   |                |                      | first product, the   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Apple I, in 1976.    |        |                 |                                                                                                                                      |
# | efaf3a05-b112-4cd7-9 | 17                | APPLE          | IMAC                 | Apple launched the   | 7.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | 680-23ce2986b6a7     |                   |                |                      | iMac after Steve     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Jobs returned to the |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | company in 1997.     |        |                 |                                                                                                                                      |
# | 5b03f5d1-9923-4af4-a | 18                | APPLE          | IPOD                 | Apple launched the   | 8.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | b85-f1960dddc966     |                   |                |                      | iPod, which          |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | revolutionized the   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | music industry.      |        |                 |                                                                                                                                      |
# | 7ee3517c-4f5e-43e9-9 | 19                | APPLE          | IPAD                 | Apple launched the   | 8.0    | 11              | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | f57-bf4b54a325c3     |                   |                |                      | iPad, creating a new |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | category of consumer |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | electronics.         |        |                 |                                                                                                                                      |
# | ecaa7159-de2e-4ffc-a | 20                | STEVE JOBS     | IMAC                 | Steve Jobs led the   | 8.0    | 8               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | 465-9a690e68c7d9     |                   |                |                      | development and      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | launch of the iMac   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | after returning to   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Apple in 1997.       |        |                 |                                                                                                                                      |
# | f58a7cd9-ede4-4e98-b | 21                | STEVE JOBS     | IPHONE               | Steve Jobs played a  | 9.0    | 8               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | eec-ec0760febd40     |                   |                |                      | key role in the      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | development and      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | launch of the iPhone |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | in 2007.             |        |                 |                                                                                                                                      |
# | 0a05778f-979f-40af-  | 22                | STEVE JOBS     | IPOD                 | Steve Jobs led the   | 8.0    | 8               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | ab60-6f88253993e6    |                   |                |                      | development and      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | launch of the iPod,  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | which revolutionized |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | the music industry.  |        |                 |                                                                                                                                      |
# | a3ec056a-7619-46bc-9 | 23                | STEVE JOBS     | IPAD                 | Steve Jobs played a  | 1.0    | 8               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |
# | 866-3dff737009f5     |                   |                |                      | key role in the      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | development and      |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | launch of the iPad.  |        |                 |                                                                                                                                      |
# | 816ab210-aea3-433e-8 | 24                | GOOGLE         | LARRY PAGE           | Larry Page 是 Google | 29.0   | 9               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'  |
# | 54c-a6efc3e139f1     |                   |                |                      | 的联合创始人之一。Go |        |                 |  'f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# |                      |                   |                |                      | ogle 最初是一个搜索  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 引擎，后来扩展到人工 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 智能等多个领域。Larr |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | y Page 在 Google 的  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 创立和发展中扮演了重 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 要角色，推动了公司从 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 搜索引擎到多元化科技 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 巨头的转型。         |        |                 |                                                                                                                                      |
# | 04451dca-feca-4190-b | 25                | GOOGLE         | SERGEY BRIN          | Sergey Brin 是       | 21.0   | 9               | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'  |
# | 212-e9f72aed3cf7     |                   |                |                      | Google 的联合创始人  |        |                 |  'f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# |                      |                   |                |                      | 之一。Google 最初是  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 一个搜索引擎，后来扩 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 展到人工智能领域。这 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 一描述整合了所有提供 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 的信息，突出了       |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Sergey Brin 在       |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Google 创立和发展中  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 的关键角色，以及     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | Google 从搜索引擎到  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 人工智能的多元化发展 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 历程。               |        |                 |                                                                                                                                      |
# | 78aced59-d1bc-4da2-9 | 26                | GOOGLE         | MENLO PARK           | Google was founded   | 16.0   | 9               | ['f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# | b5b-934d9e0fac60     |                   |                |                      | in Menlo Park,       |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | California           |        |                 |                                                                                                                                      |
# | a50981c3-a09c-41df-8 | 27                | GOOGLE         | YOUTUBE              | Google acquired      | 18.0   | 10              | ['f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# | bbb-4570ed98ccb4     |                   |                |                      | YouTube in 2006,     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | becoming a leader in |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | online video         |        |                 |                                                                                                                                      |
# | 48435746-58cb-46e9-a | 28                | GOOGLE         | ANDROID              | Google launched the  | 18.0   | 10              | ['f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# | 130-586db4ef4ac3     |                   |                |                      | Android operating    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | system in 2007, now  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | the most popular     |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | mobile OS globally   |        |                 |                                                                                                                                      |
# | 0955e0aa-9a69-4147-8 | 29                | GOOGLE         | NASDAQ               | Google went public   | 2.0    | 10              | ['f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |
# | a5a-ff003e746a8f     |                   |                |                      | on NASDAQ in 2004,   |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | raising over $1.6    |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | billion              |        |                 |                                                                                                                                      |
# | 78e40a5d-9796-4a3b-9 | 30                | 谷歌           | YOUTUBE              | 谷歌于2006年收购了Yo | 8.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | 589-6b170ef4ccf7     |                   |                |                      | uTube，成为在线视频  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 领域的领导者         |        |                 |                                                                                                                                      |
# | 7dc834ae-a064-431b-8 | 31                | 谷歌           | ANDROID              | 谷歌于2007年推出了An | 9.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | 43b-77d5deda96c1     |                   |                |                      | droid操作系统，现已  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 成为全球最流行的移动 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 操作系统             |        |                 |                                                                                                                                      |
# | 3700ad70-3f89-48c9-b | 32                | 谷歌           | ALPHAGO              | 谷歌开发了AlphaGo，2 | 7.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | a47-041654d378d2     |                   |                |                      | 016年击败了世界围棋  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 冠军李世石           |        |                 |                                                                                                                                      |
# | 7aa559c4-6d37-45a8-b | 33                | 谷歌           | 李世石               | 谷歌开发的AlphaGo击  | 1.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | 7de-d39a76ce4ff9     |                   |                |                      | 败了世界围棋冠军李世 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 石                   |        |                 |                                                                                                                                      |
# | a95ab5d3-0627-4b21-a | 34                | ALPHAGO        | 李世石               | AlphaGo在2016年击败  | 9.0    | 4               | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | ab3-d37cb154873a     |                   |                |                      | 了世界围棋冠军李世石 |        |                 |                                                                                                                                      |
# | f4e0d9af-5a23-4e51-9 | 35                | 微软           | 比尔·盖茨            | 比尔·盖茨是微软的联  | 9.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | e73-1e0d22cf05e6     |                   |                |                      | 合创始人之一         |        |                 |                                                                                                                                      |
# | 37f03eb1-7a1f-4461-8 | 36                | 微软           | 保罗·艾伦            | 保罗·艾伦是微软的联  | 9.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | 282-2d586c56fb4c     |                   |                |                      | 合创始人之一         |        |                 |                                                                                                                                      |
# | 7e1428dc-4758-41e2-9 | 37                | 微软           | 美国华盛顿州雷德蒙德 | 微软于1975年在美国华 | 8.0    | 10              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | f8f-6732a35b3b54     |                   |                |                      | 盛顿州雷德蒙德创立   |        |                 |                                                                                                                                      |
# | 1f3c29b7-70c4-4354-a | 38                | 微软           | MS-DOS               | 微软于1981年发布了MS | 8.0    | 11              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# | 630-66581b98f6e2     |                   |                |                      | -DOS操作系统         |        |                 |                                                                                                                                      |
# | 612fcffc-84a6-4351-a | 39                | 微软           | WINDOWS              | 微软于1985年推出了Wi | 1.0    | 11              | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] |
# ...
# |                      |                   |                |                      | 人工智能领域         |        |                 |                                                                                                                                      |
# | 4978e0f0-47f1-4077-b | 109               | 抖音（TIKTOK） | 字节跳动             | 字节跳动是抖音（TikT | 1.0    | 7               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 03b-42780214e087     |                   |                |                      | ok）的母公司         |        |                 |                                                                                                                                      |
# | ba5b8a24-4700-4af6-b | 110               | 中融小贷       | 字节跳动             | 字节跳动收购中融小贷 | 1.0    | 6               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | f32-2f289c14a7cd     |                   |                |                      | 以获得金融牌照       |        |                 |                                                                                                                                      |
# | f7232764-49e3-4749-b | 111               | 云雀（LARK）   | 字节跳动             | 字节跳动是云雀（Lark | 1.0    | 6               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | c34-e73d4ebb51fd     |                   |                |                      | ）的母公司           |        |                 |                                                                                                                                      |
# | 21a000d1-08df-426f-8 | 112               | 中关村科技园   | 清华大学             | 清华大学为中关村科技 | 1.0    | 6               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 3df-fa12b40d6662     |                   |                |                      | 园提供人才储备       |        |                 |                                                                                                                                      |
# | 3bf6e536-8f3a-4920-9 | 113               | 中关村科技园   | 浙江大学             | 浙江大学为中关村科技 | 1.0    | 6               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 7fb-4462ff49c810     |                   |                |                      | 园提供人才储备       |        |                 |                                                                                                                                      |
# | 82ccd44f-6a69-4597-8 | 114               | 中关村科技园   | 双创政策             | 双创政策催生中关村科 | 1.0    | 5               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 1bb-5dc9704d6f1a     |                   |                |                      | 技园的孵化器模式     |        |                 |                                                                                                                                      |
# | e0b421cb-582e-4bbb-8 | 115               | 中关村科技园   | 科创板               | 科创板为中关村科技园 | 1.0    | 5               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 552-bb5a4308cd8f     |                   |                |                      | 的科技企业提供融资通 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 道                   |        |                 |                                                                                                                                      |
# | 1e189014-4f0a-40c8-b | 116               | 粤港澳大湾区   | 清华大学             | 清华大学为粤港澳大湾 | 1.0    | 4               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 8e0-16bbc74bb6e6     |                   |                |                      | 区提供人才储备       |        |                 |                                                                                                                                      |
# | d9a0fce1-e783-4f6c-8 | 117               | 粤港澳大湾区   | 浙江大学             | 浙江大学为粤港澳大湾 | 1.0    | 4               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 435-e9965645b2f6     |                   |                |                      | 区提供人才储备       |        |                 |                                                                                                                                      |
# | 77a6bfa4-eb73-4172-8 | 118               | 华为           | 小米                 | 华为和小米在智能手机 | 8.0    | 11              | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'  |
# | f25-1727f2e6a1b1     |                   |                |                      | 市场中存在激烈的竞争 |        |                 |  'ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# |                      |                   |                |                      | 关系。尽管两者在市场 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 上互为竞争对手，但它 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 们也共同参与了开放原 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 子开源基金会，显示出 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 在某些领域中的合作意 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 愿。这种竞争与合作并 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 存的关系体现了两家公 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 司在科技行业中的复杂 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 互动。               |        |                 |                                                                                                                                      |
# | 45ada7a6-a142-4a69-a | 119               | 华为           | 开放原子开源基金会   | 华为参与开放原子开源 | 1.0    | 11              | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 480-b349ac12443c     |                   |                |                      | 基金会               |        |                 |                                                                                                                                      |
# | 26e08050-bb60-4740-b | 120               | 小米           | 开放原子开源基金会   | 小米参与开放原子开源 | 1.0    | 4               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | 1ab-b4fe2109d3aa     |                   |                |                      | 基金会               |        |                 |                                                                                                                                      |
# | e0847183-782a-4221-9 | 121               | 阿里巴巴       | 腾讯会议             | 阿里巴巴的钉钉与腾讯 | 7.0    | 8               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'  |
# | e46-334dffa13f15     |                   |                |                      | 会议在协同办公领域竞 |        |                 |  'ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# |                      |                   |                |                      | 争                   |        |                 |                                                                                                                                      |
# | 3a57baab-f6bf-4aab-  | 122               | 阿里巴巴       | 钉钉                 | 钉钉是阿里巴巴旗下的 | 1.0    | 7               | ['115274092015190a0c5f38b887dce5d094af773d03db43339372050a36fc7fde1ad1308fb2d5e18cbdf8cd7e17469e5194f7b4d8290213413255be7c3dc5e97a'] |
# | bbdc-c918ba0aaee0    |                   |                |                      | 协同办公工具         |        |                 |                                                                                                                                      |
# | db1b1497-aa98-47c5-8 | 123               | 阿里巴巴       | 华为云               | 阿里巴巴的钉钉使用华 | 8.0    | 7               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | aaa-401750e26aa0     |                   |                |                      | 为云基础设施         |        |                 |                                                                                                                                      |
# | a77b0512-5e92-4236-8 | 124               | 腾讯会议       | 华为云               | 腾讯会议使用华为云基 | 8.0    | 5               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | 920-4e26d76e8db9     |                   |                |                      | 础设施               |        |                 |                                                                                                                                      |
# | 99816e0d-56f7-48cc-8 | 125               | 腾讯会议       | 钉钉                 | 钉钉与腾讯会议在协同 | 6.0    | 5               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | 2e2-86f5fd642beb     |                   |                |                      | 办公领域竞争         |        |                 |                                                                                                                                      |
# | c925feb3-2dc6-4fc3-8 | 126               | 寒武纪         | 中芯国际             | 寒武纪的思元370芯片  | 7.0    | 2               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | 21f-3a90d65de28a     |                   |                |                      | 与中芯国际的7nm工艺  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 突破共同加速了国产化 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 进程                 |        |                 |                                                                                                                                      |
# | 0bda819b-a2c1-4e9c-9 | 127               | 百度           | 商汤科技             | 百度的“文心一言”大模 | 1.0    | 2               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | 330-7e1d08dd0c96     |                   |                |                      | 型和商汤科技的SenseN |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | ova平台共同重塑AI产  |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 业生态               |        |                 |                                                                                                                                      |
# | 6812e8c8-160f-4f32-b | 128               | 思元370芯片    | 7NM工艺              | 思元370芯片与7nm工艺 | 7.0    | 2               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | b31-21453b5a1cec     |                   |                |                      | 共同代表国产化进程的 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 突破                 |        |                 |                                                                                                                                      |
# | 975eb9d9-230d-4bf9-a | 129               | 文心一言       | SENSENOVA平台        | 文心一言与SenseNova  | 1.0    | 2               | ['ce107dd1f1c26ce2073fdb34877c6ca82fed3205d49df55738513411bf0e423971a7a6e80396e4cba4ae8dca7a8afb90ea6d9830f5d62a342c1d0de07766f3fe'] |
# | 5c0-0fc8509517e2     |                   |                |                      | 平台共同重塑AI产业生 |        |                 |                                                                                                                                      |
# |                      |                   |                |                      | 态                   |        |                 |                                                                                                                                      |
# +----------------------+-------------------+----------------+----------------------+----------------------+--------+-----------------+--------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# &emsp;&emsp;各个字段的解释如下所示：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>relationships DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个关系记录。                       |
# | human_readable_id   | 字符串             | 可读的标识符，通常用于用户界面显示，便于用户理解和识别。   |
# | source              | 字符串             | 关系的源实体，表示关系的起始节点。                         |
# | target              | 字符串             | 关系的目标实体，表示关系的结束节点。                       |
# | description         | 字符串             | 对关系的详细描述，提供更多上下文信息。                     |
# | weight              | 浮点数             | 关系的权重，通常用于表示关系的重要性或强度。               |
# | combined_degree     | 整数               | 关系的组合度，表示与其他实体的连接数量。                   |
# | text_unit_ids       | 列表（字符串）     | 关联的文本单元的唯一标识符列表，通常用于将关系与文本关联。 |
#
# </div>

# %% [markdown]
# &emsp;&emsp;在知识图谱构建过程中，我们可以使用已经创建好的`__Entity__`节点，然后根据`source`和`target`字段，创建关系。其导入策略可以考虑以下原则：
#
# - **节点标识**：需要使用`id`字段作为Relationship节点的唯一标识符，确保图谱中关系节点一致性。
# - **约束策略**：唯一性约束，确保关系的id是唯一的。
# - **属性选择**：比如关系的描述，权重，组合度等，根据需求选择。
# - **关系策略**：查找两个实体节点（source 和 target），创建或更新这两个实体之间的 RELATED 关系。

# %% [markdown]
# &emsp;&emsp;因此，把上述的策略转化成代码。就如下所示：其中比较关键的是：
#
# - RELATED关系：连接两个__Entity__节点，表示实体之间的直接语义关系，例如：(Person:Entity)-[:RELATED]->(Company:Entity)
# - HAS_RELATIONSHIP关系：连接__Chunk__节点和__Relationship__节点，表示某个文本块中提到了某种关系，例如：(TextChunk:Chunk)-[:HAS_RELATIONSHIP]->(EntityRelationship:Relationship)

# %%
def setup_relationship_constraints():
    """创建Relationship标签的约束"""
    with driver.session(database=NEO4J_DATABASE) as session:
        try:
            # 创建Relationship.id唯一性约束
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (r:__Relationship__) REQUIRE r.id IS UNIQUE")
            print("已创建__Relationship__.id唯一性约束")
        except Exception as e:
            print(f"创建__Relationship__约束时出错 (可能已存在): {e}")
            # 尝试旧版本Neo4j的语法
            try:
                session.run("CREATE CONSTRAINT ON (r:__Relationship__) ASSERT r.id IS UNIQUE")
                print("已使用旧语法创建__Relationship__.id唯一性约束")
            except Exception as e2:
                print(f"使用旧语法创建约束也失败: {e2}")

def import_relationships(df_relationships, batch_size=100, max_workers=8):
    """
    导入关系数据到Neo4j
    
    参数:
    - df_relationships: 包含关系数据的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """
    # 1. 创建Relationship的约束
    setup_relationship_constraints()
    
    # 2. 检查标签和节点是否存在
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Entity和Chunk节点数量
        result = session.run("MATCH (e:__Entity__) RETURN count(e) as count")
        entity_count = result.single()["count"]
        
        result = session.run("MATCH (c:__Chunk__) RETURN count(c) as count")
        chunk_count = result.single()["count"]
        
        print(f"节点数量: {entity_count} 个__Entity__节点, {chunk_count} 个__Chunk__节点")
        
        if entity_count == 0:
            print("没有__Entity__节点，请先导入Entity数据")
        
        if chunk_count == 0:
            print("没有__Chunk__节点，请先导入Chunk数据")
    
    # 3. 预处理text_unit_ids - 确保是列表格式
    print("预处理text_unit_ids...")
    
    # 创建DataFrame的副本
    df_relationships = df_relationships.copy()
    
    # 处理text_unit_ids字段
    for idx, row in df_relationships.iterrows():
        text_unit_ids = row.get('text_unit_ids')
        
        # 如果不是列表，转换为列表
        if not isinstance(text_unit_ids, list):
            if isinstance(text_unit_ids, str):
                try:
                    # 尝试解析JSON字符串
                    import json
                    text_unit_ids = json.loads(text_unit_ids)
                except:
                    # 如果解析失败，将其作为单个元素的列表
                    text_unit_ids = [text_unit_ids]
            elif hasattr(text_unit_ids, 'dtype') and hasattr(text_unit_ids, 'tolist'):
                # 处理NumPy数组
                text_unit_ids = text_unit_ids.tolist()
            else:
                # 其他类型，转为列表
                text_unit_ids = [text_unit_ids] if text_unit_ids is not None else []
        
        # 处理嵌套列表
        flat_text_unit_ids = []
        for item in text_unit_ids:
            if isinstance(item, list) or (hasattr(item, 'dtype') and hasattr(item, 'tolist')):
                if hasattr(item, 'tolist'):
                    flat_text_unit_ids.extend(item.tolist())
                else:
                    flat_text_unit_ids.extend(item)
            else:
                flat_text_unit_ids.append(item)
        
        # 确保所有ID都是字符串且非空
        flat_text_unit_ids = [str(id) for id in flat_text_unit_ids if id is not None and str(id).strip() != '']
        
        # 更新DataFrame
        df_relationships.at[idx, 'text_unit_ids'] = flat_text_unit_ids
    
    # 4. 验证source和target是否存在
    print("验证source和target实体...")
    sample_rows = df_relationships.head(min(5, len(df_relationships)))  # 取前5行进行验证
    
    with driver.session(database=NEO4J_DATABASE) as session:
        for _, row in sample_rows.iterrows():
            source_id = row['source']
            target_id = row['target']
            
            # 检查source实体
            result = session.run("MATCH (e:__Entity__ {id: $id}) RETURN count(e) as count", id=source_id)
            source_exists = result.single()["count"] > 0
            
            # 检查target实体
            result = session.run("MATCH (e:__Entity__ {id: $id}) RETURN count(e) as count", id=target_id)
            target_exists = result.single()["count"] > 0
            
            print(f"实体检查: source={source_id} {'存在' if source_exists else '不存在'}, target={target_id} {'存在' if target_exists else '不存在'}")
            
            if not source_exists or not target_exists:
                print("部分实体不存在，将在导入过程中创建")
    
    # 5. 导入关系数据
    print("开始导入关系数据...")
    
    # 分两步执行，先创建关系节点和实体间关系，再创建与Chunk的关系
    # 步骤1: 创建关系节点和实体间关系
    relationship_statement = """
    // 创建关系节点
    MERGE (r:__Relationship__ {id: value.id})
    SET r.human_readable_id = value.human_readable_id,
        r.description = value.description,
        r.weight = value.weight,
        r.combined_degree = value.combined_degree,
        r.name = value.human_readable_id
    
    // 查找或创建源实体和目标实体
    WITH r, value
    MERGE (source:__Entity__ {id: value.source})
    MERGE (target:__Entity__ {id: value.target})
    
    // 创建RELATED关系
    MERGE (source)-[rel:RELATED]->(target)
    SET rel.relationship_id = value.id,
        rel.description = value.description,
        rel.weight = value.weight
    
    RETURN r.id as relationship_id
    """
    
    # 执行导入关系节点和实体间关系
    relationship_result = parallel_batched_import(relationship_statement, df_relationships, batch_size, max_workers)
    print(f"已创建 {relationship_result['successful_rows']} 个__Relationship__节点和RELATED关系")
    
    # 步骤2: 创建与Chunk的关系
    # 准备Chunk关系数据
    chunk_relations = []
    for _, row in df_relationships.iterrows():
        rel_id = row['id']
        for chunk_id in row['text_unit_ids']:
            chunk_relations.append({
                'relationship_id': rel_id,
                'chunk_id': chunk_id
            })
    
    if chunk_relations:
        df_chunk_relations = pd.DataFrame(chunk_relations)
        
        # 创建Chunk到Relationship的关系
        chunk_rel_statement = """
        MATCH (r:__Relationship__ {id: value.relationship_id})
        MATCH (c:__Chunk__ {id: value.chunk_id})
        MERGE (c)-[:HAS_RELATIONSHIP]->(r)
        """
        
        # 执行导入Chunk关系
        chunk_rel_result = parallel_batched_import(chunk_rel_statement, df_chunk_relations, batch_size, max_workers)
        print(f"已创建 {chunk_rel_result['successful_rows']} 个Chunk-Relationship关系")
    else:
        print("没有找到有效的Chunk-Relationship关系数据")
    
    # 6. 验证结果
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Relationship节点数量
        result = session.run("MATCH (r:__Relationship__) RETURN count(r) as count")
        relationship_count = result.single()["count"]
        
        # 检查RELATED关系数量
        result = session.run("MATCH ()-[r:RELATED]->() RETURN count(r) as count")
        related_count = result.single()["count"]
        
        # 检查HAS_RELATIONSHIP关系数量
        try:
            result = session.run("MATCH (c:__Chunk__)-[r:HAS_RELATIONSHIP]->() RETURN count(r) as count")
            has_relationship_count = result.single()["count"]
        except Exception as e:
            print(f"查询HAS_RELATIONSHIP关系时出错: {e}")
            has_relationship_count = "未知"
        
        print(f"验证结果: {relationship_count} 个__Relationship__节点, {related_count} 个RELATED关系, {has_relationship_count} 个HAS_RELATIONSHIP关系")
    
    return relationship_result

# %%
# 导入关系
import_relationships(df_relations, batch_size=100, max_workers=8)
# Out:
# 已创建__Relationship__.id唯一性约束
# 节点数量: 106 个__Entity__节点, 16 个__Chunk__节点
# 预处理text_unit_ids...
# 验证source和target实体...
# 实体检查: source=APPLE INC. 不存在, target=STEVE JOBS 不存在
# 部分实体不存在，将在导入过程中创建
# 实体检查: source=APPLE INC. 不存在, target=STEVE WOZNIAK 不存在
# 部分实体不存在，将在导入过程中创建
# 实体检查: source=APPLE INC. 不存在, target=RON WAYNE 不存在
# 部分实体不存在，将在导入过程中创建
# 实体检查: source=APPLE INC. 不存在, target=CUPERTINO 不存在
# 部分实体不存在，将在导入过程中创建
# 实体检查: source=APPLE INC. 不存在, target=SILICON VALLEY 不存在
# 部分实体不存在，将在导入过程中创建
# 开始导入关系数据...
# 开始并行导入 130 行数据，分为 2 个批次，每批 100 条
# 批次 1 完成: 30 行, 耗时 1.02秒
# 进度: 1/2 批次完成 (50.0%)
# 批次 0 完成: 100 行, 耗时 1.60秒
# 进度: 2/2 批次完成 (100.0%)
# 导入完成: 总计 130 行, 成功 130 行, 失败 0 行
# 总耗时: 1.60秒, 平均速度: 81.32 行/秒
# 已创建 130 个__Relationship__节点和RELATED关系
# 开始并行导入 141 行数据，分为 2 个批次，每批 100 条
# 批次 1 完成: 41 行, 耗时 0.40秒
# 进度: 1/2 批次完成 (50.0%)
# 批次 0 完成: 100 行, 耗时 0.68秒
# 进度: 2/2 批次完成 (100.0%)
# 导入完成: 总计 141 行, 成功 141 行, 失败 0 行
# 总耗时: 0.68秒, 平均速度: 207.00 行/秒
# 已创建 141 个Chunk-Relationship关系
# 验证结果: 130 个__Relationship__节点, 130 个RELATED关系, 141 个HAS_RELATIONSHIP关系
# {'total_rows': 130,
#  'successful_rows': 130,
#  'failed_rows': 0,
#  'duration_seconds': 1.5987186431884766,
#  'rows_per_second': 81.31512105265041,
#  'batch_results': [{'batch': 1,
#    'rows': 30,
#    'success': True,
#    'duration': 1.019993782043457,
#    'counters': {'_contains_updates': True, 'labels_added': 64, 'relationships_created': 30, 'nodes_created': 64, 'properties_set': 304}},
#   {'batch': 0,
#    'rows': 100,
#    'success': True,
#    'duration': 1.5969271659851074,
#    'counters': {'_contains_updates': True, 'labels_added': 172, 'relationships_created': 100, 'nodes_created': 172, 'properties_set': 972}}]}

# %% [markdown]
# &emsp;&emsp;执行完成后，可以在`localhost:7474`的`Neo4j`浏览器中，可以看到会生成`__Relationship__`节点，同时，`__Entity__`节点与`__Chunk__`节点之间，也创建了`HAS_RELATIONSHIP`关系，以及`__Relationship__`节点与`__Entity__`节点之间，也创建了`RELATED`关系。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121928544.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了`relationships.parquet`文件的导入。接下来，我们开始导入`communities.parquet`文件。

# %% [markdown]
# ## 4.6 导入社区

# %% [markdown]
# &emsp;&emsp;在`communities.parquet`文件中，主要存储的通过莱顿社区发现算法，根据`settings.yaml` 文件中`cluster_graph`配置划分出的社区层级，同时通过后处理，对每个社区中包含的实体，关系，文本单元等进行关联。读取该文件的代码如下所示：

# %%
# 使用绝对路径读取 Parquet 文件
df_communities = pd.read_parquet('communities.parquet')  # 替换为实际路径

# 假设 df 是你的 DataFrame
print(tabulate(df_communities, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+-----------+-------+--------+------------+--------------+------------------------------------------+------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+------------+------+
# | id                   | human_readable_id | community | level | parent | children   | title        | entity_ids                               | relationship_ids                         | text_unit_ids                                                                                                                        | period     | size |
# +----------------------+-------------------+-----------+-------+--------+------------+--------------+------------------------------------------+------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+------------+------+
# | 14642d87-7570-47d3-8 | 0                 | 0         | 0     | -1     | [5 6]      | Community 0  | ['c4bf1c25-cdd2-4f05-b858-b485717fefa7'  | ['04451dca-feca-4190-b212-e9f72aed3cf7'  | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'  | 2025-03-12 | 10   |
# | ddc-d476fa9e5346     |                   |           |       |        |            |              |  '2c6ffa99-fffb-488f-b050-71deab7c150d'  |  '0955e0aa-9a69-4147-8a5a-ff003e746a8f'  |  'b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'  |            |      |
# |                      |                   |           |       |        |            |              |  '50b90370-f4b6-4a3f-a900-363c4c16de17'  |  '3700ad70-3f89-48c9-ba47-041654d378d2'  |  'f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |            |      |
# |                      |                   |           |       |        |            |              |  '51633ffb-8c01-4e96-be3a-13db4061e788'  |  '48435746-58cb-46e9-a130-586db4ef4ac3'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '42c8cae8-0e5c-4430-b859-595eb4ec584e'  |  '78aced59-d1bc-4da2-9b5b-934d9e0fac60'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '19aa98c5-8378-4a3e-ba84-3517a8517152'  |  '78e40a5d-9796-4a3b-9589-6b170ef4ccf7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '3646a409-05c8-43c1-8ae6-fdfbc2af796d'  |  '7aa559c4-6d37-45a8-b7de-d39a76ce4ff9'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'b3177da6-ac72-4c1f-8a43-b287d1be5b68'  |  '7dc834ae-a064-431b-843b-77d5deda96c1'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'f1d9e0cd-64d1-41c2-a03b-14aa8ce1730c'  |  '816ab210-aea3-433e-854c-a6efc3e139f1'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '606558ee-36d4-4626-9c42-7342dc8b1dc7'] |  'a50981c3-a09c-41df-8bbb-4570ed98ccb4'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'a95ab5d3-0627-4b21-aab3-d37cb154873a'] |                                                                                                                                      |            |      |
# | b5b26fdf-98ea-42c9-b | 1                 | 1         | 0     | -1     | [7 8 9]    | Community 1  | ['e1bf420e-8d58-4f6f-ad67-4b6d36587e53'  | ['09d7a448-7d00-47b8-b9b6-471cc6c29c55'  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  | 2025-03-12 | 13   |
# | 553-bf764d399c17     |                   |           |       |        |            |              |  'b50512b1-2314-4da1-88b4-7e8d6edc5364'  |  '0a05778f-979f-40af-ab60-6f88253993e6'  |  'b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] |            |      |
# |                      |                   |           |       |        |            |              |  'a1970ae2-2174-464c-8e6a-a69038276d4c'  |  '2da622b4-44f0-4c66-b0c6-dfb88d31d9e2'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'bc99b765-aaf4-45ea-9dc6-257093d1ff61'  |  '3bdfb17e-16de-48f0-b2ba-737fad5fd12b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'a54c2467-c3fd-44df-a8a1-8833a488e180'  |  '48d8bc4b-09c2-410b-bb3f-63435a0fa52e'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'c90a88ac-e1ae-4cb4-be79-adce4f21fa6b'  |  '5b03f5d1-9923-4af4-ab85-f1960dddc966'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '46b5a6ed-2d99-478a-b088-5cc746943c58'  |  '7b66e3bc-1923-4995-882b-2565cd44654b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'e46d6ac5-135f-41d5-b7db-a020eb6ccf67'  |  '7ee3517c-4f5e-43e9-9f57-bf4b54a325c3'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0e4861f4-29ec-4ddd-bf7d-a055a00e75a4'  |  '8f3f2643-27ab-4ece-bae4-35fa36c47450'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '4b2d9bf3-01d4-435c-9de5-8eb8744ffc11'  |  'a3ec056a-7619-46bc-9866-3dff737009f5'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '1d238b98-0667-4c09-8b39-831a9d63e2c7'  |  'b45e85e5-85e0-41da-8a14-c2a59fadf6e7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '2b44a251-58fc-48e0-bdcd-4fc9173adb3c'  |  'bbbdb1fe-5c09-4dfd-97c9-faf3924e7678'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'f368d1b9-3236-4167-85f8-c5501e58d2ac'] |  'bfe79d79-b3f1-40a4-a91b-a926e3d7a0e7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'c97d7e94-d8aa-4c46-befd-ad2704ffc056'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'cffabb9c-7278-4942-9726-9ba78e19160e'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'd9aca59f-9c0c-4f25-a483-41e864d5bd9e'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'ecaa7159-de2e-4ffc-a465-9a690e68c7d9'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'efaf3a05-b112-4cd7-9680-23ce2986b6a7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'f58a7cd9-ede4-4e98-beec-ec0760febd40'] |                                                                                                                                      |            |      |
# | 1faef61e-29fd-4c72-9 | 2                 | 2         | 0     | -1     | []         | Community 2  | ['249fccf6-e79a-43c8-b2b5-6ca1f6a3c2c1'  | ['28334e1f-9b88-41b8-b549-ec6775c4db2c'  | ['c74ed55a3ebcbc0bb18a6e60a119aab7efcf80364e115f5ce4157b1ac1a2aef7ac4d9f0b13ab35a02fdc3814716c37007baabe0eeb612481ae10ef89fdc45015'] | 2025-03-12 | 8    |
# | c87-8321df56ac70     |                   |           |       |        |            |              |  'c4892971-46e1-4a9f-8256-8414d812612d'  |  '2f1666d9-f6b9-44fc-b64e-59f939b62027'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'd2d860ef-f321-48e2-ac23-02cf5d15d48c'  |  '43e99a4d-ec4d-40ca-a828-21522bc90207'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'ea3bb2b4-cb0a-43f9-9fc0-9ea11ae8d727'  |  '70a6dc3c-3ea6-452c-8566-d7d488d580be'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'd1410226-961c-4fdd-8d76-e66aac46becb'  |  '7d06b858-4ce9-4765-a818-fee31c128d96'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '9a3c82d8-152a-438b-b3fa-0980dbcdaa53'  |  'e272da89-8c80-4c59-a7df-61469c5450a3'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'a5ef70b5-84e9-4cb8-b647-eedd9d69b279'  |  'e2d5aa30-4467-4025-929c-622a6a603e72'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'fbdceca3-e4ef-41df-bb34-e69434ad7eac'] |                                          |                                                                                                                                      |            |      |
# | a8260f47-7149-4b19-a | 3                 | 3         | 0     | -1     | [10 11]    | Community 3  | ['9054b1d2-40a3-4aab-9c0f-249edecf17dc'  | ['04c29a25-0ac7-4ef9-bf41-df1011c2a975'  | ['01434455979f8f5369ea62fdc2ff4ff1360677293c575d32f1672521daaee69a7f111448645d4c70464db9dbbbe3d009c42336fd2801161e3418c607aa4efc1d'  | 2025-03-12 | 11   |
# | fa1-804c0ce942ee     |                   |           |       |        |            |              |  '6d5bce0c-e166-460f-a432-879f253d4eda'  |  '3a6b6371-0afb-4ec2-9729-67f54ec18454'  |  '8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'  |            |      |
# |                      |                   |           |       |        |            |              |  'd7b3cafa-352a-464e-aa67-a58cc0cce3a2'  |  '4319e729-a0eb-4580-9ec0-73a2fe104afd'  |  'c4c5297b4bf585666851d3e50123a6e5dd9a6223b14675624752a2a3033ba6629af55fb798a18a2d6ecbb974baddbfb2eace4d6468971449b35c10fa5c1cc2cc'  |            |      |
# |                      |                   |           |       |        |            |              |  'd6d7881f-e57c-4f34-8f2b-ac6b1250a9a9'  |  '480a1038-c5a7-4df3-aea5-fba2f2e85953'  |  'c74ed55a3ebcbc0bb18a6e60a119aab7efcf80364e115f5ce4157b1ac1a2aef7ac4d9f0b13ab35a02fdc3814716c37007baabe0eeb612481ae10ef89fdc45015'] |            |      |
# |                      |                   |           |       |        |            |              |  'bfc9aac3-999b-49cb-b81e-6339836368d4'  |  '4de5bed7-b933-47fc-bddc-e325df3fad6a'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'af9a14ed-b907-4097-826e-fe106502d627'  |  '6ac1c842-fdfc-4edf-bc8e-8047520d4751'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '758325f0-6a01-487e-82e4-3fe8dc7dd3f9'  |  '7ca46970-b1a2-4592-98ac-17a28c3e8141'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'fb0ba0b2-b5fe-4a4d-a0d2-fdf0d2518c08'  |  '7f8dbd71-f326-4f25-812b-29466e517ece'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0d6ad177-3e6a-4cc5-bf6c-0c0e1a4683c7'  |  'b654f769-e0a8-440e-aef3-0818fea43f5a'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '8b0e3553-021a-4e25-9458-77f5ebe2a61f'  |  'ea35dc50-a02c-440e-9e9a-91184a4032f4'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '8384bbeb-0e91-4624-9ce1-fac0cfe9b59b'] |  'ecd94b0e-6e93-4a76-a9a5-c9638863c4c4'] |                                                                                                                                      |            |      |
# | a6ec85b9-2ede-4195-8 | 4                 | 4         | 0     | -1     | [12 13 14] | Community 4  | ['a75e5d6d-485d-43b5-a3cd-6d4cfd872342'  | ['0b5c0a92-c7d0-435a-9a3a-6c09bd48a2b6'  | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'  | 2025-03-12 | 14   |
# | 9d6-f4ca050a0c8c     |                   |           |       |        |            |              |  '9f736e48-1338-4b4c-aafb-327d6b30fd86'  |  '1f3c29b7-70c4-4354-a630-66581b98f6e2'  |  '975147fe6ddf0ae318e21d71cad00286ee9044ec244041b3a3e839c26181775b45e41409bfdae0451c7f506eb94dc9598f67ab941f8144e80075e0c72671b482'  |            |      |
# |                      |                   |           |       |        |            |              |  'e1454e36-6ef9-44b7-b642-0093038b32d5'  |  '2bb987ec-fbcd-4aac-8855-27558bf04620'  |  'd6053c77d9ebfd4d738edc8952fb42859160e8202285dc7775b30a9af0a21112d34c0fa090292a87f803dd2311ac0dcb97628989f4419b04eba30a25c1725299'  |            |      |
# |                      |                   |           |       |        |            |              |  '2d9bfc43-247c-447f-9463-c85496ddbf1d'  |  '37f03eb1-7a1f-4461-8282-2d586c56fb4c'  |  'ff294773b3428854364049d61157058e7f9de1a226375609c8b313aebd02b85757c543588bfd9af6a9fe5ce8b934d3f05568b9d546deea0526c032d061a7a1cd'] |            |      |
# |                      |                   |           |       |        |            |              |  '93762fdf-903f-442e-827b-947c8b9977e1'  |  '5fd25732-3f80-44ce-8278-fe658530b98b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '80a1b932-03ae-43a0-9bd7-37b6d74f36da'  |  '612fcffc-84a6-4351-aadb-735cfb6c2a5b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '3274ab5c-a872-4a9b-943c-a18cfbb2209f'  |  '6ac3a0c9-ce4a-4dd6-8554-d77d7c0cda89'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '9bf6c182-c48d-4bf4-9717-d64909a75391'  |  '74a8e607-9411-4968-adb1-6880f3741592'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '59b9f9dc-37ed-424e-bab0-b65edac21a41'  |  '7e1428dc-4758-41e2-9f8f-6732a35b3b54'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'e5255339-1528-44e2-add5-3f21316d5ccf'  |  '878166d3-3867-4ed6-a734-2cb3fa1d1109'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'ff1490e7-93d6-4f3e-bd04-aa20cf4d134b'  |  '8af7bc93-83d7-45c9-8d16-e2040410119b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '18b551ac-1aac-44be-abe5-d6270d4e5920'  |  'a884bad1-9af8-4881-b04b-4a2fc68d4fc0'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '85bf01f7-c57b-40d4-be01-5665a2d20470'  |  'bcd54b49-49a6-454e-bbe2-7cca0bc054db'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0e220816-9615-45a2-a7a3-563014c07af7'] |  'c95c5288-3e62-4a3e-b1f6-bb12de4f7107'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'cca81a4e-099b-47b3-9a35-4919323c17e8'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'f4e0d9af-5a23-4e51-9e73-1e0d22cf05e6'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'fb95600d-28c3-4999-8823-3b64fcfef2af'] |                                                                                                                                      |            |      |
# | 79f0fd88-7291-4b20-8 | 5                 | 5         | 1     | 0      | [15 16]    | Community 5  | ['c4bf1c25-cdd2-4f05-b858-b485717fefa7'  | ['3700ad70-3f89-48c9-ba47-041654d378d2'  | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] | 2025-03-12 | 5    |
# | 82e-5409c45b36ff     |                   |           |       |        |            |              |  '2c6ffa99-fffb-488f-b050-71deab7c150d'  |  '78e40a5d-9796-4a3b-9589-6b170ef4ccf7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '50b90370-f4b6-4a3f-a900-363c4c16de17'  |  '7aa559c4-6d37-45a8-b7de-d39a76ce4ff9'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '42c8cae8-0e5c-4430-b859-595eb4ec584e'  |  '7dc834ae-a064-431b-843b-77d5deda96c1'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '606558ee-36d4-4626-9c42-7342dc8b1dc7'] |  'a95ab5d3-0627-4b21-aab3-d37cb154873a'] |                                                                                                                                      |            |      |
# | 4318a641-0a78-462d-b | 6                 | 6         | 1     | 0      | []         | Community 6  | ['51633ffb-8c01-4e96-be3a-13db4061e788'  | ['04451dca-feca-4190-b212-e9f72aed3cf7'  | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'  | 2025-03-12 | 5    |
# | f9c-c664cdebbd2c     |                   |           |       |        |            |              |  '19aa98c5-8378-4a3e-ba84-3517a8517152'  |  '0955e0aa-9a69-4147-8a5a-ff003e746a8f'  |  'f3f52dc49c93ea0a43c6c483269624ed6227b53c15bf39a1fd8102227d44332fad53503232eff12494290e40dfdb114c8c1df2db601a555fec297639ec3d7a6a'] |            |      |
# |                      |                   |           |       |        |            |              |  '3646a409-05c8-43c1-8ae6-fdfbc2af796d'  |  '78aced59-d1bc-4da2-9b5b-934d9e0fac60'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'b3177da6-ac72-4c1f-8a43-b287d1be5b68'  |  '816ab210-aea3-433e-854c-a6efc3e139f1'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'f1d9e0cd-64d1-41c2-a03b-14aa8ce1730c'] |                                          |                                                                                                                                      |            |      |
# | e4b4e43c-be07-487c-b | 7                 | 7         | 1     | 1      | []         | Community 7  | ['e1bf420e-8d58-4f6f-ad67-4b6d36587e53'  | ['0a05778f-979f-40af-ab60-6f88253993e6'  | ['b0c0fdb9714ba7fb74bb0e162bfb90ec6bab1d5045057678d0d91b9d5f72936ae344577359ab5418f104f235cdef72f703ea06aa4b96976c1dfab32ef0000c00'] | 2025-03-12 | 6    |
# | 877-3f74e1355b8f     |                   |           |       |        |            |              |  'bc99b765-aaf4-45ea-9dc6-257093d1ff61'  |  '5b03f5d1-9923-4af4-ab85-f1960dddc966'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'a54c2467-c3fd-44df-a8a1-8833a488e180'  |  '7ee3517c-4f5e-43e9-9f57-bf4b54a325c3'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'c90a88ac-e1ae-4cb4-be79-adce4f21fa6b'  |  'a3ec056a-7619-46bc-9866-3dff737009f5'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '46b5a6ed-2d99-478a-b088-5cc746943c58'  |  'b45e85e5-85e0-41da-8a14-c2a59fadf6e7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0e4861f4-29ec-4ddd-bf7d-a055a00e75a4'] |  'c97d7e94-d8aa-4c46-befd-ad2704ffc056'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'ecaa7159-de2e-4ffc-a465-9a690e68c7d9'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'efaf3a05-b112-4cd7-9680-23ce2986b6a7'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |                                          |  'f58a7cd9-ede4-4e98-beec-ec0760febd40'] |                                                                                                                                      |            |      |
# | e56cb9f7-96fe-43ed-9 | 8                 | 8         | 1     | 1      | []         | Community 8  | ['a1970ae2-2174-464c-8e6a-a69038276d4c'  | ['8f3f2643-27ab-4ece-bae4-35fa36c47450'] | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 2025-03-12 | 2    |
# | 498-1c25df0cb8b0     |                   |           |       |        |            |              |  'f368d1b9-3236-4167-85f8-c5501e58d2ac'] |                                          |                                                                                                                                      |            |      |
# | bf01d766-bdc9-48d7-9 | 9                 | 9         | 1     | 1      | []         | Community 9  | ['b50512b1-2314-4da1-88b4-7e8d6edc5364'  | ['2da622b4-44f0-4c66-b0c6-dfb88d31d9e2'  | ['8f298209e463b21ab725bc5347cdeb4a33454e3d1cea78efdf96c3f5a26f19fd5477e4bc11589755e6e95b20dcb02bf29398715b473987f03271f5a6cb030d2b'] | 2025-03-12 | 5    |
# | 2bc-06257cf2d5c4     |                   |           |       |        |            |              |  'e46d6ac5-135f-41d5-b7db-a020eb6ccf67'  |  '7b66e3bc-1923-4995-882b-2565cd44654b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '4b2d9bf3-01d4-435c-9de5-8eb8744ffc11'  |  'bbbdb1fe-5c09-4dfd-97c9-faf3924e7678'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '1d238b98-0667-4c09-8b39-831a9d63e2c7'  |  'bfe79d79-b3f1-40a4-a91b-a926e3d7a0e7'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '2b44a251-58fc-48e0-bdcd-4fc9173adb3c'] |                                          |                                                                                                                                      |            |      |
# | cc8997cb-f5e4-4abc-8 | 10                | 10        | 1     | 3      | []         | Community 10 | ['9054b1d2-40a3-4aab-9c0f-249edecf17dc'  | ['04c29a25-0ac7-4ef9-bf41-df1011c2a975'  | ['01434455979f8f5369ea62fdc2ff4ff1360677293c575d32f1672521daaee69a7f111448645d4c70464db9dbbbe3d009c42336fd2801161e3418c607aa4efc1d'  | 2025-03-12 | 8    |
# | 543-67cc800e1eb2     |                   |           |       |        |            |              |  '6d5bce0c-e166-460f-a432-879f253d4eda'  |  '3a6b6371-0afb-4ec2-9729-67f54ec18454'  |  'c4c5297b4bf585666851d3e50123a6e5dd9a6223b14675624752a2a3033ba6629af55fb798a18a2d6ecbb974baddbfb2eace4d6468971449b35c10fa5c1cc2cc'  |            |      |
# |                      |                   |           |       |        |            |              |  'd7b3cafa-352a-464e-aa67-a58cc0cce3a2'  |  '4319e729-a0eb-4580-9ec0-73a2fe104afd'  |  'c74ed55a3ebcbc0bb18a6e60a119aab7efcf80364e115f5ce4157b1ac1a2aef7ac4d9f0b13ab35a02fdc3814716c37007baabe0eeb612481ae10ef89fdc45015'] |            |      |
# |                      |                   |           |       |        |            |              |  'd6d7881f-e57c-4f34-8f2b-ac6b1250a9a9'  |  '480a1038-c5a7-4df3-aea5-fba2f2e85953'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'bfc9aac3-999b-49cb-b81e-6339836368d4'  |  '7ca46970-b1a2-4592-98ac-17a28c3e8141'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'af9a14ed-b907-4097-826e-fe106502d627'  |  '7f8dbd71-f326-4f25-812b-29466e517ece'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'fb0ba0b2-b5fe-4a4d-a0d2-fdf0d2518c08'  |  'ea35dc50-a02c-440e-9e9a-91184a4032f4'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0d6ad177-3e6a-4cc5-bf6c-0c0e1a4683c7'] |                                          |                                                                                                                                      |            |      |
# | 4997ba0b-6f89-4d7d-9 | 11                | 11        | 1     | 3      | []         | Community 11 | ['758325f0-6a01-487e-82e4-3fe8dc7dd3f9'  | ['4de5bed7-b933-47fc-bddc-e325df3fad6a'  | ['c4c5297b4bf585666851d3e50123a6e5dd9a6223b14675624752a2a3033ba6629af55fb798a18a2d6ecbb974baddbfb2eace4d6468971449b35c10fa5c1cc2cc'] | 2025-03-12 | 3    |
# | bac-338c49e7ab62     |                   |           |       |        |            |              |  '8b0e3553-021a-4e25-9458-77f5ebe2a61f'  |  '6ac1c842-fdfc-4edf-bc8e-8047520d4751'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '8384bbeb-0e91-4624-9ce1-fac0cfe9b59b'] |                                          |                                                                                                                                      |            |      |
# | b3c084ab-ae7f-436f-8 | 12                | 12        | 1     | 4      | []         | Community 12 | ['a75e5d6d-485d-43b5-a3cd-6d4cfd872342'  | ['1f3c29b7-70c4-4354-a630-66581b98f6e2'  | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] | 2025-03-12 | 6    |
# | 117-edd1c1860720     |                   |           |       |        |            |              |  'e1454e36-6ef9-44b7-b642-0093038b32d5'  |  '37f03eb1-7a1f-4461-8282-2d586c56fb4c'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '9f736e48-1338-4b4c-aafb-327d6b30fd86'  |  '612fcffc-84a6-4351-aadb-735cfb6c2a5b'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'e5255339-1528-44e2-add5-3f21316d5ccf'  |  '7e1428dc-4758-41e2-9f8f-6732a35b3b54'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '85bf01f7-c57b-40d4-be01-5665a2d20470'  |  'f4e0d9af-5a23-4e51-9e73-1e0d22cf05e6'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '0e220816-9615-45a2-a7a3-563014c07af7'] |                                          |                                                                                                                                      |            |      |
# | 7508a26d-bac4-4a77-a | 13                | 13        | 1     | 4      | []         | Community 13 | ['80a1b932-03ae-43a0-9bd7-37b6d74f36da'  | ['2bb987ec-fbcd-4aac-8855-27558bf04620'  | ['ff294773b3428854364049d61157058e7f9de1a226375609c8b313aebd02b85757c543588bfd9af6a9fe5ce8b934d3f05568b9d546deea0526c032d061a7a1cd'] | 2025-03-12 | 3    |
# | 5ea-ffd4091a0d4e     |                   |           |       |        |            |              |  '9bf6c182-c48d-4bf4-9717-d64909a75391'  |  '5fd25732-3f80-44ce-8278-fe658530b98b'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '2d9bfc43-247c-447f-9463-c85496ddbf1d'] |                                          |                                                                                                                                      |            |      |
# | 355f84e4-6674-45e6-9 | 14                | 14        | 1     | 4      | [17 18]    | Community 14 | ['59b9f9dc-37ed-424e-bab0-b65edac21a41'  | ['878166d3-3867-4ed6-a734-2cb3fa1d1109'  | ['975147fe6ddf0ae318e21d71cad00286ee9044ec244041b3a3e839c26181775b45e41409bfdae0451c7f506eb94dc9598f67ab941f8144e80075e0c72671b482'  | 2025-03-12 | 5    |
# | 5ad-8628e035bda9     |                   |           |       |        |            |              |  '93762fdf-903f-442e-827b-947c8b9977e1'  |  'a884bad1-9af8-4881-b04b-4a2fc68d4fc0'  |  'd6053c77d9ebfd4d738edc8952fb42859160e8202285dc7775b30a9af0a21112d34c0fa090292a87f803dd2311ac0dcb97628989f4419b04eba30a25c1725299'] |            |      |
# |                      |                   |           |       |        |            |              |  '3274ab5c-a872-4a9b-943c-a18cfbb2209f'  |  'c95c5288-3e62-4a3e-b1f6-bb12de4f7107'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '18b551ac-1aac-44be-abe5-d6270d4e5920'  |  'cca81a4e-099b-47b3-9a35-4919323c17e8'  |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  'ff1490e7-93d6-4f3e-bd04-aa20cf4d134b'] |  'fb95600d-28c3-4999-8823-3b64fcfef2af'] |                                                                                                                                      |            |      |
# | 7e345181-3f87-4af6-b | 15                | 15        | 2     | 5      | []         | Community 15 | ['c4bf1c25-cdd2-4f05-b858-b485717fefa7'  | ['a95ab5d3-0627-4b21-aab3-d37cb154873a'] | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] | 2025-03-12 | 2    |
# | e6b-4fa5c0d6078c     |                   |           |       |        |            |              |  '2c6ffa99-fffb-488f-b050-71deab7c150d'] |                                          |                                                                                                                                      |            |      |
# | 2b49e8b5-e5a8-4a34-8 | 16                | 16        | 2     | 5      | []         | Community 16 | ['50b90370-f4b6-4a3f-a900-363c4c16de17'  | ['78e40a5d-9796-4a3b-9589-6b170ef4ccf7'  | ['286421f13c7d50f5e46eab4c8500bb778a63ef0b115a0125f5b60eac4eb2bfe6b394e8d2dd120622454cee42514379d1e1dbc1664fb018d4ad109f918bdea5bf'] | 2025-03-12 | 3    |
# | f45-21a6a02bfc4f     |                   |           |       |        |            |              |  '42c8cae8-0e5c-4430-b859-595eb4ec584e'  |  '7dc834ae-a064-431b-843b-77d5deda96c1'] |                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |              |  '606558ee-36d4-4626-9c42-7342dc8b1dc7'] |                                          |                                                                                                                                      |            |      |
# | d08c2d67-0506-480e-b | 17                | 17        | 2     | 14     | []         | Community 17 | ['93762fdf-903f-442e-827b-947c8b9977e1'  | ['878166d3-3867-4ed6-a734-2cb3fa1d1109'  | ['975147fe6ddf0ae318e21d71cad00286ee9044ec244041b3a3e839c26181775b45e41409bfdae0451c7f506eb94dc9598f67ab941f8144e80075e0c72671b482'  | 2025-03-12 | 3    |
# | be8-2253647c6c74     |                   |           |       |        |            |              |  '3274ab5c-a872-4a9b-943c-a18cfbb2209f'  |  'a884bad1-9af8-4881-b04b-4a2fc68d4fc0'  |  'd6053c77d9ebfd4d738edc8952fb42859160e8202285dc7775b30a9af0a21112d34c0fa090292a87f803dd2311ac0dcb97628989f4419b04eba30a25c1725299'] |            |      |
# |                      |                   |           |       |        |            |              |  '59b9f9dc-37ed-424e-bab0-b65edac21a41'] |  'c95c5288-3e62-4a3e-b1f6-bb12de4f7107'] |                                                                                                                                      |            |      |
# | b32c5d5d-6041-4bc8-8 | 18                | 18        | 2     | 14     | []         | Community 18 | ['18b551ac-1aac-44be-abe5-d6270d4e5920'  | ['fb95600d-28c3-4999-8823-3b64fcfef2af'] | ['975147fe6ddf0ae318e21d71cad00286ee9044ec244041b3a3e839c26181775b45e41409bfdae0451c7f506eb94dc9598f67ab941f8144e80075e0c72671b482'] | 2025-03-12 | 2    |
# | 175-7e81ff56099c     |                   |           |       |        |            |              |  'ff1490e7-93d6-4f3e-bd04-aa20cf4d134b'] |                                          |                                                                                                                                      |            |      |
# +----------------------+-------------------+-----------+-------+--------+------------+--------------+------------------------------------------+------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+------------+------+

# %% [markdown]
# &emsp;&emsp;各个字段的解释如下所示：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>communities DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个社区记录。                       |
# | human_readable_id   | 字符串             | 可读的标识符，通常用于用户界面显示，便于用户理解和识别。   |
# | community           | 整数               | 社区的标识符，表示该记录所属的社区编号。                   |
# | level               | 整数               | 社区的层级，表示该社区在层级结构中的位置。                 |
# | parent              | 整数               | 父社区的标识符，表示该社区的上级社区，-1 表示没有父社区。  |
# | children            | 列表（字符串）     | 子社区的标识符列表，表示该社区下属的子社区。               |
# | title               | 字符串             | 社区的名称或标题                  |
# | entity_ids          | 列表（字符串）     | 关联的实体的唯一标识符列表，通常用于将社区与实体关联。     |
# | relationship_ids    | 列表（字符串）     | 关联的关系的唯一标识符列表，表示该社区中涉及的关系。       |
# | text_unit_ids       | 列表（字符串）     | 关联的文本单元的唯一标识符列表，通常用于将社区与文本关联。 |
# | period              | 日期               | 社区的时间段，表示该社区的有效时间范围。                   |
# | size                | 整数               | 社区的规模，通常表示社区中包含的实体或成员数量。           |
# </div>

# %% [markdown]
# &emsp;&emsp;思考现在已经完成的节点和关系，我们其实只需要把关系与社区进行关联就足够了。因此，导入的策略可以考虑以下原则：
#
# - **节点标识**：需要使用`id`字段作为Community节点的唯一标识符，确保图谱中节点一致性。
# - **约束策略**：唯一性约束，确保关系的id是唯一的。
# - **属性选择**：比如社区的名称，级别，规模等，根据需求选择。
# - **关系策略**：与该社区相关的实体节点（通过 relationship_ids）与社区建立 IN_COMMUNITY 关系。

# %% [markdown]
# &emsp;&emsp;因此，把上述的策略转化成代码。就如下所示：

# %%
def setup_community_constraints():
    """创建Community标签的约束"""
    with driver.session(database=NEO4J_DATABASE) as session:
        try:
            # 创建Community.id唯一性约束
            session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (c:__Community__) REQUIRE c.id IS UNIQUE")
            print("已创建__Community__.id唯一性约束")
        except Exception as e:
            print(f"创建__Community__约束时出错 (可能已存在): {e}")
            # 尝试旧版本Neo4j的语法
            try:
                session.run("CREATE CONSTRAINT ON (c:__Community__) ASSERT c.id IS UNIQUE")
                print("已使用旧语法创建__Community__.id唯一性约束")
            except Exception as e2:
                print(f"使用旧语法创建约束也失败: {e2}")

def import_communities(df_communities, batch_size=100, max_workers=8):
    """
    导入社区(Community)数据到Neo4j
    
    参数:
    - df_communities: 包含社区数据的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """
    # 1. 创建Community的约束
    setup_community_constraints()
    
    # 2. 预处理列表字段 - 确保是列表格式
    print("预处理列表字段...")
    
    # 创建DataFrame的副本
    df_communities = df_communities.copy()
    
    # 需要处理的列表字段
    list_fields = ['children', 'entity_ids', 'relationship_ids', 'text_unit_ids']
    
    for field in list_fields:
        if field in df_communities.columns:
            for idx, row in df_communities.iterrows():
                field_value = row.get(field)
                
                # 如果不是列表，转换为列表
                if not isinstance(field_value, list):
                    if isinstance(field_value, str):
                        try:
                            # 尝试解析JSON字符串
                            import json
                            field_value = json.loads(field_value)
                        except:
                            # 如果解析失败，将其作为单个元素的列表
                            field_value = [field_value]
                    elif hasattr(field_value, 'dtype') and hasattr(field_value, 'tolist'):
                        # 处理NumPy数组
                        field_value = field_value.tolist()
                    else:
                        # 其他类型，转为列表
                        field_value = [field_value] if field_value is not None else []
                
                # 处理嵌套列表
                flat_field_value = []
                for item in field_value:
                    if isinstance(item, list) or (hasattr(item, 'dtype') and hasattr(item, 'tolist')):
                        if hasattr(item, 'tolist'):
                            flat_field_value.extend(item.tolist())
                        else:
                            flat_field_value.extend(item)
                    else:
                        flat_field_value.append(item)
                
                # 确保所有ID都是字符串且非空
                if field in ['entity_ids', 'relationship_ids', 'text_unit_ids']:
                    flat_field_value = [str(id) for id in flat_field_value if id is not None and str(id).strip() != '']
                
                # 更新DataFrame
                df_communities.at[idx, field] = flat_field_value
    
    # 3. 导入社区节点
    print("开始导入社区节点...")
    
    community_statement = """
    // 创建Community节点
    MERGE (c:__Community__ {id: value.id})
    SET c.human_readable_id = value.human_readable_id,
        c.community = value.community,
        c.level = value.level,
        c.parent = value.parent,
        c.children = value.children,
        c.title = value.title,
        c.period = value.period,
        c.size = value.size,
        c.name = coalesce(value.title, value.human_readable_id, 'Community_' + value.id)
    
    RETURN c.id as community_id
    """
    
    # 执行导入社区节点
    community_result = parallel_batched_import(community_statement, df_communities, batch_size, max_workers)
    print(f"已创建 {community_result['successful_rows']} 个__Community__节点")
    
    # 4. 创建与Entity的关系
    print("开始创建社区与实体的关系...")
    
    # 准备Entity关系数据
    entity_relations = []
    for _, row in df_communities.iterrows():
        community_id = row['id']
        entity_ids = row.get('entity_ids', [])
        
        for entity_id in entity_ids:
            entity_relations.append({
                'community_id': community_id,
                'entity_id': entity_id
            })
    
    if entity_relations:
        df_entity_relations = pd.DataFrame(entity_relations)
        
        entity_rel_statement = """
        MATCH (c:__Community__ {id: value.community_id})
        MATCH (e:__Entity__ {id: value.entity_id})
        MERGE (e)-[:IN_COMMUNITY]->(c)
        """
        
        entity_rel_result = parallel_batched_import(entity_rel_statement, df_entity_relations, batch_size, max_workers)
        print(f"已创建 {entity_rel_result['successful_rows']} 个Entity-Community关系")
    else:
        print("没有找到有效的Entity-Community关系数据")
    
    # 5. 创建与Relationship的关系
    print("开始创建社区与关系的关系...")
    
    # 准备Relationship关系数据
    rel_relations = []
    for _, row in df_communities.iterrows():
        community_id = row['id']
        relationship_ids = row.get('relationship_ids', [])
        
        for rel_id in relationship_ids:
            rel_relations.append({
                'community_id': community_id,
                'relationship_id': rel_id
            })
    
    if rel_relations:
        df_rel_relations = pd.DataFrame(rel_relations)
        
        rel_rel_statement = """
        MATCH (c:__Community__ {id: value.community_id})
        MATCH (r:__Relationship__ {id: value.relationship_id})
        MERGE (r)-[:IN_COMMUNITY]->(c)
        """
        
        rel_rel_result = parallel_batched_import(rel_rel_statement, df_rel_relations, batch_size, max_workers)
        print(f"已创建 {rel_rel_result['successful_rows']} 个Relationship-Community关系")
    else:
        print("没有找到有效的Relationship-Community关系数据")
    
    # 6. 验证结果
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Community节点数量
        result = session.run("MATCH (c:__Community__) RETURN count(c) as count")
        community_count = result.single()["count"]
        
        # 检查IN_COMMUNITY关系数量
        result = session.run("MATCH ()-[r:IN_COMMUNITY]->() RETURN count(r) as count")
        in_community_count = result.single()["count"]
        
        print(f"验证结果: {community_count} 个__Community__节点, {in_community_count} 个IN_COMMUNITY关系")
    
    return community_result

# %%
# 导入社区
import_communities(df_communities, batch_size=100, max_workers=8)
# Out:
# 已创建__Community__.id唯一性约束
# 预处理列表字段...
# 开始导入社区节点...
# 开始并行导入 19 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 19 行, 耗时 0.51秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 19 行, 成功 19 行, 失败 0 行
# 总耗时: 0.51秒, 平均速度: 37.47 行/秒
# 已创建 19 个__Community__节点
# 开始创建社区与实体的关系...
# 开始并行导入 114 行数据，分为 2 个批次，每批 100 条
# 批次 1 (行 100-113) 处理失败: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=403, clientId=1] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=402, clientId=2]} on NODE_RELATIONSHIP_GROUP_DELETE(52) because holders of that lock are waiting for ForsetiClient[transactionId=403, clientId=1].
#  Wait list:ExclusiveLock[
# Client[402] waits for [ForsetiClient[transactionId=403, clientId=1]]]}
# 批次 1 失败: 14 行, 耗时 0.69秒, 错误: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=403, clientId=1] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=402, clientId=2]} on NODE_RELATIONSHIP_GROUP_DELETE(52) because holders of that lock are waiting for ForsetiClient[transactionId=403, clientId=1].
#  Wait list:ExclusiveLock[
# Client[402] waits for [ForsetiClient[transactionId=403, clientId=1]]]}
# 进度: 1/2 批次完成 (50.0%)
# 批次 0 完成: 100 行, 耗时 0.70秒
# 进度: 2/2 批次完成 (100.0%)
# 导入完成: 总计 114 行, 成功 100 行, 失败 14 行
# 总耗时: 0.70秒, 平均速度: 143.41 行/秒
# 已创建 100 个Entity-Community关系
# 开始创建社区与关系的关系...
# 开始并行导入 116 行数据，分为 2 个批次，每批 100 条
# 批次 1 (行 100-115) 处理失败: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=406, clientId=1] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=405, clientId=3]} on NODE_RELATIONSHIP_GROUP_DELETE(223) because holders of that lock are waiting for ForsetiClient[transactionId=406, clientId=1].
#  Wait list:ExclusiveLock[
# Client[405] waits for [ForsetiClient[transactionId=406, clientId=1]]]}
# 批次 1 失败: 16 行, 耗时 0.40秒, 错误: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=406, clientId=1] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=405, clientId=3]} on NODE_RELATIONSHIP_GROUP_DELETE(223) because holders of that lock are waiting for ForsetiClient[transactionId=406, clientId=1].
#  Wait list:ExclusiveLock[
# Client[405] waits for [ForsetiClient[transactionId=406, clientId=1]]]}
# 进度: 1/2 批次完成 (50.0%)
# 批次 0 完成: 100 行, 耗时 0.41秒
# 进度: 2/2 批次完成 (100.0%)
# 导入完成: 总计 116 行, 成功 100 行, 失败 16 行
# 总耗时: 0.59秒, 平均速度: 170.37 行/秒
# 已创建 100 个Relationship-Community关系
# 验证结果: 19 个__Community__节点, 200 个IN_COMMUNITY关系
# {'total_rows': 19,
#  'successful_rows': 19,
#  'failed_rows': 0,
#  'duration_seconds': 0.5070624351501465,
#  'rows_per_second': 37.4707307875684,
#  'batch_results': [{'batch': 0,
#    'rows': 19,
#    'success': True,
#    'duration': 0.5055193901062012,
#    'counters': {'_contains_updates': True, 'labels_added': 19, 'nodes_created': 19, 'properties_set': 190}}]}

# %% [markdown]
# &emsp;&emsp;执行完成后，可以在`localhost:7474`的`Neo4j`浏览器中，可以看到会生成`__Community__`节点，同时，`__Entity__`节点与`__Community__`节点之间，也创建了`IN_COMMUNITY`关系，以及`__Relationship__`节点与`__Community__`节点之间，也创建了`IN_COMMUNITY`关系。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121942902.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了`communities.parquet`文件的导入。接下来，我们开始导入`community_reports.parquet`文件。

# %% [markdown]
# ## 4.7 导入社区报告

# %% [markdown]
# &emsp;&emsp;在`community_reports.parquet`文件中，主要存储的内容是让大模型通过提示工程，对每个社区中的实体和关系进行总结，并生成社区的报告。读取该文件的代码如下所示：

# %%
# 使用绝对路径读取 Parquet 文件
df_communities_reports = pd.read_parquet('community_reports.parquet')  # 替换为实际路径

# 假设 df 是你的 DataFrame
print(tabulate(df_communities_reports, headers='keys', tablefmt='pretty', showindex=False, stralign='left', maxcolwidths=[20, 20, 20, 20, 20]))
# Out:
# +----------------------+-------------------+-----------+-------+--------+------------+------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------+
# | id                   | human_readable_id | community | level | parent | children   | title                                    | summary                                                                                                                                                                                                                                                                                                              | full_content                                                                                                                                                                                                                                                                                                         | rank | rating_explanation                                                                                                                   | findings                                                                                                                                                                                                                                                                                                                                                | full_content_json                                                                                                                                                                                                                                                                                                                      | period     | size |
# +----------------------+-------------------+-----------+-------+--------+------------+------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------+
# | 509abf3cc4d4433080f2 | 15                | 15        | 2     | 5      | []         | AlphaGo与李世石的对决                    | 该社区围绕AlphaGo与李世石的对决展开，AlphaGo是谷歌开发的人工智能程序，2016年击败了世界围棋冠军李世石，展示了人工智能的强大潜力。                                                                                                                                                                                     | # AlphaGo与李世石的对决                                                                                                                                                                                                                                                                                              | 8.5  | 影响严重性评分较高，因为AlphaGo的胜利标志着人工智能在复杂策略游戏中的突破，对人工智能领域和围棋界产生了深远影响。                    | [{'explanation': 'AlphaGo在2016年击败世界围棋冠军李世石，这一事件不仅展示了人工智能在复杂策略游戏中的强大潜力，也标志着人工智能技术的一个重要里程碑。这一胜利对人工智能领域产生了深远的影响，推动了相关技术的研究和应用。[数据: 实体 (24), 关系 (34)]', 'summary': 'AlphaGo的胜利标志着人工智能的突破'}                                                 | {                                                                                                                                                                                                                                                                                                                                      | 2025-03-12 | 2    |
# | 45989332bb86         |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |  {'explanation': '李世石作为世界围棋冠军，在与AlphaGo的对决中扮演了关键角色。他的参与不仅增加了对决的关注度，也使得AlphaGo的胜利更加具有说服力。李世石的表现和反应对于理解人工智能与人类在智力游戏中的竞争具有重要意义。[数据: 实体 (31), 关系 (33, 34)]', 'summary': '李世石的角色'}]                                                                  |     "title": "AlphaGo与李世石的对决",                                                                                                                                                                                                                                                                                                  |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | 该社区围绕AlphaGo与李世石的对决展开，AlphaGo是谷歌开发的人工智能程序，2016年击败了世界围棋冠军李世石，展示了人工智能的强大潜力。                                                                                                                                                                                     |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "summary": "该社区围绕AlphaGo与李世石的对决展开，AlphaGo是谷歌开发的人工智能程序，2016年击败了世界围棋冠军李世石，展示了人工智能的强大潜力。",                                                                                                                                                                                     |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "findings": [                                                                                                                                                                                                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | ## AlphaGo的胜利标志着人工智能的突破                                                                                                                                                                                                                                                                                 |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         {                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "summary": "AlphaGo的胜利标志着人工智能的突破",                                                                                                                                                                                                                                                                            |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | AlphaGo在2016年击败世界围棋冠军李世石，这一事件不仅展示了人工智能在复杂策略游戏中的强大潜力，也标志着人工智能技术的一个重要里程碑。这一胜利对人工智能领域产生了深远的影响，推动了相关技术的研究和应用。[数据: 实体 (24), 关系 (34)]                                                                                  |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "explanation": "AlphaGo在2016年击败世界围棋冠军李世石，这一事件不仅展示了人工智能在复杂策略游戏中的强大潜力，也标志着人工智能技术的一个重要里程碑。这一胜利对人工智能领域产生了深远的影响，推动了相关技术的研究和应用。[数据: 实体 (24), 关系 (34)]"                                                                       |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         },                                                                                                                                                                                                                                                                                                                             |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | ## 李世石的角色                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         {                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "summary": "李世石的角色",                                                                                                                                                                                                                                                                                                 |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | 李世石作为世界围棋冠军，在与AlphaGo的对决中扮演了关键角色。他的参与不仅增加了对决的关注度，也使得AlphaGo的胜利更加具有说服力。李世石的表现和反应对于理解人工智能与人类在智力游戏中的竞争具有重要意义。[数据: 实体 (31), 关系 (33, 34)]                                                                               |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "explanation": "李世石作为世界围棋冠军，在与AlphaGo的对决中扮演了关键角色。他的参与不仅增加了对决的关注度，也使得AlphaGo的胜利更加具有说服力。李世石的表现和反应对于理解人工智能与人类在智力游戏中的竞争具有重要意义。[数据: 实体 (31), 关系 (33, 34)]"                                                                    |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         }                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     ],                                                                                                                                                                                                                                                                                                                                 |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "rating": 8.5,                                                                                                                                                                                                                                                                                                                     |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "rating_explanation": "影响严重性评分较高，因为AlphaGo的胜利标志着人工智能在复杂策略游戏中的突破，对人工智能领域和围棋界产生了深远影响。"                                                                                                                                                                                          |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         | }                                                                                                                                                                                                                                                                                                                                      |            |      |
# | 510f6682020c473b89ba | 16                | 16        | 2     | 5      | []         | 谷歌及其技术生态系统                     | 该社区围绕谷歌展开，谷歌是一家全球知名的科技巨头，以其卓越的创新能力著称。谷歌通过收购YouTube和推出Android操作系统，极大地扩展了其技术生态系统。此外，谷歌在人工智能和量子计算领域也取得了显著成就，展现了其在未来技术前沿的持续探索和领导力。                                                                       | # 谷歌及其技术生态系统                                                                                                                                                                                                                                                                                               | 9.5  | 影响严重性评分较高，因为谷歌的技术创新和市场主导地位对全球科技行业有着深远的影响。                                                   | [{'explanation': '谷歌以其卓越的创新能力在全球科技行业中占据领先地位。从收购YouTube到推出Android操作系统，再到开发AlphaGo和投入量子计算领域，谷歌不断扩展其技术生态系统，展现了其在多个技术领域的领导力。[数据: 实体 (23), 关系 (30, 31)]', 'summary': '谷歌的技术创新能力'}                                                                            | {                                                                                                                                                                                                                                                                                                                                      | 2025-03-12 | 3    |
# | cb8d9ed1c7c2         |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |  {'explanation': 'YouTube作为全球知名的在线视频平台，在谷歌的支持下进一步巩固了其在在线视频市场的主导地位。YouTube的广泛视频内容和用户基础使其成为娱乐、教育、新闻等多个领域的重要平台。[数据: 实体 (20), 关系 (30)]', 'summary': 'YouTube的市场主导地位'}                                                                                              |     "title": "谷歌及其技术生态系统",                                                                                                                                                                                                                                                                                                   |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | 该社区围绕谷歌展开，谷歌是一家全球知名的科技巨头，以其卓越的创新能力著称。谷歌通过收购YouTube和推出Android操作系统，极大地扩展了其技术生态系统。此外，谷歌在人工智能和量子计算领域也取得了显著成就，展现了其在未来技术前沿的持续探索和领导力。                                                                       |      |                                                                                                                                      |  {'explanation': 'Android操作系统自2007年推出以来，迅速成为全球最流行的移动操作系统。其开源的特性、广泛的设备兼容性以及丰富的应用生态系统使其在全球范围内占据了主导地位。[数据: 实体 (21), 关系 (31)]', 'summary': 'Android的全球普及'}                                                                                                                 |     "summary": "该社区围绕谷歌展开，谷歌是一家全球知名的科技巨头，以其卓越的创新能力著称。谷歌通过收购YouTube和推出Android操作系统，极大地扩展了其技术生态系统。此外，谷歌在人工智能和量子计算领域也取得了显著成就，展现了其在未来技术前沿的持续探索和领导力。",                                                                       |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |  {'explanation': '谷歌在人工智能领域取得了显著成就，特别是开发了AlphaGo，这一程序成功击败了世界围棋冠军李世石，展示了其在AI领域的领先地位。[数据: 实体 (23)]', 'summary': '谷歌在人工智能领域的成就'}                                                                                                                                                   |     "findings": [                                                                                                                                                                                                                                                                                                                      |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | ## 谷歌的技术创新能力                                                                                                                                                                                                                                                                                                |      |                                                                                                                                      |  {'explanation': '近年来，谷歌在量子计算领域投入了大量资源，并取得了突破性进展。这展现了谷歌在未来技术前沿的持续探索和领导力，对科技行业的发展具有重要意义。[数据: 实体 (23)]', 'summary': '谷歌在量子计算领域的探索'}]                                                                                                                                 |         {                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "summary": "谷歌的技术创新能力",                                                                                                                                                                                                                                                                                           |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | 谷歌以其卓越的创新能力在全球科技行业中占据领先地位。从收购YouTube到推出Android操作系统，再到开发AlphaGo和投入量子计算领域，谷歌不断扩展其技术生态系统，展现了其在多个技术领域的领导力。[数据: 实体 (23), 关系 (30, 31)]                                                                                              |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "explanation": "谷歌以其卓越的创新能力在全球科技行业中占据领先地位。从收购YouTube到推出Android操作系统，再到开发AlphaGo和投入量子计算领域，谷歌不断扩展其技术生态系统，展现了其在多个技术领域的领导力。[数据: 实体 (23), 关系 (30, 31)]"                                                                                   |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         },                                                                                                                                                                                                                                                                                                                             |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | ## YouTube的市场主导地位                                                                                                                                                                                                                                                                                             |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         {                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "summary": "YouTube的市场主导地位",                                                                                                                                                                                                                                                                                        |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | YouTube作为全球知名的在线视频平台，在谷歌的支持下进一步巩固了其在在线视频市场的主导地位。YouTube的广泛视频内容和用户基础使其成为娱乐、教育、新闻等多个领域的重要平台。[数据: 实体 (20), 关系 (30)]                                                                                                                   |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "explanation": "YouTube作为全球知名的在线视频平台，在谷歌的支持下进一步巩固了其在在线视频市场的主导地位。YouTube的广泛视频内容和用户基础使其成为娱乐、教育、新闻等多个领域的重要平台。[数据: 实体 (20), 关系 (30)]"                                                                                                        |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         },                                                                                                                                                                                                                                                                                                                             |            |      |
# ...
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         },                                                                                                                                                                                                                                                                                                                             |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | ## 科技巨头推动全球经济数字化转型                                                                                                                                                                                                                                                                                    |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         {                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "summary": "科技巨头推动全球经济数字化转型",                                                                                                                                                                                                                                                                               |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      | 科技巨头通过技术创新推动了全球经济的数字化转型。电商平台作为科技巨头的一部分，改变了生活方式并推动了全球经济的数字化转型。[数据: 实体 (53, 54), 关系 (75, 76)]                                                                                                                                                       |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |             "explanation": "科技巨头通过技术创新推动了全球经济的数字化转型。电商平台作为科技巨头的一部分，改变了生活方式并推动了全球经济的数字化转型。[数据: 实体 (53, 54), 关系 (75, 76)]"                                                                                                                                            |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |         }                                                                                                                                                                                                                                                                                                                              |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     ],                                                                                                                                                                                                                                                                                                                                 |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "rating": 8.5,                                                                                                                                                                                                                                                                                                                     |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         |     "rating_explanation": "影响严重性评分较高，因为这些科技巨头和新兴技术对全球经济、社会生活方式以及未来科技趋势具有深远影响。"                                                                                                                                                                                                       |            |      |
# |                      |                   |           |       |        |            |                                          |                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                      |      |                                                                                                                                      |                                                                                                                                                                                                                                                                                                                                                         | }                                                                                                                                                                                                                                                                                                                                      |            |      |
# +----------------------+-------------------+-----------+-------+--------+------------+------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------+

# %% [markdown]
# &emsp;&emsp;各个字段的解释如下所示：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>community_reports DataFrame 字段解释</font></p>
# <div class="center">
#
# | 字段名              | 类型               | 说明                                                         |
# |---------------------|--------------------|--------------------------------------------------------------|
# | id                  | 字符串             | 唯一标识符，用于唯一标识每个记录。                           |
# | human_readable_id   | 字符串             | 可读的标识符，通常用于用户界面显示，便于用户理解和识别。   |
# | community           | 整数               | 社区的标识符，表示该记录所属的社区编号。                   |
# | level               | 整数               | 社区的层级，表示该社区在层级结构中的位置。                 |
# | parent              | 整数               | 父社区的标识符，表示该社区的上级社区，-1 表示没有父社区。  |
# | children            | 列表（字符串）     | 子社区的标识符列表，表示该社区下属的子社区。               |
# | title               | 字符串             | 社区的名称或标题，简要描述该社区的主题。                   |
# | summary             | 字符串             | 对社区的简要描述，提供更多上下文信息。                     |
# | full_content        | 字符串             | 社区的详细内容，包含更全面的信息和背景。                   |
# | rank                | 浮点数             | 社区的排名，通常用于表示社区的重要性或影响力。             |
# | rating_explanation   | 字符串             | 对社区评分的解释，说明评分的依据和原因。                   |
# | findings            | 列表（字典）       | 相关发现的列表，每个发现包含解释和摘要。                   |
# | full_content_json   | JSON               | 社区的完整内容，以 JSON 格式存储，便于数据交换和处理。     |
# | period              | 日期               | 社区的时间段，表示该社区的有效时间范围。                   |
# | size                | 整数               | 社区的规模，通常表示社区中包含的实体或成员数量。           |
# </div>

# %% [markdown]
# &emsp;&emsp;对于社区报告，是不是需要将它们连接到它们所涉及的实体，并且为社区更新属性。因此，导入的策略可以考虑以下原则：
#
# - **属性策略**：更新社区的属性，包括 level、title、rank、rank_explanation、full_content 和 summary。
# - **关系策略**：遍历与该社区相关的发现（findings），为每个发现创建一个新的 Finding 节点，并将其与社区建立 HAS_FINDING 关系。

# %%
def import_community_reports(df_reports, batch_size=20, max_workers=2):
    """
    导入社区报告数据到Neo4j
    
    参数:
    - df_reports: 包含社区报告数据的DataFrame
    - batch_size: 每批处理的行数
    - max_workers: 并行线程数
    
    返回:
    - 导入统计信息的字典
    """
    # 1. 预处理社区报告数据
    print("预处理社区报告数据...")
    df_reports = df_reports.copy()
    
    # 先创建新列，避免KeyError
    df_reports['community_str'] = None
    df_reports['processed_findings'] = None
    
    # 检查findings字段并打印样本数据以便调试
    sample_findings = []
    
    for idx, row in df_reports.iterrows():
        # 处理community字段 - 先转换为字符串再赋值
        if 'community' in row:
            community_str = str(row['community'])
            df_reports.at[idx, 'community_str'] = community_str
        
        # 处理findings字段 - 特别处理NumPy数组
        findings = row.get('findings')
        
        # 处理NumPy数组
        if hasattr(findings, 'dtype') and hasattr(findings, 'tolist'):
            print(f"行 {idx}: 将NumPy数组转换为列表，形状: {findings.shape if hasattr(findings, 'shape') else 'unknown'}")
            try:
                findings = findings.tolist()
            except Exception as e:
                print(f"行 {idx}: 转换NumPy数组失败: {e}")
                findings = []
        # 处理其他类型
        elif not isinstance(findings, list):
            if isinstance(findings, str):
                try:
                    import json
                    findings = json.loads(findings)
                    print(f"行 {idx}: 从字符串解析findings成功")
                except Exception as e:
                    print(f"行 {idx}: 解析findings字符串失败: {e}")
                    findings = []
            else:
                print(f"行 {idx}: findings不是列表、NumPy数组或字符串，而是 {type(findings)}")
                findings = []
        
        # 确保findings是有效的列表
        if not isinstance(findings, list):
            print(f"行 {idx}: 处理后findings仍不是列表，强制设为空列表")
            findings = []
        
        # 打印findings的内容以便调试
        if len(findings) > 0:
            print(f"行 {idx}: 找到 {len(findings)} 个findings")
            if idx < 3:  # 只打印前3行的详细内容
                print(f"  示例: {findings[0]}")
                sample_findings.append((idx, findings))
        else:
            print(f"行 {idx}: 没有找到findings")
        
        # 确保每个finding是字典
        valid_findings = []
        for i, finding in enumerate(findings):
            if isinstance(finding, dict):
                # 确保必要的字段存在
                if 'summary' not in finding:
                    finding['summary'] = f"Finding_{i}"
                if 'explanation' not in finding:
                    finding['explanation'] = ""
                valid_findings.append(finding)
            else:
                print(f"行 {idx}: 跳过无效的finding类型: {type(finding)}")
                # 尝试转换为字典
                if isinstance(finding, (list, tuple)) and len(finding) >= 2:
                    try:
                        valid_findings.append({
                            'summary': str(finding[0]),
                            'explanation': str(finding[1])
                        })
                        print(f"  成功转换为字典: {finding[0]}")
                    except Exception as e:
                        print(f"  转换失败: {e}")
        
        # 更新DataFrame - 使用at而不是loc
        df_reports.at[idx, 'processed_findings'] = valid_findings
    
    # 打印样本数据
    print(f"收集了 {len(sample_findings)} 个样本findings:")
    for idx, findings in sample_findings:
        print(f"行 {idx}: {len(findings)} 个findings")
    
    # 2. 准备Finding数据 - 直接从处理后的数据创建
    print("准备Finding数据...")
    findings_data = []
    
    for idx, row in df_reports.iterrows():
        community_str = row['community_str']
        processed_findings = row['processed_findings']
        
        if not isinstance(processed_findings, list):
            print(f"行 {idx}: processed_findings不是列表，跳过")
            continue
            
        for i, finding in enumerate(processed_findings):
            if isinstance(finding, dict):
                finding_id = f"{community_str}_{i}"
                findings_data.append({
                    'finding_id': finding_id,
                    'community_id': community_str,
                    'summary': finding.get('summary', f"Finding_{i}"),
                    'explanation': finding.get('explanation', "")
                })
    
    print(f"准备了 {len(findings_data)} 个Finding数据")
    
    # 3. 导入社区节点
    print("步骤1: 导入社区节点...")
    
    # 社区节点创建语句
    community_statement = """
    MERGE (c:__Community__ {community: value.community_str})
    SET c.level = value.level,
        c.title = value.title,
        c.rank = value.rank,
        c.rating_explanation = value.rating_explanation,
        c.full_content = value.full_content,
        c.summary = value.summary,
        c.name = coalesce(value.title, 'Community_' + value.community_str)
    RETURN c.community as community_id
    """
    
    # 执行导入社区节点
    community_result = parallel_batched_import(community_statement, df_reports, batch_size, max_workers)
    print(f"已创建/更新 {community_result['successful_rows']} 个社区节点")
    
    # 4. 如果有Finding数据，创建Finding节点和关系
    if findings_data:
        print("步骤2: 导入Finding节点和关系...")
        df_findings = pd.DataFrame(findings_data)
        
        finding_statement = """
        // 创建Finding节点
        MERGE (f:__Finding__ {id: value.finding_id})
        SET f.summary = value.summary,
            f.explanation = value.explanation,
            f.name = value.summary
        
        // 创建与Community的关系
        WITH f, value
        MATCH (c:__Community__ {community: value.community_id})
        MERGE (c)-[:HAS_FINDING]->(f)
        """
        
        # 执行导入Finding节点和关系
        finding_result = parallel_batched_import(finding_statement, df_findings, batch_size, max_workers)
        print(f"已创建 {finding_result['successful_rows']} 个Finding节点和HAS_FINDING关系")
    else:
        print("没有找到有效的Finding数据，跳过创建Finding节点和关系")
    
    # 5. 验证结果
    with driver.session(database=NEO4J_DATABASE) as session:
        # 检查Community节点数量
        result = session.run("MATCH (c:__Community__) RETURN count(c) as count")
        community_count = result.single()["count"]
        
        # 检查Finding节点数量 - 使用try-except处理可能的错误
        try:
            result = session.run("MATCH (f:__Finding__) RETURN count(f) as count")
            finding_count = result.single()["count"]
        except Exception as e:
            print(f"查询Finding节点时出错: {e}")
            finding_count = 0
        
        # 检查HAS_FINDING关系数量 - 使用try-except处理可能的错误
        try:
            result = session.run("MATCH ()-[r:HAS_FINDING]->() RETURN count(r) as count")
            has_finding_count = result.single()["count"]
        except Exception as e:
            print(f"查询HAS_FINDING关系时出错: {e}")
            has_finding_count = 0
        
        print(f"验证结果: {community_count} 个__Community__节点, {finding_count} 个__Finding__节点, {has_finding_count} 个HAS_FINDING关系")
    
    return community_result

# %%
# 导入社区报告
import_community_reports(df_communities_reports, batch_size=100, max_workers=8)
# Out:
# 预处理社区报告数据...
# 行 0: 将NumPy数组转换为列表，形状: (2,)
# 行 0: 找到 2 个findings
#   示例: {'explanation': 'AlphaGo在2016年击败世界围棋冠军李世石，这一事件不仅展示了人工智能在复杂策略游戏中的强大潜力，也标志着人工智能技术的一个重要里程碑。这一胜利对人工智能领域产生了深远的影响，推动了相关技术的研究和应用。[数据: 实体 (24), 关系 (34)]', 'summary': 'AlphaGo的胜利标志着人工智能的突破'}
# 行 1: 将NumPy数组转换为列表，形状: (5,)
# 行 1: 找到 5 个findings
#   示例: {'explanation': '谷歌以其卓越的创新能力在全球科技行业中占据领先地位。从收购YouTube到推出Android操作系统，再到开发AlphaGo和投入量子计算领域，谷歌不断扩展其技术生态系统，展现了其在多个技术领域的领导力。[数据: 实体 (23), 关系 (30, 31)]', 'summary': '谷歌的技术创新能力'}
# 行 2: 将NumPy数组转换为列表，形状: (4,)
# 行 2: 找到 4 个findings
#   示例: {'explanation': '量子计算作为科技行业的新兴技术之一，谷歌等科技巨头已在该领域投入大量资源，并取得了突破性进展。量子计算的发展不仅引领着当前的创新潮流，还将在未来继续推动科技行业的发展。[数据: 实体 (52), 关系 (68)]', 'summary': '量子计算的突破性进展'}
# 行 3: 将NumPy数组转换为列表，形状: (3,)
# 行 3: 找到 3 个findings
# 行 4: 将NumPy数组转换为列表，形状: (3,)
# 行 4: 找到 3 个findings
# 行 5: 将NumPy数组转换为列表，形状: (3,)
# 行 5: 找到 3 个findings
# 行 6: 将NumPy数组转换为列表，形状: (5,)
# 行 6: 找到 5 个findings
# 行 7: 将NumPy数组转换为列表，形状: (2,)
# 行 7: 找到 2 个findings
# 行 8: 将NumPy数组转换为列表，形状: (4,)
# 行 8: 找到 4 个findings
# 行 9: 将NumPy数组转换为列表，形状: (5,)
# 行 9: 找到 5 个findings
# 行 10: 将NumPy数组转换为列表，形状: (3,)
# 行 10: 找到 3 个findings
# 行 11: 将NumPy数组转换为列表，形状: (4,)
# 行 11: 找到 4 个findings
# 行 12: 将NumPy数组转换为列表，形状: (4,)
# 行 12: 找到 4 个findings
# 行 13: 将NumPy数组转换为列表，形状: (5,)
# 行 13: 找到 5 个findings
# 行 14: 将NumPy数组转换为列表，形状: (5,)
# 行 14: 找到 5 个findings
# 行 15: 将NumPy数组转换为列表，形状: (5,)
# 行 15: 找到 5 个findings
# 行 16: 将NumPy数组转换为列表，形状: (4,)
# 行 16: 找到 4 个findings
# 行 17: 将NumPy数组转换为列表，形状: (5,)
# 行 17: 找到 5 个findings
# 行 18: 将NumPy数组转换为列表，形状: (5,)
# 行 18: 找到 5 个findings
# 收集了 3 个样本findings:
# 行 0: 2 个findings
# 行 1: 5 个findings
# 行 2: 4 个findings
# 准备Finding数据...
# 准备了 76 个Finding数据
# 步骤1: 导入社区节点...
# 开始并行导入 19 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 19 行, 耗时 0.39秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 19 行, 成功 19 行, 失败 0 行
# 总耗时: 0.39秒, 平均速度: 48.34 行/秒
# 已创建/更新 19 个社区节点
# 步骤2: 导入Finding节点和关系...
# 开始并行导入 76 行数据，分为 1 个批次，每批 100 条
# 批次 0 完成: 76 行, 耗时 0.51秒
# 进度: 1/1 批次完成 (100.0%)
# 导入完成: 总计 76 行, 成功 76 行, 失败 0 行
# 总耗时: 0.59秒, 平均速度: 127.75 行/秒
# 已创建 76 个Finding节点和HAS_FINDING关系
# 验证结果: 38 个__Community__节点, 76 个__Finding__节点, 76 个HAS_FINDING关系
# {'total_rows': 19,
#  'successful_rows': 19,
#  'failed_rows': 0,
#  'duration_seconds': 0.39302730560302734,
#  'rows_per_second': 48.34269713359491,
#  'batch_results': [{'batch': 0,
#    'rows': 19,
#    'success': True,
#    'duration': 0.39155006408691406,
#    'counters': {'_contains_updates': True, 'labels_added': 19, 'nodes_created': 19, 'properties_set': 152}}]}

# %% [markdown]
# &emsp;&emsp;在完成后，可以在`localhost:7474`的`Neo4j`浏览器中，可以看到会生成`__Community__`节点，同时，`__Finding__`节点与`__Community__`节点之间，也创建了`HAS_FINDING`关系。如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503121957586.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了`community_reports.parquet`文件的导入。

# %% [markdown]
# &emsp;&emsp;完成了所有文件的导入后，一个完整的知识图谱就构建完成了。现阶段就已经可以开始使用`Neo4j`的`Cypher`语句，查询知识图谱中的数据。比如一些常见的查询，如下所示：

# %% [markdown]
# &emsp;&emsp;显示一些__Entity__节点及其关系:
#
# ```bash
#     MATCH path = (:__Entity__)-[:RELATED]->(:__Entity__)
#     RETURN path LIMIT 200
# ```

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131154423.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;显示块和文档（词汇图）：
#
# ```bash
#     MATCH (d:__Document__) WITH d LIMIT 1
#     MATCH path = (d)<-[:PART_OF]-(c:__Chunk__)
#     RETURN path LIMIT 100
# ```

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131154424.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;返回最多 25 个实体之间的社区关系路径：
#
# ```bash
#     MATCH p=()-[r:IN_COMMUNITY]->()
#     RETURN p LIMIT 25
# ```

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503131154425.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们完成了`Microsoft GraphRAG` 生成索引的完整知识图谱构建与可视化。详细了解了知识图谱的全貌后，接下来的课程，我们进行`Microsoft GraphRAG` 实现的`Query` 阶段的实操以及底层原理的讲解。
